# %%
#python resample.py $IMAGE_TO_RESAMPLE $REFERENCE_IMAGE

# %%
#!jupyter nbconvert roi_bpress_2023-6-1.ipynb --to python
# Out:
# [NbConvertApp] Converting notebook roi_bpress_2023-6-1.ipynb to python
# [NbConvertApp] Writing 30402 bytes to roi_bpress_2023-6-1.py

# %%
"""
~~~ Script description ~~~
adapted from troubshoot_bpress_slopes_6-24-22
adapted from ATM_bpress_within-between_1-4-23_rest.py on 1/31/23
- changed bpress to exclude overlap
changed path, added sys.argv for multiple jobs 5/11/23
- roi_activations_2023-05-11.npy is the same dictionary as
  mvpa_results_2023-05-11.npy with more windows and better name  
5/13
- Iterate across subs 
this script specifically looks at 28 subs for dmPFC and rTPJ
5/24
- create function that normalizes over space instead of time
6-1
- ammend for searchlight analysis w 200 schaefer rois
7-12
-copied from 6-1. rerunning for specific ROIs
"""
# Out:
# '\n~~~ Script description ~~~\nadapted from troubshoot_bpress_slopes_6-24-22\nadapted from ATM_bpress_within-between_1-4-23_rest.py on 1/31/23\n- changed bpress to exclude overlap\nchanged path, added sys.argv for multiple jobs 5/11/23\n- roi_activations_2023-05-11.npy is the same dictionary as\n  mvpa_results_2023-05-11.npy with more windows and better name  \n5/13\n- Iterate across subs \nthis script specifically looks at 28 subs for dmPFC and rTPJ\n5/24\n- create function that normalizes over space instead of time\n6-1\n- ammend for searchlight analysis w 200 schaefer rois\n7-12\n-copied from 6-1. rerunning for specific ROIs\n'

# %%
import nibabel as nib

from nilearn.input_data import NiftiMasker , MultiNiftiMasker

import nilearn as nil
"""
Plotting!
https://nilearn.github.io/plotting/index.html

"""
from nilearn import plotting
import numpy as np 
import os
import os.path
import scipy.io
import nibabel as nib
from nilearn.input_data import NiftiMasker
from nilearn.masking import compute_epi_mask
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import PredefinedSplit
from copy import deepcopy

import warnings
import sys  
import random
# import logging

import deepdish as dd
import numpy as np

import brainiak.eventseg.event
import nibabel as nib
from nilearn.input_data import NiftiMasker

import scipy.io
from scipy import stats
from scipy.stats import norm, zscore, pearsonr
from scipy.signal import gaussian, convolve
from sklearn import decomposition
from sklearn.model_selection import LeaveOneOut, KFold

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches
import seaborn as sns 

sns.set(style = 'white', context='talk', font_scale=1, rc={"lines.linewidth": 2})

if not sys.warnoptions:
    warnings.simplefilter("ignore")

"""
from utils import sherlock_h5_data

if not os.path.exists(sherlock_h5_data):
    os.makedirs(sherlock_h5_data)
    print('Make dir: ', sherlock_h5_data)
else: 
    print('Data path exists')
    
from utils import sherlock_dir
"""

random.seed(10)

from brainiak import image, io
from scipy.stats import stats
import nibabel as nib
import numpy as np
from matplotlib import pyplot as plt
from brainiak import image, io

import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import LeavePGroupsOut

import pandas as pd
from nilearn.plotting import plot_glass_brain

# Import machine learning libraries
from nilearn.input_data import NiftiMasker
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold, f_classif, SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from scipy.stats import sem
from copy import deepcopy
from sklearn.metrics import roc_auc_score
import statistics

from nilearn import datasets, plotting
from nilearn.input_data import NiftiSpheresMasker

from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn.image import concat_imgs, resample_img, mean_img, index_img
from nilearn import image
from nilearn import masking
from nilearn.plotting import view_img
from nilearn.plotting import plot_design_matrix
from nilearn.reporting import get_clusters_table
from nilearn import input_data
from nilearn import datasets


from nilearn.plotting import plot_roi
# Out:
# /jukebox/pkgs/PYGER/base/envs/0.11.0/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
from nilearn.image import resample_to_img

# %% [markdown]
# # Functions

# %%
## Expand / Label TRs
"""
0 = SM
1 = SC
2 = OM
3 = OC
4 = Re
requires list of labels ouputed by psychopy (column 1 - MM_self_title.started, etc.)
returns label list (order is preserved) and TR labels
"""

def label_lists(label, num_tr):
    b = [[]]
    a = []
    for i in label:
        # substring label in psychopy output
        # if the first three characters == M_s, etc, then add correct indext to string
        if i[1:4] == "M_s":
            a.append("SM")
            b.append([0]*num_tr)
        elif i[1:4] == "C_s":
            a.append("SC")
            b.append([1]*num_tr)        
        elif i[1:4] == "M_o":
            a.append("OM")
            b.append([2]*num_tr)
        elif i[1:4] == "C_o":
            a.append("OC")
            b.append([3]*num_tr)     
        else:
            a.append("Re")
            b.append([4]*num_tr)     
    return a, b[1:]

# %%
def find_cond_index(sub_ses_labels):
    """
    For the array of ordered run names (i.e.'Re', 'SM',) find the two indexes per condition
    """ 
    lab_inx = []

    a = []
    b = []
    c = []
    d = []
    e = []

    for i in enumerate(sub_ses_labels):
        if i[1] == "SM":
            # append the index according to where it appeared in the array
            a.append(i[0])
        if i[1] == "SC":
            b.append(i[0])
        if i[1] == "OM":
            c.append(i[0])
        if i[1] == "OC":
            d.append(i[0])

    # Create a dictionary where each key contains the appropriate indexes
    lab_indic = {
        'SM' : a,
        'SC' : b,
        'OM' : c,
        'OC' : d,
        'RE' : [0,9]
    }
    return lab_indic

# %%
def load_epi_data(sub, ses, task,run, space):
  # Load MRI file
    if space == "MNI":
        epi_in = os.path.join(data_dir, sub, ses, 'func', "%s_%s_task-%s_run-%s_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz" % (sub, ses, task,run))
    elif space == "T1":
        epi_in = os.path.join(data_dir, sub, ses, 'func', "%s_%s_task-%s_run-%s_space-T1w_desc-preproc_bold.nii.gz" % (sub, ses, task,run))
    else:
        print("wrong load epi input. check this function")
    epi_data = nib.load(epi_in)
    print("Loading data from %s" % (epi_in))
    return epi_data

def load_roi_mask(ROI_name, space):
    if space == "MNI":
        maskdir = os.path.join(rois_dir)    
        print("expected shape: 78, 93,65")
    elif space == "T1":
        maskdir = os.path.join(rois_dir+ "/T1")
        print("expected shape: 56, 72,53")
    else:
        print("wrong mask input. check this function")
    # load the mask
    maskfile = os.path.join(maskdir, "%s.nii" % (ROI_name))
    mask = nib.load(maskfile)
    print("mask shape: ", mask.shape)
    print("Loaded %s mask" % (ROI_name))
    return mask

# %%
def intersect_mask(sub, num_runs,reg, ses="ses-01",task="Attn"):
    # This is based off of 'load_data' function in template
    # Loads all fMRI runs into a matrix #
    """
    reg = T1 or MNI registration?
    norm_type = by Space or by Time? 
    """
    yoz = []
    print("Begin intersecting, yeehaw")
    for run in range(1, num_runs + 1):
        # Load epi data 
        epi = load_epi_data(sub,ses,task,run,reg)
        # Load ROI data
        roi_samp = compute_epi_mask(epi)
     #   print(roi_samp)
        #nifti_masker = NiftiMasker(mask_img=roi_samp)
        #maskedData = nifti_masker.fit_transform(epi)
        yoz.append(roi_samp)
    #print(concatenated_data)
    epi_data = nil.masking.intersect_masks(yoz)
    print("all done wit da intersextion (lol)")

    return epi_data

# %%
# find indices of where each condition occured in 10 runs for each sub
def fnd_indices(sub,behav_p):
    behav = pd.read_csv(os.path.join(behav_p, '%s_behav_cleaned.csv') % (sub))
    # Define the column in behav to be used for creating labels # 
    label = behav.iloc[:,1]
    # Create an array of labels [1] AND the order in which runs occured [0]#
    sub_ses_labels = label_lists(label, 200)
    ## Find run sequence, extraction condition indexes from behav data ## 
    return find_cond_index(sub_ses_labels[0])

# %%
# organize into dict
def org_bdata_dic(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b, in a dik
    
    """
    bold_dict = {}
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    bold_dict[cond_a] = a
    bold_dict[cond_b] = b
    
    print("concatenated", cond_a, cond_b)
    return bold_dict

# organize into list
def org_bdata_list(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b
    
    """
    bold_data = []
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    print("concatenated", cond_a, cond_b)
    return a + b

def org_bdata(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b
    
    """
    bold_data = []
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    print("returning", cond_a, cond_b)
    return np.asarray(a), np.asarray(b)

# %%
suffix = "_205_noproc.npy"

# load data into a dictionary
def load_smsc_fmri_list(sub,behav_p,cond_a,cond_b,suffix,int_mask):
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    #cats = load_fMRI3d(sub, 10, "MNI", 'space', int_mask)
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    return org_bdata_list(cats, lab_indic, cond_a, cond_b)

# Load data into dictionary
def load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask):
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    #cats = load_fMRI3d(sub, 10, "MNI", 'space', int_mask)
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    return org_bdata_dic(cats, lab_indic, cond_a, cond_b)

# %% [markdown]
# # Rest stuff

# %%
def create_event_list_rest(sub, bpress, cond, cond_alt, run_dic, base_onset,comp_onset_list,stim_dur):
    """
    this function reads in a condition for each sub
    and returns the corresponding b4 + after events
    
    sub: subject number
    bpress: array of button press onset times
    cond: which condition do you want to create event dataframe fore
    """
    all_tims = []
    events = {}
    # Convert alternate bpress to array #
    bpress_arr = np.asarray(bpress[sub][cond_alt])
    # Select runs to include according to run_dic, append
    # * include runs of rest 
    all_tims = all_tims + list(bpress_arr[run_dic[sub]['RE']])
    # how much to shift from button press onset
    
    ## create fake bpress for missing data if only one run ## 
    if len(all_tims) <2 and len(run_dic[sub]['RE']) >1:
        all_tims = list(all_tims[0], all_tims[0])
        
    return all_tims

# %%
def load_2conds_runs_fmri(sub,behav_p,cond_a,cond_b, run_dic, suffix="_205_noproc.npy"):
    """
    read in target conditions + subject info
    output: 2 runs of condition A, as they were presented, then two runs of condition B
    """
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True)) 
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    a, b = org_bdata(cats, lab_indic, cond_a, cond_b)
    # Get the indices of the runs to include #
    return list(a[run_dic[sub][cond_a]]), list(b[run_dic[sub][cond_b]])

# %%
def load_1cond_runs_fmri(sub,behav_p,cond_a, cond_b, run_dic, targ_run, suffix="_205_noproc.npy"):
    """
    read in target conditions + subject info
    output: 2 runs of condition A, as they were presented, then two runs of condition B
    """
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    a, b = org_bdata(cats, lab_indic, cond_a, cond_b)
    # Get the indices of the runs to include #
    return list(a[run_dic[sub][cond_a]])

# %% [markdown]
# # Define Static VARS

# %%
####
data_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/bids/derivatives/fmriprep/"
#rois_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/work/rois/"
rois_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/work/rois/results_masks/masks_mvpa"
behav_p = '/jukebox/graziano/coolCatIsaac/ATM/data/behavioral'
load_bpress = "/jukebox/graziano/coolCatIsaac/ATM/data/work/results/bpress_GLM/behav"
load_fmri = "/jukebox/graziano/coolCatIsaac/ATM/data/work/results/bpress_GLM/"
confounds = '/jukebox/graziano/coolCatIsaac/ATM/data/bids/derivatives/fmriprep/afni-head_mot/'
confounds_dir = '/jukebox/graziano/coolCatIsaac/ATM/data/work/workspace/censor_hm/'

# load whole brain mask
int_mask = nib.load('/jukebox/graziano/coolCatIsaac/ATM/data/work/workspace/load_fcma/mask_10r_n22-subs.nii.gz')

# %% [markdown]
# # dynamic vars

# %%
## sublist for rest ##
"""
no 5,8, 19, 26, 12
sub-005
 - 
sub-008

sub-019
- 
sub-012
- index range issue -- definitely due to the NO selection of runs for fMRI data -- we
select runs to be included for bpress data but not fMRI data -- need to edit
"""

### Rest Subs ### 
sub_list = ["sub-000", "sub-001","sub-002","sub-003","sub-004","sub-006","sub-007",
            "sub-009","sub-010","sub-011","sub-013","sub-014","sub-015", "sub-016","sub-017", 
            "sub-018","sub-020", "sub-021", "sub-022","sub-023","sub-024","sub-025","sub-027"]
## bad subs that do not work for rest ## 
sub_list = ["sub-000", "sub-001","sub-002","sub-003","sub-004",'sub-005', "sub-006","sub-007",'sub-008',
            "sub-009","sub-010","sub-011",'sub-012',"sub-013","sub-014","sub-015", "sub-016","sub-017", 
            "sub-018",'sub-019',"sub-020", "sub-021", "sub-022","sub-023","sub-024","sub-025", "sub-026","sub-027"]


## What threshold of head motion to extract ## 
hm_thresh = str(3)

## cluster coordinates to be extracted 
# coords = [(51,-42,44)]

# %%
len(sub_list)
# Out:
# 28

# %% [markdown]
# # bpress data

# %%
## Bpress behavioral data -- overlap removed ##
bpress = dict(enumerate(np.load(os.path.join(load_bpress, "n28_4_conds_ts_press_ovrlpREMOV.npy"), 
                                allow_pickle=True).flatten(),1))[1]

# %%
### runs to exclude with head motion accounted for and missing bpress runs deleted
run_dic = dict(enumerate(np.load(os.path.join(confounds_dir, "n28_runs_2_include_removNoBpress_delHMruns_threshp%s.npy") %(hm_thresh), 
                                allow_pickle=True).flatten(),1))[1]

# %% [markdown]
# # Confounds

# %%
conf_sub = dict(enumerate(np.load(os.path.join(confounds_dir, 'n28_conf+cens_MERGE_removNoBpress_delHMruns_threshp%s_glm.npy')%(hm_thresh), 
                                          allow_pickle = True).flatten(),1))[1]

# %% [markdown]
# # Create rest button presses

# %%
"""
for sub in sub_list:
    print(sub)
    temp = []
    events_b = create_event_list_rest(sub, bpress, "RE",cond_a,run_dic,base_onset,comp_onset_list,stim_dur)
    for runs in range(len(run_dic[sub]['RE'])):
        temp.append(events_b[runs])   
    bpress.setdefault(sub, {}).setdefault('RE',temp)
"""
# Out:
# '\nfor sub in sub_list:\n    print(sub)\n    temp = []\n    events_b = create_event_list_rest(sub, bpress, "RE",cond_a,run_dic,base_onset,comp_onset_list,stim_dur)\n    for runs in range(len(run_dic[sub][\'RE\'])):\n        temp.append(events_b[runs])   \n    bpress.setdefault(sub, {}).setdefault(\'RE\',temp)\n'

# %% [markdown]
# # ROI Info

# %%
"""
# sublist is set up top
# sub_list = ['sub-001']

# load in target ROI
# roi = ["l_prim_motor_sm_win2_mask"]
# roi = ["dmPFC_ovlp_mask"]
# roi = ["rTPJ_mask"]

roi = ["l_prim_motor_sm_win2_mask"]
tr = 1.5
high_pass = 1/128
roi_mask = load_roi_mask(roi[0], "MNI")

# REGRESS CONFOUNDS 
##** standardize = False ??? # 


masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                     standardize=True, detrend=True, high_pass=high_pass,
                    t_r=tr)
"""
# Out:
# '\n# sublist is set up top\n# sub_list = [\'sub-001\']\n\n# load in target ROI\n# roi = ["l_prim_motor_sm_win2_mask"]\n# roi = ["dmPFC_ovlp_mask"]\n# roi = ["rTPJ_mask"]\n\nroi = ["l_prim_motor_sm_win2_mask"]\ntr = 1.5\nhigh_pass = 1/128\nroi_mask = load_roi_mask(roi[0], "MNI")\n\n# REGRESS CONFOUNDS \n##** standardize = False ??? # \n\n\nmasker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,\n                     standardize=True, detrend=True, high_pass=high_pass,\n                    t_r=tr)\n'

# %% [markdown]
# # Define main function

# %%
def get_activations(sub_list, roi, roi_voxels, tr_range, cond_list):
    """
    Purpose:
        - extract activations from each ROI at each window, average two TRs within window
    Inputs:
        - sub_list: list of subs to iterate through
        - roi: which roi to extract activations 
        - roi_voxels: number of voxels for the selected ROI
        - tr_range: how many TRs should be averaged over?
        - cond_list: Which two conditions are we comparing
    Outputs:
        - X: Activations for every button press across subs for a given window 
        - Y: array of integers describing if button press is cond a (0) or cond b (1)
        - Groups: array of integers denoting button presses for each sub
    """
    # load in target ROI
    roi = roi
    high_pass = 1/128
    roi_mask = load_roi_mask(roi[0], "MNI")

    # Create masker object and REGRESS CONFOUNDS 
    masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                         standardize=True, detrend=True, high_pass=high_pass,t_r=1.5)

    ## X variable corresponds to a matrix that is: roi voxels x 
    X = np.empty((0, roi_voxels))
    ## Set subject array ## 
    group_id = 0
    groups = np.array([])
    ## set array for labels ## 
    y = np.array([])

    for sub in sub_list:
        ## Which conditions? ## 
        cond_a = cond_list[0]
        cond_b = cond_list[1]

        print(sub)
        # LOAD RUNS FOR COND A AND COND B
        fmri_imgs = load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask)
        # for each condition, extract patterns for each TR and average
        for sing_cond in cond_list:
            # for each run in available run dictionairy
            for run in range(len(run_dic[sub][sing_cond])):
                temp_run = []
                print("condition: ", sing_cond)
                #temp_pred = []
                print("run", run)

                # Fit the masker object to extract a 2d matrix: voxels x TR [454, 205]
                print("sub: ", sub)
                roi_act = masker.fit_transform(fmri_imgs[sing_cond][run], confounds = conf_sub[sub][sing_cond][run])
                print(roi_act.shape)


                # extract BPRESS behavioral data # 
                linez = bpress[sub][sing_cond][run]
                print("button press TRS:", linez)

                # Average activations 
                avg_activations = []
                
                # For each TR #
                for tr in linez:
                    # Find the tr that each onset occured - convert from seconds to TR
                    print(tr)
                    tr = round(tr/1.5)
                    print(tr)
                    temp = []
                    for i in tr_range:
                        try:
                            # IF tr exists in the range of TRs add to temp array before averaging in the next step
                            temp.append(roi_act[tr+i])
                        except:
                            continue
                    print("temp length: ", len(temp))
                    # If TRs exist for this button press, add it to the array # 
                    if (len(temp) > 0):
                        X = np.vstack((X, np.mean(temp, axis=0)))
                        print("X: ", X.shape)
                        groups = np.append(groups, group_id)
                        # note that I changed this to cond_a, cond_b
                        if (sing_cond == cond_a):
                            y = np.append(y, 0)

                        elif (sing_cond == cond_b):
                            y = np.append(y, 1)


        group_id = group_id + 1
    
    return X, y, groups

# %%
def get_activations_spacenorm(sub_list, roi, roi_voxels, tr_range, cond_list):
    """
    Purpose:
        - extract activations from each ROI at each window, average two TRs within window
        - ** only difference from above is we changed standardize to false **
    Inputs:
        - sub_list: list of subs to iterate through
        - roi: which roi to extract activations 
        - roi_voxels: number of voxels for the selected ROI
        - tr_range: how many TRs should be averaged over?
        - cond_list: Which two conditions are we comparing
    Outputs:
        - X: Activations for every button press across subs for a given window 
        - Y: array of integers describing if button press is cond a (0) or cond b (1)
        - Groups: array of integers denoting button presses for each sub
    """
    # load in target ROI
    high_pass = 1/128
    roi_mask = roi

    # Create masker object and REGRESS CONFOUNDS 
    masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                         standardize=False, detrend=True, high_pass=high_pass,t_r=1.5)

    ## X variable corresponds to a matrix that is: roi voxels x 
    X = np.empty((0, roi_voxels))
    ## Set subject array ## 
    group_id = 0
    groups = np.array([])
    ## set array for labels ## 
    y = np.array([])

    for sub in sub_list:
        ## Which conditions? ## 
        cond_a = cond_list[0]
        cond_b = cond_list[1]

        print(sub)
        # LOAD RUNS FOR COND A AND COND B
        fmri_imgs = load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask)
        # for each condition, extract patterns for each TR and average
        for sing_cond in cond_list:
            # for each run in available run dictionairy
            for run in range(len(run_dic[sub][sing_cond])):
                temp_run = []
                print("condition: ", sing_cond)
                #temp_pred = []
                print("run", run)

                # Fit the masker object to extract a 2d matrix: voxels x TR [454, 205]
                print("sub: ", sub)
                roi_act = masker.fit_transform(fmri_imgs[sing_cond][run], confounds = conf_sub[sub][sing_cond][run])
                print(roi_act.shape)


                # extract BPRESS behavioral data # 
                linez = bpress[sub][sing_cond][run]
                print("button press TRS:", linez)

                # Average activations 
                avg_activations = []
                
                # For each TR #
                for tr in linez:
                    # Find the tr that each onset occured - convert from seconds to TR
                    print(tr)
                    tr = round(tr/1.5)
                    print(tr)
                    temp = []
                    for i in tr_range:
                        try:
                            # IF tr exists in the range of TRs add to temp array before averaging in the next step
                            temp.append(roi_act[tr+i])
                        except:
                            continue
                    print("temp length: ", len(temp))
                    # If TRs exist for this button press, add it to the array # 
                    if (len(temp) > 0):
                        X = np.vstack((X, np.mean(temp, axis=0)))
                        print("X: ", X.shape)
                        groups = np.append(groups, group_id)
                        # note that I changed this to cond_a, cond_b
                        if (sing_cond == cond_a):
                            y = np.append(y, 0)

                        elif (sing_cond == cond_b):
                            y = np.append(y, 1)


        group_id = group_id + 1
    
    return X, y, groups

# %% [markdown]
# # begin

# %%
"""
DATA:
 - ALL_roi_activations_n28_spacenorm_2023-06-1.npy: This is activation for ALL ROIS from the schaefer atlas,copied from
     the *all* roi activations located in the searchlight folder 
 - roi_activations_n28_2023-05-14.npy : i think this is temporal norm but don't quote me
 - roi_activations_n28_spacenorm_2023-05-24.npy: spatial normalized data for two (maybe three? ) target ROIs. 
     does NOT account for the window shift [in old analysis we were off by one]
 - roi_activations_newWin_n28_spacenorm_2023-05-24.npy: *used in FINAL ANALYSIS* spatial normed with the following 
     window sizes: tr_range_dict = {'1' : np.array([-3,-4]), '2' : np.array([-1,-2]), '3' : np.array([0,1]), 
                 '4' : np.array([2,3]), '5' : np.array([4,5]), '6' : np.array([6,7]), 
                '7' : np.array([8,9]), '8' : np.array([10,11])}
  - ^^^ not sure what used in final analysis means. According to the 'final' directory, these were the window sizes used:
  tr_range_dict = {'1' : np.array([-2,-3]), '2' : np.array([0,-1]), '3' : np.array([1,2]), 
                 '4' : np.array([3,4]), '5' : np.array([5,6]), '6' : np.array([7,8]), 
                '7' : np.array([9,10]), '8' : np.array([11,12])}    

"""
# Out:
# "\nDATA:\n - ALL_roi_activations_n28_spacenorm_2023-06-1.npy: This is activation for ALL ROIS from the schaefer atlas,copied from\n     the *all* roi activations located in the searchlight folder \n - roi_activations_n28_2023-05-14.npy : i think this is temporal norm but don't quote me\n - roi_activations_n28_spacenorm_2023-05-24.npy: spatial normalized data for two (maybe three? ) target ROIs. \n     does NOT account for the window shift [in old analysis we were off by one]\n - roi_activations_newWin_n28_spacenorm_2023-05-24.npy: *used in FINAL ANALYSIS* spatial normed with the following \n     window sizes: tr_range_dict = {'1' : np.array([-3,-4]), '2' : np.array([-1,-2]), '3' : np.array([0,1]), \n                 '4' : np.array([2,3]), '5' : np.array([4,5]), '6' : np.array([6,7]), \n                '7' : np.array([8,9]), '8' : np.array([10,11])}\n    \n\n"

# %%
# Top Directory
top_dir = '/jukebox/graziano/coolCatIsaac/ATM/code/analysis/MVPA/searchlight'
act_dir = top_dir + '/activations'
perm_dir = top_dir +'/permutations'


perm_results = perm_dir + '/perm_results'
parc_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/work/rois/schaef_par/MNI/"
load_work = "/jukebox/graziano/coolCatIsaac/ATM/data/work/results/corr_data/"

# %%
### Set RoI ## 
#roi_dict = {'motor': ["l_prim_motor_sm_win2_mask"], 'dmPFC': ["dmPFC_ovlp_mask"], 'rTPJ': ["rTPJ_mask"]}

cond_list = [['SM', 'SC'], ['OM', 'OC']]
cond_list = [['OM', 'OC']]

tr_range_dict = {'1' : np.array([-3,-4]), '2' : np.array([-1,-2]), '3' : np.array([1,2]), 
                 '4' : np.array([3,4]), '5' : np.array([5,6]), '6' : np.array([7,8]), 
                '7' : np.array([9,10]), '8' : np.array([11,12])}

tr_range_dict = {'1' : np.array([-3,-4]), '2' : np.array([-1,-2]), '3' : np.array([0,1]), 
                 '4' : np.array([2,3]), '5' : np.array([4,5]), '6' : np.array([6,7]), 
                '7' : np.array([8,9]), '8' : np.array([10,11])}

"""
tr_range_dict = {'6' : np.array([7,8]), 
                '7' : np.array([9,10]), '8' : np.array([11,12])}
"""

## used in searchligh analysis -- i think? but i'm really not sure...
tr_range_dict = {'1' : np.array([-3,-4]), '2' : np.array([-1,-2]), '3' : np.array([0,1]), 
                 '4' : np.array([2,3]), '5' : np.array([4,5]), '6' : np.array([6,7]), 
                '7' : np.array([8,9]), '8' : np.array([10,11])}

## used in 'final' folder analysis ## 
tr_range_dict = {'1' : np.array([-2,-3]), '2' : np.array([0,-1]), '3' : np.array([1,2]), 
                 '4' : np.array([3,4]), '5' : np.array([5,6]), '6' : np.array([7,8]), 
                '7' : np.array([9,10]), '8' : np.array([11,12])}


### Save Vars ## 
date = '2023-06-1'
## activation dic ## 
act_dict_name = f'ALL_roi_activations_n28_spacenorm_{date}'

#perm_dict_name = f'perm_results_{date}_slurmy'

#load activation dictionary
activations = np.load(os.path.join(act_dir, '%s.npy') %(act_dict_name ), allow_pickle=True).item()

# %% [markdown]
# ## get current atlas info

# %%
dataset = datasets.fetch_atlas_schaefer_2018(n_rois=200)
atlas_filename = dataset.maps
labels = dataset.labels

print(f"Atlas ROIs are located in nifti image (4D) at: {atlas_filename}")
# Out:
# Atlas ROIs are located in nifti image (4D) at: /usr/people/isaacrc/nilearn_data/schaefer_2018/Schaefer2018_200Parcels_7Networks_order_FSLMNI152_1mm.nii.gz

# %%
# set path to atlas #
schaef = "Schaefer2018_200Parcels_7Networks_order_FSLMNI152_2mm.nii.gz"
#schaef = "Schaefer2018_400Parcels_7Networks_order_FSLMNI152_2mm.nii.gz"

# %%
## which ROI?
roi_num_one = 92

# %% [markdown]
# # Load in and resample ROI

# %%
# Load  sample data for resampling
concat = list(np.load(load_work + 'sub-007' +"_fwm7_mni_norm.npy", allow_pickle = True))
resamp_run = concat[0]
# Load parcellation
#d = nib.load(os.path.join(parc_dir + "Schaefer2018_200Parcels_17Networks_order_FSLMNI152_2mm.nii.gz"))
d = nib.load(os.path.join(parc_dir + schaef))
d_resamp = resample_to_img(d, resamp_run, interpolation='nearest')
# Get parcellation fdata
aparc = d_resamp.get_fdata()
# paracellations scheme
print(f'count parc:{len(np.unique(d_resamp.get_fdata()))}')
print("shape of d object", d_resamp.shape)
# Out:
# count parc:201
# shape of d object (78, 93, 65)

# %%
# View ROI # 

roi_num = roi_num_one
print("Begin Parc", roi_num)
# How many voxels for this ROI? #
num_voxels = np.sum(aparc == roi_num)
print("num voxels in one parcel:", num_voxels)
# Create an empty that is the shape of d
roi_tem = np.zeros(d_resamp.shape)
# set all cases where parcel is equal to roi_num, equal to one, everything else zero (creates a mask)
roi_tem[aparc == roi_num] = 1
# Create a nift image of the mask
roi_img = nib.Nifti1Image(roi_tem, affine = d_resamp.affine, header = d_resamp.header)
### set ROI_name #
roi_name = labels[roi_num][10:].decode("utf-8")
#nib.save(roi_img, rois_dir+'/'+ roi_name,)

plot_roi(roi_img)
# Out:
# Begin Parc 92
# num voxels in one parcel: 296

# %% [markdown]
# # run analysis

# %%
for roi_num in range(roi_num_one, roi_num_one+1):
    print("Begin Parc", roi_num)
    # How many voxels for this ROI? #
    num_voxels = np.sum(aparc == roi_num)
    print("num voxels in one parcel:", num_voxels)
    # Create an empty that is the shape of d
    roi_tem = np.zeros(d_resamp.shape)
    # set all cases where parcel is equal to roi_num, equal to one, everything else zero (creates a mask)
    roi_tem[aparc == roi_num] = 1
    # Create a nift image of the mask
    roi_img = nib.Nifti1Image(roi_tem, affine = d_resamp.affine, header = d_resamp.header)
    ### set ROI_name #
    roi_name = labels[roi_num][10:].decode("utf-8")
    print(roi_name)
    for conds in cond_list:
            print(conds)
            for window in tr_range_dict:
                print(f'window {window}')
                # Get activations ---- norm by space or time ? --- #
                X, y, g = get_activations_spacenorm(sub_list, roi_img, roi_voxels = num_voxels, 
                                          tr_range = tr_range_dict[window], cond_list = conds)
                ##### NORMALIZE ACROSS VOX ####
                X = zscore(X, axis = 1)
                ###
                print(X.shape)
                print(y.shape)
                print(g.shape)

                print('now save')
                # set analysis # 
                analysis = '%s_%s_%s_win%s' %(conds[0], conds[1], roi_name, window)
                # Save act dic ## 
                if os.path.isfile(os.path.join(act_dir, '%s.npy') %(act_dict_name)):
                    print('exists!')
                    activations = np.load(os.path.join(act_dir, '%s.npy') %(act_dict_name ), allow_pickle=True).item()
                else:
                    activations = {}
                    print('creating dic')
                d2 = {"X": X, "y": y, "groups":g}
                activations[analysis] = d2
                np.save(os.path.join(act_dir, '%s.npy') %(act_dict_name), activations)
# Out:
# Begin Parc 92
# num voxels in one parcel: 296
# LH_Default_PFC_11
# ['OM', 'OC']
# window 6
# sub-000
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-000
# (205, 296)
# button press TRS: [ 26.15  44.63  71.6   92.68 110.85 143.25 203.31 234.51 251.08 269.36
#  286.63 296.68]
# 26.15
# 17
# temp length:  2
# X:  (1, 296)
# 44.63
# 30
# temp length:  2
# X:  (2, 296)
# 71.6
# 48
# temp length:  2
# X:  (3, 296)
# 92.68
# 62
# temp length:  2
# X:  (4, 296)
# 110.85
# 74
# temp length:  2
# X:  (5, 296)
# 143.25
# 96
# temp length:  2
# X:  (6, 296)
# 203.31
# 136
# temp length:  2
# X:  (7, 296)
# 234.51
# 156
# temp length:  2
# X:  (8, 296)
# 251.08
# 167
# temp length:  2
# X:  (9, 296)
# 269.36
# 180
# temp length:  2
# X:  (10, 296)
# 286.63
# 191
# temp length:  2
# X:  (11, 296)
# 296.68
# 198
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-000
# (205, 296)
# button press TRS: [ 24.08  47.63  71.26  93.88 116.83 141.44 166.61 188.43 210.33 231.93
#  255.94 288.24]
# 24.08
# 16
# temp length:  2
# X:  (12, 296)
# 47.63
# 32
# temp length:  2
# X:  (13, 296)
# 71.26
# 48
# temp length:  2
# X:  (14, 296)
# 93.88
# 63
# temp length:  2
# X:  (15, 296)
# 116.83
# 78
# temp length:  2
# X:  (16, 296)
# 141.44
# 94
# temp length:  2
# X:  (17, 296)
# 166.61
# 111
# temp length:  2
# X:  (18, 296)
# 188.43
# 126
# temp length:  2
# X:  (19, 296)
# 210.33
# 140
# temp length:  2
# X:  (20, 296)
# 231.93
# 155
# temp length:  2
# X:  (21, 296)
# 255.94
# 171
# temp length:  2
# X:  (22, 296)
# 288.24
# 192
# temp length:  2
# X:  (23, 296)
# sub-001
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-001
# (205, 296)
# button press TRS: [ 13.35  39.75  75.18  85.   112.55 155.96 188.75 200.98 221.06 238.51]
# 13.35
# 9
# temp length:  2
# X:  (24, 296)
# 39.75
# 26
# temp length:  2
# X:  (25, 296)
# 75.18
# 50
# temp length:  2
# X:  (26, 296)
# 85.0
# 57
# temp length:  2
# X:  (27, 296)
# 112.55
# 75
# temp length:  2
# X:  (28, 296)
# 155.96
# 104
# temp length:  2
# X:  (29, 296)
# 188.75
# 126
# temp length:  2
# X:  (30, 296)
# 200.98
# 134
# temp length:  2
# X:  (31, 296)
# 221.06
# 147
# temp length:  2
# X:  (32, 296)
# 238.51
# 159
# temp length:  2
# X:  (33, 296)
# condition:  OM
# run 1
# sub:  sub-001
# (205, 296)
# button press TRS: [ 34.31  80.84 101.98 112.46 153.61 203.79 234.54 269.91 287.09 294.51]
# 34.31
# 23
# temp length:  2
# X:  (34, 296)
# 80.84
# 54
# temp length:  2
# X:  (35, 296)
# 101.98
# 68
# temp length:  2
# X:  (36, 296)
# 112.46
# 75
# temp length:  2
# X:  (37, 296)
# 153.61
# 102
# temp length:  2
# X:  (38, 296)
# 203.79
# 136
# temp length:  2
# X:  (39, 296)
# 234.54
# 156
# temp length:  2
# X:  (40, 296)
# 269.91
# 180
# temp length:  2
# X:  (41, 296)
# 287.09
# 191
# temp length:  2
# X:  (42, 296)
# 294.51
# 196
# temp length:  2
# X:  (43, 296)
# condition:  OC
# run 0
# sub:  sub-001
# (205, 296)
# button press TRS: [ 18.3   40.1   62.01  82.81 104.95 125.63 148.23 170.01 193.55 223.03
#  244.19 273.39 304.86]
# 18.3
# 12
# temp length:  2
# X:  (44, 296)
# 40.1
# 27
# temp length:  2
# X:  (45, 296)
# 62.01
# 41
# temp length:  2
# X:  (46, 296)
# 82.81
# 55
# temp length:  2
# X:  (47, 296)
# 104.95
# 70
# temp length:  2
# X:  (48, 296)
# 125.63
# 84
# temp length:  2
# X:  (49, 296)
# 148.23
# 99
# temp length:  2
# X:  (50, 296)
# 170.01
# 113
# temp length:  2
# X:  (51, 296)
# 193.55
# 129
# temp length:  2
# X:  (52, 296)
# 223.03
# 149
# temp length:  2
# X:  (53, 296)
# 244.19
# 163
# temp length:  2
# X:  (54, 296)
# 273.39
# 182
# temp length:  2
# X:  (55, 296)
# 304.86
# 203
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-001
# (205, 296)
# button press TRS: [ 23.57  46.73  70.63  94.03 117.08 140.65 165.68 188.75 216.85 241.43
#  264.7  292.83]
# 23.57
# 16
# temp length:  2
# X:  (56, 296)
# 46.73
# 31
# temp length:  2
# X:  (57, 296)
# 70.63
# 47
# temp length:  2
# X:  (58, 296)
# 94.03
# 63
# temp length:  2
# X:  (59, 296)
# 117.08
# 78
# temp length:  2
# X:  (60, 296)
# 140.65
# 94
# temp length:  2
# X:  (61, 296)
# 165.68
# 110
# temp length:  2
# X:  (62, 296)
# 188.75
# 126
# temp length:  2
# X:  (63, 296)
# 216.85
# 145
# temp length:  2
# X:  (64, 296)
# 241.43
# 161
# temp length:  2
# X:  (65, 296)
# 264.7
# 176
# temp length:  2
# X:  (66, 296)
# 292.83
# 195
# temp length:  2
# X:  (67, 296)
# sub-002
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-002
# (205, 296)
# button press TRS: [ 11.6   34.5   54.95  63.65  75.36  85.25 108.6  127.61 153.3  182.78
#  204.91 241.06 268.71 287.38 298.76]
# 11.6
# 8
# temp length:  2
# X:  (68, 296)
# 34.5
# 23
# temp length:  2
# X:  (69, 296)
# 54.95
# 37
# temp length:  2
# X:  (70, 296)
# 63.65
# 42
# temp length:  2
# X:  (71, 296)
# 75.36
# 50
# temp length:  2
# X:  (72, 296)
# 85.25
# 57
# temp length:  2
# X:  (73, 296)
# 108.6
# 72
# temp length:  2
# X:  (74, 296)
# 127.61
# 85
# temp length:  2
# X:  (75, 296)
# 153.3
# 102
# temp length:  2
# X:  (76, 296)
# 182.78
# 122
# temp length:  2
# X:  (77, 296)
# 204.91
# 137
# temp length:  2
# X:  (78, 296)
# 241.06
# 161
# temp length:  2
# X:  (79, 296)
# 268.71
# 179
# temp length:  2
# X:  (80, 296)
# 287.38
# 192
# temp length:  2
# X:  (81, 296)
# 298.76
# 199
# temp length:  0
# condition:  OM
# run 1
# sub:  sub-002
# (205, 296)
# button press TRS: [ 43.67  55.93  74.08  87.17 113.45 132.8  157.9  183.08 213.27 237.82
#  277.06]
# 43.67
# 29
# temp length:  2
# X:  (82, 296)
# 55.93
# 37
# temp length:  2
# X:  (83, 296)
# 74.08
# 49
# temp length:  2
# X:  (84, 296)
# 87.17
# 58
# temp length:  2
# X:  (85, 296)
# 113.45
# 76
# temp length:  2
# X:  (86, 296)
# 132.8
# 89
# temp length:  2
# X:  (87, 296)
# 157.9
# 105
# temp length:  2
# X:  (88, 296)
# 183.08
# 122
# temp length:  2
# X:  (89, 296)
# 213.27
# 142
# temp length:  2
# X:  (90, 296)
# 237.82
# 159
# temp length:  2
# X:  (91, 296)
# 277.06
# 185
# temp length:  2
# X:  (92, 296)
# condition:  OC
# run 0
# sub:  sub-002
# (205, 296)
# button press TRS: [ 24.68  47.41  71.01  91.2  112.95 135.38 159.33 184.08 206.38 228.19
#  253.61 272.48 297.09]
# 24.68
# 16
# temp length:  2
# X:  (93, 296)
# 47.41
# 32
# temp length:  2
# X:  (94, 296)
# 71.01
# 47
# temp length:  2
# X:  (95, 296)
# 91.2
# 61
# temp length:  2
# X:  (96, 296)
# 112.95
# 75
# temp length:  2
# X:  (97, 296)
# 135.38
# 90
# temp length:  2
# X:  (98, 296)
# 159.33
# 106
# temp length:  2
# X:  (99, 296)
# 184.08
# 123
# temp length:  2
# X:  (100, 296)
# 206.38
# 138
# temp length:  2
# X:  (101, 296)
# 228.19
# 152
# temp length:  2
# X:  (102, 296)
# 253.61
# 169
# temp length:  2
# X:  (103, 296)
# 272.48
# 182
# temp length:  2
# X:  (104, 296)
# 297.09
# 198
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-002
# (205, 296)
# button press TRS: [ 22.12  45.12  66.02  85.48 113.67 134.03 154.22 177.93 201.17 220.88
#  239.72 266.38 287.33]
# 22.12
# 15
# temp length:  2
# X:  (105, 296)
# 45.12
# 30
# temp length:  2
# X:  (106, 296)
# 66.02
# 44
# temp length:  2
# X:  (107, 296)
# 85.48
# 57
# temp length:  2
# X:  (108, 296)
# 113.67
# 76
# temp length:  2
# X:  (109, 296)
# 134.03
# 89
# temp length:  2
# X:  (110, 296)
# 154.22
# 103
# temp length:  2
# X:  (111, 296)
# 177.93
# 119
# temp length:  2
# X:  (112, 296)
# 201.17
# 134
# temp length:  2
# X:  (113, 296)
# 220.88
# 147
# temp length:  2
# X:  (114, 296)
# 239.72
# 160
# temp length:  2
# X:  (115, 296)
# 266.38
# 178
# temp length:  2
# X:  (116, 296)
# 287.33
# 192
# temp length:  2
# X:  (117, 296)
# sub-003
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-003
# (205, 296)
# button press TRS: [ 34.74  69.27  83.   156.25 188.73 221.27]
# 34.74
# 23
# temp length:  2
# X:  (118, 296)
# 69.27
# 46
# temp length:  2
# X:  (119, 296)
# 83.0
# 55
# temp length:  2
# X:  (120, 296)
# 156.25
# 104
# temp length:  2
# X:  (121, 296)
# 188.73
# 126
# temp length:  2
# X:  (122, 296)
# 221.27
# 148
# temp length:  2
# X:  (123, 296)
# condition:  OM
# run 1
# sub:  sub-003
# (205, 296)
# button press TRS: [ 86.63  99.43 152.17 203.7  234.38 257.12 269.58 294.13]
# 86.63
# 58
# temp length:  2
# X:  (124, 296)
# 99.43
# 66
# temp length:  2
# X:  (125, 296)
# 152.17
# 101
# temp length:  2
# X:  (126, 296)
# 203.7
# 136
# temp length:  2
# X:  (127, 296)
# 234.38
# 156
# temp length:  2
# X:  (128, 296)
# 257.12
# 171
# temp length:  2
# X:  (129, 296)
# 269.58
# 180
# temp length:  2
# X:  (130, 296)
# 294.13
# 196
# temp length:  2
# X:  (131, 296)
# condition:  OC
# run 0
# sub:  sub-003
# (205, 296)
# button press TRS: [ 12.87  34.22  57.02  78.08 100.55 120.93 142.2  169.18 189.33 213.83
#  229.93 254.37 277.93]
# 12.87
# 9
# temp length:  2
# X:  (132, 296)
# 34.22
# 23
# temp length:  2
# X:  (133, 296)
# 57.02
# 38
# temp length:  2
# X:  (134, 296)
# 78.08
# 52
# temp length:  2
# X:  (135, 296)
# 100.55
# 67
# temp length:  2
# X:  (136, 296)
# 120.93
# 81
# temp length:  2
# X:  (137, 296)
# 142.2
# 95
# temp length:  2
# X:  (138, 296)
# 169.18
# 113
# temp length:  2
# X:  (139, 296)
# 189.33
# 126
# temp length:  2
# X:  (140, 296)
# 213.83
# 143
# temp length:  2
# X:  (141, 296)
# 229.93
# 153
# temp length:  2
# X:  (142, 296)
# 254.37
# 170
# temp length:  2
# X:  (143, 296)
# 277.93
# 185
# temp length:  2
# X:  (144, 296)
# condition:  OC
# run 1
# sub:  sub-003
# (205, 296)
# button press TRS: [ 23.18  46.6   71.34  93.72 116.43 140.6  165.58 188.45 210.5  231.34
#  255.58 276.58 305.5 ]
# 23.18
# 15
# temp length:  2
# X:  (145, 296)
# 46.6
# 31
# temp length:  2
# X:  (146, 296)
# 71.34
# 48
# temp length:  2
# X:  (147, 296)
# 93.72
# 62
# temp length:  2
# X:  (148, 296)
# 116.43
# 78
# temp length:  2
# X:  (149, 296)
# 140.6
# 94
# temp length:  2
# X:  (150, 296)
# 165.58
# 110
# temp length:  2
# X:  (151, 296)
# 188.45
# 126
# temp length:  2
# X:  (152, 296)
# 210.5
# 140
# temp length:  2
# X:  (153, 296)
# 231.34
# 154
# temp length:  2
# X:  (154, 296)
# 255.58
# 170
# temp length:  2
# X:  (155, 296)
# 276.58
# 184
# temp length:  2
# X:  (156, 296)
# 305.5
# 204
# temp length:  0
# sub-004
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-004
# (205, 296)
# button press TRS: [ 31.63  55.65  82.73 155.82 188.57 221.4  234.55]
# 31.63
# 21
# temp length:  2
# X:  (157, 296)
# 55.65
# 37
# temp length:  2
# X:  (158, 296)
# 82.73
# 55
# temp length:  2
# X:  (159, 296)
# 155.82
# 104
# temp length:  2
# X:  (160, 296)
# 188.57
# 126
# temp length:  2
# X:  (161, 296)
# 221.4
# 148
# temp length:  2
# X:  (162, 296)
# 234.55
# 156
# temp length:  2
# X:  (163, 296)
# condition:  OM
# run 1
# sub:  sub-004
# (205, 296)
# button press TRS: [ 81.32 111.03 129.3  153.58 234.48 269.8  299.16]
# 81.32
# 54
# temp length:  2
# X:  (164, 296)
# 111.03
# 74
# temp length:  2
# X:  (165, 296)
# 129.3
# 86
# temp length:  2
# X:  (166, 296)
# 153.58
# 102
# temp length:  2
# X:  (167, 296)
# 234.48
# 156
# temp length:  2
# X:  (168, 296)
# 269.8
# 180
# temp length:  2
# X:  (169, 296)
# 299.16
# 199
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-004
# (205, 296)
# button press TRS: [ 17.59  39.4   63.87  82.17  98.85 121.27 142.08 163.22 185.88 210.03
#  229.97 255.11 273.51 295.16]
# 17.59
# 12
# temp length:  2
# X:  (170, 296)
# 39.4
# 26
# temp length:  2
# X:  (171, 296)
# 63.87
# 43
# temp length:  2
# X:  (172, 296)
# 82.17
# 55
# temp length:  2
# X:  (173, 296)
# 98.85
# 66
# temp length:  2
# X:  (174, 296)
# 121.27
# 81
# temp length:  2
# X:  (175, 296)
# 142.08
# 95
# temp length:  2
# X:  (176, 296)
# 163.22
# 109
# temp length:  2
# X:  (177, 296)
# 185.88
# 124
# temp length:  2
# X:  (178, 296)
# 210.03
# 140
# temp length:  2
# X:  (179, 296)
# 229.97
# 153
# temp length:  2
# X:  (180, 296)
# 255.11
# 170
# temp length:  2
# X:  (181, 296)
# 273.51
# 182
# temp length:  2
# X:  (182, 296)
# 295.16
# 197
# temp length:  1
# X:  (183, 296)
# condition:  OC
# run 1
# sub:  sub-004
# (205, 296)
# button press TRS: [110.8  137.07 154.28 235.15 269.53 299.77]
# 110.8
# 74
# temp length:  2
# X:  (184, 296)
# 137.07
# 91
# temp length:  2
# X:  (185, 296)
# 154.28
# 103
# temp length:  2
# X:  (186, 296)
# 235.15
# 157
# temp length:  2
# X:  (187, 296)
# 269.53
# 180
# temp length:  2
# X:  (188, 296)
# 299.77
# 200
# temp length:  0
# sub-005
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub
#  241.26 264.15 294.4 ]
# 23.25
# 16
# temp length:  2
# X:  (317, 296)
# 41.1
# 27
# temp length:  2
# X:  (318, 296)
# 60.07
# 40
# temp length:  2
# X:  (319, 296)
# 79.67
# 53
# temp length:  2
# X:  (320, 296)
# 101.43
# 68
# temp length:  2
# X:  (321, 296)
# 120.52
# 80
# temp length:  2
# X:  (322, 296)
# 153.78
# 103
# temp length:  2
# X:  (323, 296)
# 179.0
# 119
# temp length:  2
# X:  (324, 296)
# 205.18
# 137
# temp length:  2
# X:  (325, 296)
# 222.56
# 148
# temp length:  2
# X:  (326, 296)
# 241.26
# 161
# temp length:  2
# X:  (327, 296)
# 264.15
# 176
# temp length:  2
# X:  (328, 296)
# 294.4
# 196
# temp length:  2
# X:  (329, 296)
# sub-007
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-007
# (205, 296)
# button press TRS: [ 40.25  55.37  68.    82.12 155.6  188.92 221.03 238.08]
# 40.25
# 27
# temp length:  2
# X:  (330, 296)
# 55.37
# 37
# temp length:  2
# X:  (331, 296)
# 68.0
# 45
# temp length:  2
# X:  (332, 296)
# 82.12
# 55
# temp length:  2
# X:  (333, 296)
# 155.6
# 104
# temp length:  2
# X:  (334, 296)
# 188.92
# 126
# temp length:  2
# X:  (335, 296)
# 221.03
# 147
# temp length:  2
# X:  (336, 296)
# 238.08
# 159
# temp length:  2
# X:  (337, 296)
# condition:  OM
# run 1
# sub:  sub-007
# (205, 296)
# button press TRS: [110.33 152.46 234.44 269.96 297.36]
# 110.33
# 74
# temp length:  2
# X:  (338, 296)
# 152.46
# 102
# temp length:  2
# X:  (339, 296)
# 234.44
# 156
# temp length:  2
# X:  (340, 296)
# 269.96
# 180
# temp length:  2
# X:  (341, 296)
# 297.36
# 198
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-007
# (205, 296)
# button press TRS: [ 17.83  40.12  61.68  81.7  103.6  125.85 147.63 176.81 209.7  259.36
#  286.31]
# 17.83
# 12
# temp length:  2
# X:  (342, 296)
# 40.12
# 27
# temp length:  2
# X:  (343, 296)
# 61.68
# 41
# temp length:  2
# X:  (344, 296)
# 81.7
# 54
# temp length:  2
# X:  (345, 296)
# 103.6
# 69
# temp length:  2
# X:  (346, 296)
# 125.85
# 84
# temp length:  2
# X:  (347, 296)
# 147.63
# 98
# temp length:  2
# X:  (348, 296)
# 176.81
# 118
# temp length:  2
# X:  (349, 296)
# 209.7
# 140
# temp length:  2
# X:  (350, 296)
# 259.36
# 173
# temp length:  2
# X:  (351, 296)
# 286.31
# 191
# temp length:  2
# X:  (352, 296)
# sub-008
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-008
# (205, 296)
# button press TRS: [ 20.71  39.52  57.6   77.93 109.82 131.37 153.68 180.51 222.8  252.15
#  276.93]
# 20.71
# 14
# temp length:  2
# X:  (353, 296)
# 39.52
# 26
# temp length:  2
# X:  (354, 296)
# 57.6
# 38
# temp length:  2
# X:  (355, 296)
# 77.93
# 52
# temp length:  2
# X:  (356, 296)
# 109.82
# 73
# temp length:  2
# X:  (357, 296)
# 131.37
# 88
# temp length:  2
# X:  (358, 296)
# 153.68
# 102
# temp length:  2
# X:  (359, 296)
# 180.51
# 120
# temp length:  2
# X:  (360, 296)
# 222.8
# 149
# temp length:  2
# X:  (361, 296)
# 252.15
# 168
# temp length:  2
# X:  (362, 296)
# 276.93
# 185
# temp length:  2
# X:  (363, 296)
# condition:  OM
# run 1
# sub:  sub-008
# (205, 296)
# button press TRS: [ 42.35  69.88 105.15 128.12 151.86 203.83 234.38 269.1  286.66 293.75
#  298.71]
# 42.35
# 28
# temp length:  2
# X:  (364, 296)
# 69.88
# 47
# temp length:  2
# X:  (365, 296)
# 105.15
# 70
# temp length:  2
# X:  (366, 296)
# 128.12
# 85
# temp length:  2
# X:  (367, 296)
# 151.86
# 101
# temp length:  2
# X:  (368, 296)
# 203.83
# 136
# temp length:  2
# X:  (369, 296)
# 234.38
# 156
# temp length:  2
# X:  (370, 296)
# 269.1
# 179
# temp length:  2
# X:  (371, 296)
# 286.66
# 191
# temp length:  2
# X:  (372, 296)
# 293.75
# 196
# temp length:  2
# X:  (373, 296)
# 298.71
# 199
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-008
# (205, 296)
# button press TRS: [ 19.22  39.17  63.72  90.59 117.   136.78 163.52 183.17 208.98 231.08
#  264.56 277.77]
# 19.22
# 13
# temp length:  2
# X:  (374, 296)
# 39.17
# 26
# temp length:  2
# X:  (375, 296)
# 63.72
# 42
# temp length:  2
# X:  (376, 296)
# 90.59
# 60
# temp length:  2
# X:  (377, 296)
# 117.0
# 78
# temp length:  2
# X:  (378, 296)
# 136.78
# 91
# temp length:  2
# X:  (379, 296)
# 163.52
# 109
# temp length:  2
# X:  (380, 296)
# 183.17
# 122
# temp length:  2
# X:  (381, 296)
# 208.98
# 139
# temp length:  2
# X:  (382, 296)
# 231.08
# 154
# temp length:  2
# X:  (383, 296)
# 264.56
# 176
# temp length:  2
# X:  (384, 296)
# 277.77
# 185
# temp length:  2
# X:  (385, 296)
# condition:  OC
# run 1
# sub:  sub-008
# (205, 296)
# button press TRS: [ 22.97  41.23  65.23  83.33 106.7  129.5  164.75 191.48 213.4  235.55
#  259.35 290.43]
# 22.97
# 15
# temp length:  2
# X:  (386, 296)
# 41.23
# 27
# temp length:  2
# X:  (387, 296)
# 65.23
# 43
# temp length:  2
# X:  (388, 296)
# 83.33
# 56
# temp length:  2
# X:  (389, 296)
# 106.7
# 71
# temp length:  2
# X:  (390, 296)
# 129.5
# 86
# temp length:  2
# X:  (391, 296)
# 164.75
# 110
# temp length:  2
# X:  (392, 296)
# 191.48
# 128
# temp length:  2
# X:  (393, 296)
# 213.4
# 142
# temp length:  2
# X:  (394, 296)
# 235.55
# 157
# temp length:  2
# X:  (395, 296)
# 259.35
# 173
# temp length:  2
# X:  (396, 296)
# 290.43
# 194
# temp length:  2
# X:  (397, 296)
# sub-009
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-009
# (205, 296)
# button press TRS: [209.78]
# 209.78
# 140
# temp length:  2
# X:  (398, 296)
# condition:  OM
# run 1
# sub:  sub-009
# (205, 296)
# button press TRS: [197.03]
# 197.03
# 131
# temp length:  2
# X:  (399, 296)
# condition:  OC
# run 0
# sub:  sub-009
# (205, 296)
# button press TRS: [ 17.75  39.31  62.36  77.5   98.88 113.43 133.94 174.74 193.18 212.58
#  240.68 269.13 291.73 307.24]
# 17.75
# 12
# temp length:  2
# X:  (400, 296)
# 39.31
# 26
# temp length:  2
# X:  (401, 296)
# 62.36
# 42
# temp length:  2
# X:  (402, 296)
# 77.5
# 52
# temp length:  2
# X:  (403, 296)
# 98.88
# 66
# temp length:  2
# X:  (404, 296)
# 113.43
# 76
# temp length:  2
# X:  (405, 296)
# 133.94
# 89
# temp length:  2
# X:  (406, 296)
# 174.74
# 116
# temp length:  2
# X:  (407, 296)
# 193.18
# 129
# temp length:  2
# X:  (408, 296)
# 212.58
# 142
# temp length:  2
# X:  (409, 296)
# 240.68
# 160
# temp length:  2
# X:  (410, 296)
# 269.13
# 179
# temp length:  2
# X:  (411, 296)
# 291.73
# 194
# temp length:  2
# X:  (412, 296)
# 307.24
# 205
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-009
# (205, 296)
# button press TRS: [ 19.14  41.43  66.61  84.53 107.01 131.11 150.39 179.26 201.29 231.38
#  264.46 299.22]
# 19.14
# 13
# temp length:  2
# X:  (413, 296)
# 41.43
# 28
# temp length:  2
# X:  (414, 296)
# 66.61
# 44
# temp length:  2
# X:  (415, 296)
# 84.53
# 56
# temp length:  2
# X:  (416, 296)
# 107.01
# 71
# temp length:  2
# X:  (417, 296)
# 131.11
# 87
# temp length:  2
# X:  (418, 296)
# 150.39
# 100
# temp length:  2
# X:  (419, 296)
# 179.26
# 120
# temp length:  2
# X:  (420, 296)
# 201.29
# 134
# temp length:  2
# X:  (421, 296)
# 231.38
# 154
# temp length:  2
# X:  (422, 296)
# 264.46
# 176
# temp length:  2
# X:  (423, 296)
# 299.22
# 199
# temp length:  0
# sub-010
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-010
# (205, 296)
# button press TRS: [ 40.43  55.02  83.15 100.43 113.6  127.   146.31 156.4  190.38 221.58
#  229.86 238.43 255.35 281.11]
# 40.43
# 27
# temp length:  2
# X:  (424, 296)
# 55.02
# 37
# temp length:  2
# X:  (425, 296)
# 83.15
# 55
# temp length:  2
# X:  (426, 296)
# 100.43
# 67
# temp length:  2
# X:  (427, 296)
# 113.6
# 76
# temp length:  2
# X:  (428, 296)
# 127.0
# 85
# temp length:  2
# X:  (429, 296)
# 146.31
# 98
# temp length:  2
# X:  (430, 296)
# 156.4
# 104
# temp length:  2
# X:  (431, 296)
# 190.38
# 127
# temp length:  2
# X:  (432, 296)
# 221.58
# 148
# temp length:  2
# X:  (433, 296)
# 229.86
# 153
# temp length:  2
# X:  (434, 296)
# 238.43
# 159
# temp length:  2
# X:  (435, 296)
# 255.35
# 170
# temp length:  2
# X:  (436, 296)
# 281.11
# 187
# temp length:  2
# X:  (437, 296)
# condition:  OC
# run 0
# sub:  sub-010
# (205, 296)
# button press TRS: [ 24.95 212.11 241.03 266.59 295.36]
# 24.95
# 17
# temp length:  2
# X:  (438, 296)
# 212.11
# 141
# temp length:  2
# X:  (439, 296)
# 241.03
# 161
# temp length:  2
# X:  (440, 296)
# 266.59
# 178
# temp length:  2
# X:  (441, 296)
# 295.36
# 197
# temp length:  1
# X:  (442, 296)
# condition:  OC
# run 1
# sub:  sub-010
# (205, 296)
# button press TRS: [ 23.89  71.6   88.52 106.37 144.83 166.53 188.85 268.07]
# 23.89
# 16
# temp length:  2
# X:  (443, 296)
# 71.6
# 48
# temp length:  2
# X:  (444, 296)
# 88.52
# 59
# temp length:  2
# X:  (445, 296)
# 106.37
# 71
# temp length:  2
# X:  (446, 296)
# 144.83
# 97
# temp length:  2
# X:  (447, 296)
# 166.53
# 111
# temp length:  2
# X:  (448, 296)
# 188.85
# 126
# temp length:  2
# X:  (449, 296)
# 268.07
# 179
# temp length:  2
# X:  (450, 296)
# sub-011
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-011
# (205, 296)
# button press TRS: [ 39.48  69.21  83.21 112.53 156.43 188.78 222.18 237.91]
# 39.48
# 26
# temp length:  2
# X:  (451, 296)
# 69.21
# 46
# temp length:  2
# X:  (452, 296)
# 83.21
# 55
# temp length:  2
# X:  (453, 296)
# 112.53
# 75
# temp length:  2
# X:  (454, 296)
# 156.43
# 104
# temp length:  2
# X:  (455, 296)
# 188.78
# 126
# temp length:  2
# X:  (456, 296)
# 222.18
# 148
# temp length:  2
# X:  (457, 296)
# 237.91
# 159
# temp length:  2
# X:  (458, 296)
# condition:  OM
# run 1
# sub:  sub-011
# (205, 296)
# button press TRS: [ 29.33  61.15 110.4  151.78 203.53 234.72 269.12 296.75]
# 29.33
# 20
# temp length:  2
# X:  (459, 296)
# 61.15
# 41
# temp length:  2
# X:  (460, 296)
# 110.4
# 74
# temp length:  2
# X:  (461, 296)
# 151.78
# 101
# temp length:  2
# X:  (462, 296)
# 203.53
# 136
# temp length:  2
# X:  (463, 296)
# 234.72
# 156
# temp length:  2
# X:  (464, 296)
# 269.12
# 179
# temp length:  2
# X:  (465, 296)
# 296.75
# 198
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-011
# (205, 296)
# button press TRS: [ 17.58  39.05  62.22  94.73 116.77 136.6  163.26 192.6  208.36 254.86
#  273.1  301.46]
# 17.58
# 12
# temp length:  2
# X:  (466, 296)
# 39.05
# 26
# temp length:  2
# X:  (467, 296)
# 62.22
# 41
# temp length:  2
# X:  (468, 296)
# 94.73
# 63
# temp length:  2
# X:  (469, 296)
# 116.77
# 78
# temp length:  2
# X:  (470, 296)
# 136.6
# 91
# temp length:  2
# X:  (471, 296)
# 163.26
# 109
# temp length:  2
# X:  (472, 296)
# 192.6
# 128
# temp length:  2
# X:  (473, 296)
# 208.36
# 139
# temp length:  2
# X:  (474, 296)
# 254.86
# 170
# temp length:  2
# X:  (475, 296)
# 273.1
# 182
# temp length:  2
# X:  (476, 296)
# 301.46
# 201
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-011
# (205, 296)
# button press TRS: [ 22.75  47.58  74.07 142.58 167.05 256.05]
# 22.75
# 15
# temp length:  2
# X:  (477, 296)
# 47.58
# 32
# temp length:  2
# X:  (478, 296)
# 74.07
# 49
# temp length:  2
# X:  (479, 296)
# 142.58
# 95
# temp length:  2
# X:  (480, 296)
# 167.05
# 111
# temp length:  2
# X:  (481, 296)
# 256.05
# 171
# temp length:  2
# X:  (482, 296)
# sub-012
# concatenated OM OC
# condition:  OC
# run 0
# sub:  sub-012
# (205, 296)
# button press TRS: [ 22.92  46.67  71.9   94.15 113.   134.15 162.12 184.37 206.7  226.72
#  250.55 272.83 294.2 ]
# 22.92
# 15
# temp length:  2
# X:  (483, 296)
# 46.67
# 31
# temp length:  2
# X:  (484, 296)
# 71.9
# 48
# temp length:  2
# X:  (485, 296)
# 94.15
# 63
# temp length:  2
# X:  (486, 296)
# 113.0
# 75
# temp length:  2
# X:  (487, 296)
# 134.15
# 89
# temp length:  2
# X:  (488, 296)
# 162.12
# 108
# temp length:  2
# X:  (489, 296)
# 184.37
# 123
# temp length:  2
# X:  (490, 296)
# 206.7
# 138
# temp length:  2
# X:  (491, 296)
# 226.72
# 151
# temp length:  2
# X:  (492, 296)
# 250.55
# 167
# temp length:  2
# X:  (493, 296)
# 272.83
# 182
# temp length:  2
# X:  (494, 296)
# 294.2
# 196
# temp length:  2
# X:  (495, 296)
# sub-013
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-013
# (205, 296)
# button press TRS: [ 44.74  71.2   85.25 111.15 145.77 156.8  203.32 234.48 269.9  286.55]
# 44.74
# 30
# temp length:  2
# X:  (496, 296)
# 71.2
# 47
# temp length:  2
# X:  (497, 296)
# 85.25
# 57
# temp length:  2
# X:  (498, 296)
# 111.15
# 74
# temp length:  2
# X:  (499, 296)
# 145.77
# 97
# temp length:  2
# X:  (500, 296)
# 156.8
# 105
# temp length:  2
# X:  (501, 296)
# 203.32
# 136
# temp length:  2
# X:  (502, 296)
# 234.48
# 156
# temp length:  2
# X:  (503, 296)
# 269.9
# 180
# temp length:  2
# X:  (504, 296)
# 286.55
# 191
# temp length:  2
# X:  (505, 296)
# condition:  OM
# run 1
# sub:  sub-013
# (205, 296)
# button press TRS: [ 39.62  55.12  67.75  81.81 156.95 174.73 188.7  221.24 238.13 262.3 ]
# 39.62
# 26
# temp length:  2
# X:  (506, 296)
# 55.12
# 37
# temp length:  2
# X:  (507, 296)
# 67.75
# 45
# temp length:  2
# X:  (508, 296)
# 81.81
# 55
# temp length:  2
# X:  (509, 296)
# 156.95
# 105
# temp length:  2
# X:  (510, 296)
# 174.73
# 116
# temp length:  2
# X:  (511, 296)
# 188.7
# 126
# temp length:  2
# X:  (512, 296)
# 221.24
# 147
# temp length:  2
# X:  (513, 296)
# 238.13
# 159
# temp length:  2
# X:  (514, 296)
# 262.3
# 175
# temp length:  2
# X:  (515, 296)
# condition:  OC
# run 0
# sub:  sub-013
# (205, 296)
# button press TRS: [ 23.65  46.95  70.5   93.37 116.2  140.78 165.73 188.02 210.95 231.68
#  255.18 277.23 304.47]
# 23.65
# 16
# temp length:  2
# X:  (516, 296)
# 46.95
# 31
# temp length:  2
# X:  (517, 296)
# 70.5
# 47
# temp length:  2
# X:  (518, 296)
# 93.37
# 62
# temp length:  2
# X:  (519, 296)
# 116.2
# 77
# temp length:  2
# X:  (520, 296)
# 140.78
# 94
# temp length:  2
# X:  (521, 296)
# 165.73
# 110
# temp length:  2
# X:  (522, 296)
# 188.02
# 125
# temp length:  2
# X:  (523, 296)
# 210.95
# 141
# temp length:  2
# X:  (524, 296)
# 231.68
# 154
# temp length:  2
# X:  (525, 296)
# 255.18
# 170
# temp length:  2
# X:  (526, 296)
# 277.23
# 185
# temp length:  2
# X:  (527, 296)
# 304.47
# 203
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-013
# (205, 296)
# button press TRS: [ 17.6   39.48  59.45  78.46 104.96 125.86 146.85 169.64 200.41 221.68
#  242.94 269.04 290.64]
# 17.6
# 12
# temp length:  2
# X:  (528, 296)
# 39.48
# 26
# temp length:  2
# X:  (529, 296)
# 59.45
# 40
# temp length:  2
# X:  (530, 296)
# 78.46
# 52
# temp length:  2
# X:  (531, 296)
# 104.96
# 70
# temp length:  2
# X:  (532, 296)
# 125.86
# 84
# temp length:  2
# X:  (533, 296)
# 146.85
# 98
# temp length:  2
# X:  (534, 296)
# 169.64
# 113
# temp length:  2
# X:  (535, 296)
# 200.41
# 134
# temp length:  2
# X:  (536, 296)
# 221.68
# 148
# temp length:  2
# X:  (537, 296)
# 242.94
# 162
# temp length:  2
# X:  (538, 296)
# 269.04
# 179
# temp length:  2
# X:  (539, 296)
# 290.64
# 194
# temp length:  2
# X:  (540, 296)
# sub-014
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-014
# (205, 296)
# button press TRS: [110.55 146.27 298.38]
# 110.55
# 74
# temp length:  2
# X:  (541, 296)
# 146.27
# 98
# temp length:  2
# X:  (542, 296)
# 298.38
# 199
# temp length:  0
# condition:  OM
# run 1
# sub:  sub-014
# (205, 296)
# button press TRS: [ 39.63  77.95 168.71 206.19 257.34]
# 39.63
# 26
# temp length:  2
# X:  (543, 296)
# 77.95
# 52
# temp length:  2
# X:  (544, 296)
# 168.71
# 112
# temp length:  2
# X:  (545, 296)
# 206.19
# 137
# temp length:  2
# X:  (546, 296)
# 257.34
# 172
# temp length:  2
# X:  (547, 296)
# condition:  OC
# run 0
# sub:  sub-014
# (205, 296)
# button press TRS: [ 23.41  46.28  92.93 115.76 139.99 160.33 183.08 205.9  227.78 250.48
#  270.53]
# 23.41
# 16
# temp length:  2
# X:  (548, 296)
# 46.28
# 31
# temp length:  2
# X:  (549, 296)
# 92.93
# 62
# temp length:  2
# X:  (550, 296)
# 115.76
# 77
# temp length:  2
# X:  (551, 296)
# 139.99
# 93
# temp length:  2
# X:  (552, 296)
# 160.33
# 107
# temp length:  2
# X:  (553, 296)
# 183.08
# 122
# temp length:  2
# X:  (554, 296)
# 205.9
# 137
# temp length:  2
# X:  (555, 296)
# 227.78
# 152
# temp length:  2
# X:  (556, 296)
# 250.48
# 167
# temp length:  2
# X:  (557, 296)
# 270.53
# 180
# temp length:  2
# X:  (558, 296)
# condition:  OC
# run 1
# sub:  sub-014
# (205, 296)
# button press TRS: [ 17.97  39.3   61.45  81.25 104.1  125.2  141.5  161.92 185.12 204.73
#  224.92 248.55 268.47 290.42]
# 17.97
# 12
# temp length:  2
# X:  (559, 296)
# 39.3
# 26
# temp length:  2
# X:  (560, 296)
# 61.45
# 41
# temp length:  2
# X:  (561, 296)
# 81.25
# 54
# temp length:  2
# X:  (562, 296)
# 104.1
# 69
# temp length:  2
# X:  (563, 296)
# 125.2
# 83
# temp length:  2
# X:  (564, 296)
# 141.5
# 94
# temp length:  2
# X:  (565, 296)
# 161.92
# 108
# temp length:  2
# X:  (566, 296)
# 185.12
# 123
# temp length:  2
# X:  (567, 296)
# 204.73
# 136
# temp length:  2
# X:  (568, 296)
# 224.92
# 150
# temp length:  2
# X:  (569, 296)
# 248.55
# 166
# temp length:  2
# X:  (570, 296)
# 268.47
# 179
# temp length:  2
# X:  (571, 296)
# 290.42
# 194
# temp length:  2
# X:  (572, 296)
# sub-015
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-015
# (205, 296)
# button press TRS: [ 40.08  74.33 155.65 188.75 221.18 238.53]
# 40.08
# 27
# temp length:  2
# X:  (573, 296)
# 74.33
# 50
# temp length:  2
# X:  (574, 296)
# 155.65
# 104
# temp length:  2
# X:  (575, 296)
# 188.75
# 126
# temp length:  2
# X:  (576, 296)
# 221.18
# 147
# temp length:  2
# X:  (577, 296)
# 238.53
# 159
# temp length:  2
# X:  (578, 296)
# condition:  OM
# run 1
# sub:  sub-015
# (205, 296)
# button press TRS: [110.37 126.98 151.97 234.73 256.33 269.98 286.93 296.68]
# 110.37
# 74
# temp length:  2
# X:  (579, 296)
# 126.98
# 85
# temp length:  2
# X:  (580, 296)
# 151.97
# 101
# temp length:  2
# X:  (581, 296)
# 234.73
# 156
# temp length:  2
# X:  (582, 296)
# 256.33
# 171
# temp length:  2
# X:  (583, 296)
# 269.98
# 180
# temp length:  2
# X:  (584, 296)
# 286.93
# 191
# temp length:  2
# X:  (585, 296)
# 296.68
# 198
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-015
# (205, 296)
# button press TRS: [ 17.92  39.2   62.48  81.95 104.35 125.65 146.7  175.67 193.45 215.36
#  234.97 265.28 287.06 305.03]
# 17.92
# 12
# temp length:  2
# X:  (586, 296)
# 39.2
# 26
# temp length:  2
# X:  (587, 296)
# 62.48
# 42
# temp length:  2
# X:  (588, 296)
# 81.95
# 55
# temp length:  2
# X:  (589, 296)
# 104.35
# 70
# temp length:  2
# X:  (590, 296)
# 125.65
# 84
# temp length:  2
# X:  (591, 296)
# 146.7
# 98
# temp length:  2
# X:  (592, 296)
# 175.67
# 117
# temp length:  2
# X:  (593, 296)
# 193.45
# 129
# temp length:  2
# X:  (594, 296)
# 215.36
# 144
# temp length:  2
# X:  (595, 296)
# 234.97
# 157
# temp length:  2
# X:  (596, 296)
# 265.28
# 177
# temp length:  2
# X:  (597, 296)
# 287.06
# 191
# temp length:  2
# X:  (598, 296)
# 305.03
# 203
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-015
# (205, 296)
# button press TRS: [ 23.85  46.83  70.63  93.03 116.28 140.57 165.31 187.82 210.23 231.48
#  254.13 277.11 304.95]
# 23.85
# 16
# temp length:  2
# X:  (599, 296)
# 46.83
# 31
# temp length:  2
# X:  (600, 296)
# 70.63
# 47
# temp length:  2
# X:  (601, 296)
# 93.03
# 62
# temp length:  2
# X:  (602, 296)
# 116.28
# 78
# temp length:  2
# X:  (603, 296)
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-017
# (205, 296)
# button press TRS: [ 47.35  78.08 156.73 182.89 265.09 284.36]
# 47.35
# 32
# temp length:  2
# X:  (648, 296)
# 78.08
# 52
# temp length:  2
# X:  (649, 296)
# 156.73
# 104
# temp length:  2
# X:  (650, 296)
# 182.89
# 122
# temp length:  2
# X:  (651, 296)
# 265.09
# 177
# temp length:  2
# X:  (652, 296)
# 284.36
# 190
# temp length:  2
# X:  (653, 296)
# condition:  OM
# run 1
# sub:  sub-017
# (205, 296)
# button press TRS: [ 37.    62.05 111.8  148.45 175.92 213.72 237.67 254.32 289.91]
# 37.0
# 25
# temp length:  2
# X:  (654, 296)
# 62.05
# 41
# temp length:  2
# X:  (655, 296)
# 111.8
# 75
# temp length:  2
# X:  (656, 296)
# 148.45
# 99
# temp length:  2
# X:  (657, 296)
# 175.92
# 117
# temp length:  2
# X:  (658, 296)
# 213.72
# 142
# temp length:  2
# X:  (659, 296)
# 237.67
# 158
# temp length:  2
# X:  (660, 296)
# 254.32
# 170
# temp length:  2
# X:  (661, 296)
# 289.91
# 193
# temp length:  2
# X:  (662, 296)
# condition:  OC
# run 0
# sub:  sub-017
# (205, 296)
# button press TRS: [ 21.67  44.77  66.15  86.58 109.45 130.22 150.92 179.03 196.78 218.25
#  239.93 265.33 291.48]
# 21.67
# 14
# temp length:  2
# X:  (663, 296)
# 44.77
# 30
# temp length:  2
# X:  (664, 296)
# 66.15
# 44
# temp length:  2
# X:  (665, 296)
# 86.58
# 58
# temp length:  2
# X:  (666, 296)
# 109.45
# 73
# temp length:  2
# X:  (667, 296)
# 130.22
# 87
# temp length:  2
# X:  (668, 296)
# 150.92
# 101
# temp length:  2
# X:  (669, 296)
# 179.03
# 119
# temp length:  2
# X:  (670, 296)
# 196.78
# 131
# temp length:  2
# X:  (671, 296)
# 218.25
# 146
# temp length:  2
# X:  (672, 296)
# 239.93
# 160
# temp length:  2
# X:  (673, 296)
# 265.33
# 177
# temp length:  2
# X:  (674, 296)
# 291.48
# 194
# temp length:  2
# X:  (675, 296)
# condition:  OC
# run 1
# sub:  sub-017
# (205, 296)
# button press TRS: [ 24.9   47.14  71.77  93.92 122.97 147.28 171.4  193.92 219.78 247.3
#  300.03]
# 24.9
# 17
# temp length:  2
# X:  (676, 296)
# 47.14
# 31
# temp length:  2
# X:  (677, 296)
# 71.77
# 48
# temp length:  2
# X:  (678, 296)
# 93.92
# 63
# temp length:  2
# X:  (679, 296)
# 122.97
# 82
# temp length:  2
# X:  (680, 296)
# 147.28
# 98
# temp length:  2
# X:  (681, 296)
# 171.4
# 114
# temp length:  2
# X:  (682, 296)
# 193.92
# 129
# temp length:  2
# X:  (683, 296)
# 219.78
# 147
# temp length:  2
# X:  (684, 296)
# 247.3
# 165
# temp length:  2
# X:  (685, 296)
# 300.03
# 200
# temp length:  0
# sub-018
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-018
# (205, 296)
# button press TRS: [106.19 128.23 145.48 203.81 255.09 306.49]
# 106.19
# 71
# temp length:  2
# X:  (686, 296)
# 128.23
# 85
# temp length:  2
# X:  (687, 296)
# 145.48
# 97
# temp length:  2
# X:  (688, 296)
# 203.81
# 136
# temp length:  2
# X:  (689, 296)
# 255.09
# 170
# temp length:  2
# X:  (690, 296)
# 306.49
# 204
# temp length:  0
# condition:  OM
# run 1
# sub:  sub-018
# (205, 296)
# button press TRS: [ 40.05  59.98  83.32 110.62 189.33 231.03 278.48]
# 40.05
# 27
# temp length:  2
# X:  (691, 296)
# 59.98
# 40
# temp length:  2
# X:  (692, 296)
# 83.32
# 56
# temp length:  2
# X:  (693, 296)
# 110.62
# 74
# temp length:  2
# X:  (694, 296)
# 189.33
# 126
# temp length:  2
# X:  (695, 296)
# 231.03
# 154
# temp length:  2
# X:  (696, 296)
# 278.48
# 186
# temp length:  2
# X:  (697, 296)
# condition:  OC
# run 0
# sub:  sub-018
# (205, 296)
# button press TRS: [ 23.82  46.37  69.72  92.87 115.8  140.62 165.75 187.43 209.67 231.48
#  254.45 277.16 299.35]
# 23.82
# 16
# temp length:  2
# X:  (698, 296)
# 46.37
# 31
# temp length:  2
# X:  (699, 296)
# 69.72
# 46
# temp length:  2
# X:  (700, 296)
# 92.87
# 62
# temp length:  2
# X:  (701, 296)
# 115.8
# 77
# temp length:  2
# X:  (702, 296)
# 140.62
# 94
# temp length:  2
# X:  (703, 296)
# 165.75
# 110
# temp length:  2
# X:  (704, 296)
# 187.43
# 125
# temp length:  2
# X:  (705, 296)
# 209.67
# 140
# temp length:  2
# X:  (706, 296)
# 231.48
# 154
# temp length:  2
# X:  (707, 296)
# 254.45
# 170
# temp length:  2
# X:  (708, 296)
# 277.16
# 185
# temp length:  2
# X:  (709, 296)
# 299.35
# 200
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-018
# (205, 296)
# button press TRS: [ 17.35  38.27  60.7   80.88 102.15 124.55 145.38 169.05 192.23 212.5
#  238.03 268.35 290.16]
# 17.35
# 12
# temp length:  2
# X:  (710, 296)
# 38.27
# 26
# temp length:  2
# X:  (711, 296)
# 60.7
# 40
# temp length:  2
# X:  (712, 296)
# 80.88
# 54
# temp length:  2
# X:  (713, 296)
# 102.15
# 68
# temp length:  2
# X:  (714, 296)
# 124.55
# 83
# temp length:  2
# X:  (715, 296)
# 145.38
# 97
# temp length:  2
# X:  (716, 296)
# 169.05
# 113
# temp length:  2
# X:  (717, 296)
# 192.23
# 128
# temp length:  2
# X:  (718, 296)
# 212.5
# 142
# temp length:  2
# X:  (719, 296)
# 238.03
# 159
# temp length:  2
# X:  (720, 296)
# 268.35
# 179
# temp length:  2
# X:  (721, 296)
# 290.16
# 193
# temp length:  2
# X:  (722, 296)
# sub-019
# concatenated OM OC
# condition:  OC
# run 0
# sub:  sub-019
# (205, 296)
# button press TRS: [ 20.39  40.81  69.66  89.48 106.96 135.63 187.72 209.71 235.99 261.37
#  280.54 298.96]
# 20.39
# 14
# temp length:  2
# X:  (723, 296)
# 40.81
# 27
# temp length:  2
# X:  (724, 296)
# 69.66
# 46
# temp length:  2
# X:  (725, 296)
# 89.48
# 60
# temp length:  2
# X:  (726, 296)
# 106.96
# 71
# temp length:  2
# X:  (727, 296)
# 135.63
# 90
# temp length:  2
# X:  (728, 296)
# 187.72
# 125
# temp length:  2
# X:  (729, 296)
# 209.71
# 140
# temp length:  2
# X:  (730, 296)
# 235.99
# 157
# temp length:  2
# X:  (731, 296)
# 261.37
# 174
# temp length:  2
# X:  (732, 296)
# 280.54
# 187
# temp length:  2
# X:  (733, 296)
# 298.96
# 199
# temp length:  0
# sub-020
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-020
# (205, 296)
# button press TRS: [ 41.4   77.07 143.68 156.35 182.02 204.08 221.42 239.68 303.15]
# 41.4
# 28
# temp length:  2
# X:  (734, 296)
# 77.07
# 51
# temp length:  2
# X:  (735, 296)
# 143.68
# 96
# temp length:  2
# X:  (736, 296)
# 156.35
# 104
# temp length:  2
# X:  (737, 296)
# 182.02
# 121
# temp length:  2
# X:  (738, 296)
# 204.08
# 136
# temp length:  2
# X:  (739, 296)
# 221.42
# 148
# temp length:  2
# X:  (740, 296)
# 239.68
# 160
# temp length:  2
# X:  (741, 296)
# 303.15
# 202
# temp length:  0
# condition:  OM
# run 1
# sub:  sub-020
# (205, 296)
# button press TRS: [ 36.6   56.02  85.63  98.93 136.   152.25 180.5  196.42 210.25 226.42
#  255.05 271.81]
# 36.6
# 24
# temp length:  2
# X:  (742, 296)
# 56.02
# 37
# temp length:  2
# X:  (743, 296)
# 85.63
# 57
# temp length:  2
# X:  (744, 296)
# 98.93
# 66
# temp length:  2
# X:  (745, 296)
# 136.0
# 91
# temp length:  2
# X:  (746, 296)
# 152.25
# 102
# temp length:  2
# X:  (747, 296)
# 180.5
# 120
# temp length:  2
# X:  (748, 296)
# 196.42
# 131
# temp length:  2
# X:  (749, 296)
# 210.25
# 140
# temp length:  2
# X:  (750, 296)
# 226.42
# 151
# temp length:  2
# X:  (751, 296)
# 255.05
# 170
# temp length:  2
# X:  (752, 296)
# 271.81
# 181
# temp length:  2
# X:  (753, 296)
# condition:  OC
# run 0
# sub:  sub-020
# (205, 296)
# button press TRS: [ 17.55  40.14  61.54  82.12 104.38 126.05 146.28 174.75 193.15 213.6
#  235.08 259.7  282.38 304.86]
# 17.55
# 12
# temp length:  2
# X:  (754, 296)
# 40.14
# 27
# temp length:  2
# X:  (755, 296)
# 61.54
# 41
# temp length:  2
# X:  (756, 296)
# 82.12
# 55
# temp length:  2
# X:  (757, 296)
# 104.38
# 70
# temp length:  2
# X:  (758, 296)
# 126.05
# 84
# temp length:  2
# X:  (759, 296)
# 146.28
# 98
# temp length:  2
# X:  (760, 296)
# 174.75
# 116
# temp length:  2
# X:  (761, 296)
# 193.15
# 129
# temp length:  2
# X:  (762, 296)
# 213.6
# 142
# temp length:  2
# X:  (763, 296)
# 235.08
# 157
# temp length:  2
# X:  (764, 296)
# 259.7
# 173
# temp length:  2
# X:  (765, 296)
# 282.38
# 188
# temp length:  2
# X:  (766, 296)
# 304.86
# 203
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-020
# (205, 296)
# button press TRS: [ 24.17  47.25  71.33  93.82 116.48 140.72 166.42 188.33 210.73 231.72
#  255.02 278.08 305.43]
# 24.17
# 16
# temp length:  2
# X:  (767, 296)
# 47.25
# 32
# temp length:  2
# X:  (768, 296)
# 71.33
# 48
# temp length:  2
# X:  (769, 296)
# 93.82
# 63
# temp length:  2
# X:  (770, 296)
# 116.48
# 78
# temp length:  2
# X:  (771, 296)
# 140.72
# 94
# temp length:  2
# X:  (772, 296)
# 166.42
# 111
# temp length:  2
# X:  (773, 296)
# 188.33
# 126
# temp length:  2
# X:  (774, 296)
# 210.73
# 140
# temp length:  2
# X:  (775, 296)
# 231.72
# 154
# temp length:  2
# X:  (776, 296)
# 255.02
# 170
# temp length:  2
# X:  (777, 296)
# 278.08
# 185
# temp length:  2
# X:  (778, 296)
# 305.43
# 204
# temp length:  0
# sub-021
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-021
# (205, 296)
# button press TRS: [ 34.81 111.25 128.11 162.16 237.76 280.66 294.59]
# 34.81
# 23
# temp length:  2
# X:  (779, 296)
# 111.25
# 74
# temp length:  2
# X:  (780, 296)
# 128.11
# 85
# temp length:  2
# X:  (781, 296)
# 162.16
# 108
# temp length:  2
# X:  (782, 296)
# 237.76
# 159
# temp length:  2
# X:  (783, 296)
# 280.66
# 187
# temp length:  2
# X:  (784, 296)
# 294.59
# 196
# temp length:  2
# X:  (785, 296)
# condition:  OM
# run 1
# sub:  sub-021
# (205, 296)
# button press TRS: [ 19.35  40.27  67.67  83.37 112.62 150.85 184.65 197.88 214.12 237.68
#  261.4  286.3 ]
# 19.35
# 13
# temp length:  2
# X:  (786, 296)
# 40.27
# 27
# temp length:  2
# X:  (787, 296)
# 67.67
# 45
# temp length:  2
# X:  (788, 296)
# 83.37
# 56
# temp length:  2
# X:  (789, 296)
# 112.62
# 75
# temp length:  2
# X:  (790, 296)
# 150.85
# 101
# temp length:  2
# X:  (791, 296)
# 184.65
# 123
# temp length:  2
# X:  (792, 296)
# 197.88
# 132
# temp length:  2
# X:  (793, 296)
# 214.12
# 143
# temp length:  2
# X:  (794, 296)
# 237.68
# 158
# temp length:  2
# X:  (795, 296)
# 261.4
# 174
# temp length:  2
# X:  (796, 296)
# 286.3
# 191
# temp length:  2
# X:  (797, 296)
# condition:  OC
# run 0
# sub:  sub-021
# (205, 296)
# button press TRS: [ 23.57  46.9   71.27  93.42 116.05 140.2  165.72 189.35 212.07 231.15
#  256.45 271.15 300.31]
# 23.57
# 16
# temp length:  2
# X:  (798, 296)
# 46.9
# 31
# temp length:  2
# X:  (799, 296)
# 71.27
# 48
# temp length:  2
# X:  (800, 296)
# 93.42
# 62
# temp length:  2
# X:  (801, 296)
# 116.05
# 77
# temp length:  2
# X:  (802, 296)
# 140.2
# 93
# temp length:  2
# X:  (803, 296)
# 165.72
# 110
# temp length:  2
# X:  (804, 296)
# 189.35
# 126
# temp length:  2
# X:  (805, 296)
# 212.07
# 141
# temp length:  2
# X:  (806, 296)
# 231.15
# 154
# temp length:  2
# X:  (807, 296)
# 256.45
# 171
# temp length:  2
# X:  (808, 296)
# 271.15
# 181
# temp length:  2
# X:  (809, 296)
# 300.31
# 200
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-021
# (205, 296)
# button press TRS: [ 21.06  43.05  62.29  99.26 131.41 151.43 169.94 188.29 203.31 219.21
#  241.89 265.86 283.69]
# 21.06
# 14
# temp length:  2
# X:  (810, 296)
# 43.05
# 29
# temp length:  2
# X:  (811, 296)
# 62.29
# 42
# temp length:  2
# X:  (812, 296)
# 99.26
# 66
# temp length:  2
# X:  (813, 296)
# 131.41
# 88
# temp length:  2
# X:  (814, 296)
# 151.43
# 101
# temp length:  2
# X:  (815, 296)
# 169.94
# 113
# temp length:  2
# X:  (816, 296)
# 188.29
# 126
# temp length:  2
# X:  (817, 296)
# 203.31
# 136
# temp length:  2
# X:  (818, 296)
# 219.21
# 146
# temp length:  2
# X:  (819, 296)
# 241.89
# 161
# temp length:  2
# X:  (820, 296)
# 265.86
# 177
# temp length:  2
# X:  (821, 296)
# 283.69
# 189
# temp length:  2
# X:  (822, 296)
# sub-022
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-022
# (205, 296)
# button press TRS: [ 18.83  39.98  67.23  83.   112.73 136.96 156.18 188.7  221.93 238.44
#  267.59]
# 18.83
# 13
# temp length:  2
# X:  (823, 296)
# 39.98
# 27
# temp length:  2
# X:  (824, 296)
# 67.23
# 45
# temp length:  2
# X:  (825, 296)
# 83.0
# 55
# temp length:  2
# X:  (826, 296)
# 112.73
# 75
# temp length:  2
# X:  (827, 296)
# 136.96
# 91
# temp length:  2
# X:  (828, 296)
# 156.18
# 104
# temp length:  2
# X:  (829, 296)
# 188.7
# 126
# temp length:  2
# X:  (830, 296)
# 221.93
# 148
# temp length:  2
# X:  (831, 296)
# 238.44
# 159
# temp length:  2
# X:  (832, 296)
# 267.59
# 178
# temp length:  2
# X:  (833, 296)
# condition:  OM
# run 1
# sub:  sub-022
# (205, 296)
# button press TRS: [ 15.83  30.72  44.87  80.98 110.85 126.28 152.17 203.52 234.38 251.11
#  269.65 286.5  299.81]
# 15.83
# 11
# temp length:  2
# X:  (834, 296)
# 30.72
# 20
# temp length:  2
# X:  (835, 296)
# 44.87
# 30
# temp length:  2
# X:  (836, 296)
# 80.98
# 54
# temp length:  2
# X:  (837, 296)
# 110.85
# 74
# temp length:  2
# X:  (838, 296)
# 126.28
# 84
# temp length:  2
# X:  (839, 296)
# 152.17
# 101
# temp length:  2
# X:  (840, 296)
# 203.52
# 136
# temp length:  2
# X:  (841, 296)
# 234.38
# 156
# temp length:  2
# X:  (842, 296)
# 251.11
# 167
# temp length:  2
# X:  (843, 296)
# 269.65
# 180
# temp length:  2
# X:  (844, 296)
# 286.5
# 191
# temp length:  2
# X:  (845, 296)
# 299.81
# 200
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-022
# (205, 296)
# button press TRS: [ 18.17  40.13  62.3   81.9  104.2  129.48 151.3  178.5  208.15 235.53
#  290.21]
# 18.17
# 12
# temp length:  2
# X:  (846, 296)
# 40.13
# 27
# temp length:  2
# X:  (847, 296)
# 62.3
# 42
# temp length:  2
# X:  (848, 296)
# 81.9
# 55
# temp length:  2
# X:  (849, 296)
# 104.2
# 69
# temp length:  2
# X:  (850, 296)
# 129.48
# 86
# temp length:  2
# ...
# X:  (729, 296)
# 98.93
# 66
# temp length:  2
# X:  (730, 296)
# 136.0
# 91
# temp length:  2
# X:  (731, 296)
# 152.25
# 102
# temp length:  2
# X:  (732, 296)
# 180.5
# 120
# temp length:  2
# X:  (733, 296)
# 196.42
# 131
# temp length:  2
# X:  (734, 296)
# 210.25
# 140
# temp length:  2
# X:  (735, 296)
# 226.42
# 151
# temp length:  2
# X:  (736, 296)
# 255.05
# 170
# temp length:  2
# X:  (737, 296)
# 271.81
# 181
# temp length:  2
# X:  (738, 296)
# condition:  OC
# run 0
# sub:  sub-020
# (205, 296)
# button press TRS: [ 17.55  40.14  61.54  82.12 104.38 126.05 146.28 174.75 193.15 213.6
#  235.08 259.7  282.38 304.86]
# 17.55
# 12
# temp length:  2
# X:  (739, 296)
# 40.14
# 27
# temp length:  2
# X:  (740, 296)
# 61.54
# 41
# temp length:  2
# X:  (741, 296)
# 82.12
# 55
# temp length:  2
# X:  (742, 296)
# 104.38
# 70
# temp length:  2
# X:  (743, 296)
# 126.05
# 84
# temp length:  2
# X:  (744, 296)
# 146.28
# 98
# temp length:  2
# X:  (745, 296)
# 174.75
# 116
# temp length:  2
# X:  (746, 296)
# 193.15
# 129
# temp length:  2
# X:  (747, 296)
# 213.6
# 142
# temp length:  2
# X:  (748, 296)
# 235.08
# 157
# temp length:  2
# X:  (749, 296)
# 259.7
# 173
# temp length:  2
# X:  (750, 296)
# 282.38
# 188
# temp length:  2
# X:  (751, 296)
# 304.86
# 203
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-020
# (205, 296)
# button press TRS: [ 24.17  47.25  71.33  93.82 116.48 140.72 166.42 188.33 210.73 231.72
#  255.02 278.08 305.43]
# 24.17
# 16
# temp length:  2
# X:  (752, 296)
# 47.25
# 32
# temp length:  2
# X:  (753, 296)
# 71.33
# 48
# temp length:  2
# X:  (754, 296)
# 93.82
# 63
# temp length:  2
# X:  (755, 296)
# 116.48
# 78
# temp length:  2
# X:  (756, 296)
# 140.72
# 94
# temp length:  2
# X:  (757, 296)
# 166.42
# 111
# temp length:  2
# X:  (758, 296)
# 188.33
# 126
# temp length:  2
# X:  (759, 296)
# 210.73
# 140
# temp length:  2
# X:  (760, 296)
# 231.72
# 154
# temp length:  2
# X:  (761, 296)
# 255.02
# 170
# temp length:  2
# X:  (762, 296)
# 278.08
# 185
# temp length:  2
# X:  (763, 296)
# 305.43
# 204
# temp length:  0
# sub-021
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-021
# (205, 296)
# button press TRS: [ 34.81 111.25 128.11 162.16 237.76 280.66 294.59]
# 34.81
# 23
# temp length:  2
# X:  (764, 296)
# 111.25
# 74
# temp length:  2
# X:  (765, 296)
# 128.11
# 85
# temp length:  2
# X:  (766, 296)
# 162.16
# 108
# temp length:  2
# X:  (767, 296)
# 237.76
# 159
# temp length:  2
# X:  (768, 296)
# 280.66
# 187
# temp length:  2
# X:  (769, 296)
# 294.59
# 196
# temp length:  0
# condition:  OM
# run 1
# sub:  sub-021
# (205, 296)
# button press TRS: [ 19.35  40.27  67.67  83.37 112.62 150.85 184.65 197.88 214.12 237.68
#  261.4  286.3 ]
# 19.35
# 13
# temp length:  2
# X:  (770, 296)
# 40.27
# 27
# temp length:  2
# X:  (771, 296)
# 67.67
# 45
# temp length:  2
# X:  (772, 296)
# 83.37
# 56
# temp length:  2
# X:  (773, 296)
# 112.62
# 75
# temp length:  2
# X:  (774, 296)
# 150.85
# 101
# temp length:  2
# X:  (775, 296)
# 184.65
# 123
# temp length:  2
# X:  (776, 296)
# 197.88
# 132
# temp length:  2
# X:  (777, 296)
# 214.12
# 143
# temp length:  2
# X:  (778, 296)
# 237.68
# 158
# temp length:  2
# X:  (779, 296)
# 261.4
# 174
# temp length:  2
# X:  (780, 296)
# 286.3
# 191
# temp length:  2
# X:  (781, 296)
# condition:  OC
# run 0
# sub:  sub-021
# (205, 296)
# button press TRS: [ 23.57  46.9   71.27  93.42 116.05 140.2  165.72 189.35 212.07 231.15
#  256.45 271.15 300.31]
# 23.57
# 16
# temp length:  2
# X:  (782, 296)
# 46.9
# 31
# temp length:  2
# X:  (783, 296)
# 71.27
# 48
# temp length:  2
# X:  (784, 296)
# 93.42
# 62
# temp length:  2
# X:  (785, 296)
# 116.05
# 77
# temp length:  2
# X:  (786, 296)
# 140.2
# 93
# temp length:  2
# X:  (787, 296)
# 165.72
# 110
# temp length:  2
# X:  (788, 296)
# 189.35
# 126
# temp length:  2
# X:  (789, 296)
# 212.07
# 141
# temp length:  2
# X:  (790, 296)
# 231.15
# 154
# temp length:  2
# X:  (791, 296)
# 256.45
# 171
# temp length:  2
# X:  (792, 296)
# 271.15
# 181
# temp length:  2
# X:  (793, 296)
# 300.31
# 200
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-021
# (205, 296)
# button press TRS: [ 21.06  43.05  62.29  99.26 131.41 151.43 169.94 188.29 203.31 219.21
#  241.89 265.86 283.69]
# 21.06
# 14
# temp length:  2
# X:  (794, 296)
# 43.05
# 29
# temp length:  2
# X:  (795, 296)
# 62.29
# 42
# temp length:  2
# X:  (796, 296)
# 99.26
# 66
# temp length:  2
# X:  (797, 296)
# 131.41
# 88
# temp length:  2
# X:  (798, 296)
# 151.43
# 101
# temp length:  2
# X:  (799, 296)
# 169.94
# 113
# temp length:  2
# X:  (800, 296)
# 188.29
# 126
# temp length:  2
# X:  (801, 296)
# 203.31
# 136
# temp length:  2
# X:  (802, 296)
# 219.21
# 146
# temp length:  2
# X:  (803, 296)
# 241.89
# 161
# temp length:  2
# X:  (804, 296)
# 265.86
# 177
# temp length:  2
# X:  (805, 296)
# 283.69
# 189
# temp length:  2
# X:  (806, 296)
# sub-022
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-022
# (205, 296)
# button press TRS: [ 18.83  39.98  67.23  83.   112.73 136.96 156.18 188.7  221.93 238.44
#  267.59]
# 18.83
# 13
# temp length:  2
# X:  (807, 296)
# 39.98
# 27
# temp length:  2
# X:  (808, 296)
# 67.23
# 45
# temp length:  2
# X:  (809, 296)
# 83.0
# 55
# temp length:  2
# X:  (810, 296)
# 112.73
# 75
# temp length:  2
# X:  (811, 296)
# 136.96
# 91
# temp length:  2
# X:  (812, 296)
# 156.18
# 104
# temp length:  2
# X:  (813, 296)
# 188.7
# 126
# temp length:  2
# X:  (814, 296)
# 221.93
# 148
# temp length:  2
# X:  (815, 296)
# 238.44
# 159
# temp length:  2
# X:  (816, 296)
# 267.59
# 178
# temp length:  2
# X:  (817, 296)
# condition:  OM
# run 1
# sub:  sub-022
# (205, 296)
# button press TRS: [ 15.83  30.72  44.87  80.98 110.85 126.28 152.17 203.52 234.38 251.11
#  269.65 286.5  299.81]
# 15.83
# 11
# temp length:  2
# X:  (818, 296)
# 30.72
# 20
# temp length:  2
# X:  (819, 296)
# 44.87
# 30
# temp length:  2
# X:  (820, 296)
# 80.98
# 54
# temp length:  2
# X:  (821, 296)
# 110.85
# 74
# temp length:  2
# X:  (822, 296)
# 126.28
# 84
# temp length:  2
# X:  (823, 296)
# 152.17
# 101
# temp length:  2
# X:  (824, 296)
# 203.52
# 136
# temp length:  2
# X:  (825, 296)
# 234.38
# 156
# temp length:  2
# X:  (826, 296)
# 251.11
# 167
# temp length:  2
# X:  (827, 296)
# 269.65
# 180
# temp length:  2
# X:  (828, 296)
# 286.5
# 191
# temp length:  2
# X:  (829, 296)
# 299.81
# 200
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-022
# (205, 296)
# button press TRS: [ 18.17  40.13  62.3   81.9  104.2  129.48 151.3  178.5  208.15 235.53
#  290.21]
# 18.17
# 12
# temp length:  2
# X:  (830, 296)
# 40.13
# 27
# temp length:  2
# X:  (831, 296)
# 62.3
# 42
# temp length:  2
# X:  (832, 296)
# 81.9
# 55
# temp length:  2
# X:  (833, 296)
# 104.2
# 69
# temp length:  2
# X:  (834, 296)
# 129.48
# 86
# temp length:  2
# X:  (835, 296)
# 151.3
# 101
# temp length:  2
# X:  (836, 296)
# 178.5
# 119
# temp length:  2
# X:  (837, 296)
# 208.15
# 139
# temp length:  2
# X:  (838, 296)
# 235.53
# 157
# temp length:  2
# X:  (839, 296)
# 290.21
# 193
# temp length:  1
# X:  (840, 296)
# condition:  OC
# run 1
# sub:  sub-022
# (205, 296)
# button press TRS: [ 24.12  46.53  71.4   92.72 111.55 147.28 198.12 220.75 251.55 284.15]
# 24.12
# 16
# temp length:  2
# X:  (841, 296)
# 46.53
# 31
# temp length:  2
# X:  (842, 296)
# 71.4
# 48
# temp length:  2
# X:  (843, 296)
# 92.72
# 62
# temp length:  2
# X:  (844, 296)
# 111.55
# 74
# temp length:  2
# X:  (845, 296)
# 147.28
# 98
# temp length:  2
# X:  (846, 296)
# 198.12
# 132
# temp length:  2
# X:  (847, 296)
# 220.75
# 147
# temp length:  2
# X:  (848, 296)
# 251.55
# 168
# temp length:  2
# X:  (849, 296)
# 284.15
# 189
# temp length:  2
# X:  (850, 296)
# sub-023
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-023
# (205, 296)
# button press TRS: [ 23.8   46.67  70.43  92.52 115.68 134.45 155.25 178.77 200.62 222.93
#  246.43 268.35 298.95]
# 23.8
# 16
# temp length:  2
# X:  (892, 296)
# 46.67
# 31
# temp length:  2
# X:  (893, 296)
# 70.43
# 47
# temp length:  2
# X:  (894, 296)
# 92.52
# 62
# temp length:  2
# X:  (895, 296)
# 115.68
# 77
# temp length:  2
# X:  (896, 296)
# 134.45
# 90
# temp length:  2
# X:  (897, 296)
# 155.25
# 104
# temp length:  2
# X:  (898, 296)
# 178.77
# 119
# temp length:  2
# X:  (899, 296)
# 200.62
# 134
# temp length:  2
# X:  (900, 296)
# 222.93
# 149
# temp length:  2
# X:  (901, 296)
# 246.43
# 164
# temp length:  2
# X:  (902, 296)
# 268.35
# 179
# temp length:  2
# X:  (903, 296)
# 298.95
# 199
# temp length:  0
# sub-024
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-024
# (205, 296)
# button press TRS: [ 22.19  43.4   85.78 193.57]
# 22.19
# 15
# temp length:  2
# X:  (904, 296)
# 43.4
# 29
# temp length:  2
# X:  (905, 296)
# 85.78
# 57
# temp length:  2
# X:  (906, 296)
# 193.57
# 129
# temp length:  2
# X:  (907, 296)
# condition:  OM
# run 1
# sub:  sub-024
# (205, 296)
# button press TRS: [ 85.47 119.15 150.18 199.72 250.23]
# 85.47
# 57
# temp length:  2
# X:  (908, 296)
# 119.15
# 79
# temp length:  2
# X:  (909, 296)
# 150.18
# 100
# temp length:  2
# X:  (910, 296)
# 199.72
# 133
# temp length:  2
# X:  (911, 296)
# 250.23
# 167
# temp length:  2
# X:  (912, 296)
# condition:  OC
# run 0
# sub:  sub-024
# (205, 296)
# button press TRS: [ 18.1   40.53  62.5   83.01 104.36 125.59 142.86 169.93 190.26 211.09
#  230.64 254.58 282.93]
# 18.1
# 12
# temp length:  2
# X:  (913, 296)
# 40.53
# 27
# temp length:  2
# X:  (914, 296)
# 62.5
# 42
# temp length:  2
# X:  (915, 296)
# 83.01
# 55
# temp length:  2
# X:  (916, 296)
# 104.36
# 70
# temp length:  2
# X:  (917, 296)
# 125.59
# 84
# temp length:  2
# X:  (918, 296)
# 142.86
# 95
# temp length:  2
# X:  (919, 296)
# 169.93
# 113
# temp length:  2
# X:  (920, 296)
# 190.26
# 127
# temp length:  2
# X:  (921, 296)
# 211.09
# 141
# temp length:  2
# X:  (922, 296)
# 230.64
# 154
# temp length:  2
# X:  (923, 296)
# 254.58
# 170
# temp length:  2
# X:  (924, 296)
# 282.93
# 189
# temp length:  2
# X:  (925, 296)
# condition:  OC
# run 1
# sub:  sub-024
# (205, 296)
# button press TRS: [ 23.57  46.72  70.6   92.93 116.53 141.05 166.13 188.42 211.13 232.25
#  256.75 277.78 305.18]
# 23.57
# 16
# temp length:  2
# X:  (926, 296)
# 46.72
# 31
# temp length:  2
# X:  (927, 296)
# 70.6
# 47
# temp length:  2
# X:  (928, 296)
# 92.93
# 62
# temp length:  2
# X:  (929, 296)
# 116.53
# 78
# temp length:  2
# X:  (930, 296)
# 141.05
# 94
# temp length:  2
# X:  (931, 296)
# 166.13
# 111
# temp length:  2
# X:  (932, 296)
# 188.42
# 126
# temp length:  2
# X:  (933, 296)
# 211.13
# 141
# temp length:  2
# X:  (934, 296)
# 232.25
# 155
# temp length:  2
# X:  (935, 296)
# 256.75
# 171
# temp length:  2
# X:  (936, 296)
# 277.78
# 185
# temp length:  2
# X:  (937, 296)
# 305.18
# 203
# temp length:  0
# sub-025
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-025
# (205, 296)
# button press TRS: [ 40.18  68.34  84.52 143.18 182.25 226.98 264.43 288.88]
# 40.18
# 27
# temp length:  2
# X:  (938, 296)
# 68.34
# 46
# temp length:  2
# X:  (939, 296)
# 84.52
# 56
# temp length:  2
# X:  (940, 296)
# 143.18
# 95
# temp length:  2
# X:  (941, 296)
# 182.25
# 122
# temp length:  2
# X:  (942, 296)
# 226.98
# 151
# temp length:  2
# X:  (943, 296)
# 264.43
# 176
# temp length:  2
# X:  (944, 296)
# 288.88
# 193
# temp length:  1
# X:  (945, 296)
# condition:  OM
# run 1
# sub:  sub-025
# (205, 296)
# button press TRS: [ 51.58  90.65 112.   151.73 205.7  230.92 269.41 295.93]
# 51.58
# 34
# temp length:  2
# X:  (946, 296)
# 90.65
# 60
# temp length:  2
# X:  (947, 296)
# 112.0
# 75
# temp length:  2
# X:  (948, 296)
# 151.73
# 101
# temp length:  2
# X:  (949, 296)
# 205.7
# 137
# temp length:  2
# X:  (950, 296)
# 230.92
# 154
# temp length:  2
# X:  (951, 296)
# 269.41
# 180
# temp length:  2
# X:  (952, 296)
# 295.93
# 197
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-025
# (205, 296)
# button press TRS: [ 22.3   45.35  64.93  85.98 108.38 129.98 151.6  182.   200.03 221.66
#  243.65 270.28 290.46]
# 22.3
# 15
# temp length:  2
# X:  (953, 296)
# 45.35
# 30
# temp length:  2
# X:  (954, 296)
# 64.93
# 43
# temp length:  2
# X:  (955, 296)
# 85.98
# 57
# temp length:  2
# X:  (956, 296)
# 108.38
# 72
# temp length:  2
# X:  (957, 296)
# 129.98
# 87
# temp length:  2
# X:  (958, 296)
# 151.6
# 101
# temp length:  2
# X:  (959, 296)
# 182.0
# 121
# temp length:  2
# X:  (960, 296)
# 200.03
# 133
# temp length:  2
# X:  (961, 296)
# 221.66
# 148
# temp length:  2
# X:  (962, 296)
# 243.65
# 162
# temp length:  2
# X:  (963, 296)
# 270.28
# 180
# temp length:  2
# X:  (964, 296)
# 290.46
# 194
# temp length:  0
# condition:  OC
# run 1
# sub:  sub-025
# (205, 296)
# button press TRS: [ 23.78  46.97  70.67  93.77 117.27 140.65 166.28 188.33 210.4  232.22
#  260.47 283.3 ]
# 23.78
# 16
# temp length:  2
# X:  (965, 296)
# 46.97
# 31
# temp length:  2
# X:  (966, 296)
# 70.67
# 47
# temp length:  2
# X:  (967, 296)
# 93.77
# 63
# temp length:  2
# X:  (968, 296)
# 117.27
# 78
# temp length:  2
# X:  (969, 296)
# 140.65
# 94
# temp length:  2
# X:  (970, 296)
# 166.28
# 111
# temp length:  2
# X:  (971, 296)
# 188.33
# 126
# temp length:  2
# X:  (972, 296)
# 210.4
# 140
# temp length:  2
# X:  (973, 296)
# 232.22
# 155
# temp length:  2
# X:  (974, 296)
# 260.47
# 174
# temp length:  2
# X:  (975, 296)
# 283.3
# 189
# temp length:  2
# X:  (976, 296)
# sub-026
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-026
# (205, 296)
# button press TRS: [ 39.41  82.11 119.73 156.08 188.6  221.96 244.11]
# 39.41
# 26
# temp length:  2
# X:  (977, 296)
# 82.11
# 55
# temp length:  2
# X:  (978, 296)
# 119.73
# 80
# temp length:  2
# X:  (979, 296)
# 156.08
# 104
# temp length:  2
# X:  (980, 296)
# 188.6
# 126
# temp length:  2
# X:  (981, 296)
# 221.96
# 148
# temp length:  2
# X:  (982, 296)
# 244.11
# 163
# temp length:  2
# X:  (983, 296)
# condition:  OM
# run 1
# sub:  sub-026
# (205, 296)
# button press TRS: [ 20.38  89.7  110.95 152.57 234.35 246.85 269.88 287.56 295.  ]
# 20.38
# 14
# temp length:  2
# X:  (984, 296)
# 89.7
# 60
# temp length:  2
# X:  (985, 296)
# 110.95
# 74
# temp length:  2
# X:  (986, 296)
# 152.57
# 102
# temp length:  2
# X:  (987, 296)
# 234.35
# 156
# temp length:  2
# X:  (988, 296)
# 246.85
# 165
# temp length:  2
# X:  (989, 296)
# 269.88
# 180
# temp length:  2
# X:  (990, 296)
# 287.56
# 192
# temp length:  2
# X:  (991, 296)
# 295.0
# 197
# temp length:  0
# condition:  OC
# run 0
# sub:  sub-026
# (205, 296)
# button press TRS: [ 21.65  43.15  65.78 112.43 131.33 151.93 181.27 199.36 247.05 276.45]
# 21.65
# 14
# temp length:  2
# X:  (992, 296)
# 43.15
# 29
# temp length:  2
# X:  (993, 296)
# 65.78
# 44
# temp length:  2
# X:  (994, 296)
# 112.43
# 75
# temp length:  2
# X:  (995, 296)
# 131.33
# 88
# temp length:  2
# X:  (996, 296)
# 151.93
# 101
# temp length:  2
# X:  (997, 296)
# 181.27
# 121
# temp length:  2
# X:  (998, 296)
# 199.36
# 133
# temp length:  2
# X:  (999, 296)
# 247.05
# 165
# temp length:  2
# X:  (1000, 296)
# 276.45
# 184
# temp length:  2
# X:  (1001, 296)
# condition:  OC
# run 1
# sub:  sub-026
# (205, 296)
# button press TRS: [ 23.17  46.67 105.52 123.05 149.48 172.82 196.3  219.17 240.67 261.92
#  276.13 301.5 ]
# 23.17
# 15
# temp length:  2
# X:  (1002, 296)
# 46.67
# 31
# temp length:  2
# X:  (1003, 296)
# 105.52
# 70
# temp length:  2
# X:  (1004, 296)
# 123.05
# 82
# temp length:  2
# X:  (1005, 296)
# 149.48
# 100
# temp length:  2
# X:  (1006, 296)
# 172.82
# 115
# temp length:  2
# X:  (1007, 296)
# 196.3
# 131
# temp length:  2
# X:  (1008, 296)
# 219.17
# 146
# temp length:  2
# X:  (1009, 296)
# 240.67
# 160
# temp length:  2
# X:  (1010, 296)
# 261.92
# 175
# temp length:  2
# X:  (1011, 296)
# 276.13
# 184
# temp length:  2
# X:  (1012, 296)
# 301.5
# 201
# temp length:  0
# sub-027
# concatenated OM OC
# condition:  OM
# run 0
# sub:  sub-027

# %%
activations = np.load(os.path.join(act_dir, '%s.npy') %(act_dict_name ), allow_pickle=True).item()
for key in sorted(activations):
    print(key)
# Out:
# OM_OC_LH_Limbic_TempPole_3_win2
# OM_OC_LH_Limbic_TempPole_3_win3
# OM_OC_LH_Limbic_TempPole_3_win4
# OM_OC_LH_Limbic_TempPole_3_win5
# OM_OC_LH_Limbic_TempPole_3_win6
# OM_OC_LH_Limbic_TempPole_3_win7
# OM_OC_LH_Limbic_TempPole_3_win8
# OM_OC_LH_Limbic_TempPole_4_win1
# OM_OC_LH_Limbic_TempPole_4_win6
# OM_OC_LH_Limbic_TempPole_4_win7
# OM_OC_LH_SalVentAttn_FrOperIns_1_win2
# OM_OC_LH_SalVentAttn_FrOperIns_1_win3
# OM_OC_LH_SalVentAttn_FrOperIns_1_win4
# OM_OC_LH_SalVentAttn_FrOperIns_2_win2
# OM_OC_LH_SalVentAttn_FrOperIns_2_win3
# OM_OC_LH_SalVentAttn_FrOperIns_2_win4
# OM_OC_LH_SalVentAttn_FrOperIns_2_win5
# OM_OC_LH_SalVentAttn_FrOperIns_3_win1
# OM_OC_LH_SalVentAttn_FrOperIns_3_win6
# OM_OC_LH_SalVentAttn_FrOperIns_3_win7
# OM_OC_LH_SalVentAttn_FrOperIns_3_win8
# OM_OC_LH_SalVentAttn_FrOperIns_4_win1
# OM_OC_LH_SalVentAttn_Med_1_win1
# OM_OC_LH_SalVentAttn_Med_1_win2
# OM_OC_LH_SalVentAttn_Med_1_win3
# OM_OC_LH_SalVentAttn_Med_1_win4
# OM_OC_LH_SalVentAttn_Med_1_win5
# OM_OC_LH_SalVentAttn_Med_2_win1
# OM_OC_LH_SalVentAttn_Med_2_win6
# OM_OC_LH_SalVentAttn_Med_2_win7
# OM_OC_LH_SalVentAttn_Med_3_win2
# OM_OC_LH_SalVentAttn_Med_3_win3
# OM_OC_LH_SalVentAttn_Med_3_win4
# OM_OC_LH_SalVentAttn_Med_3_win5
# OM_OC_LH_SalVentAttn_PFCl_1_win1
# OM_OC_LH_SalVentAttn_PFCl_1_win2
# OM_OC_LH_SalVentAttn_PFCl_1_win3
# OM_OC_LH_SalVentAttn_PFCl_1_win4
# OM_OC_LH_SalVentAttn_PFCl_1_win5
# OM_OC_LH_SalVentAttn_PFCl_1_win6
# OM_OC_LH_SalVentAttn_PFCl_1_win7
# OM_OC_LH_SalVentAttn_PFCl_1_win8
# OM_OC_LH_SalVentAttn_ParOper_1_win2
# OM_OC_LH_SalVentAttn_ParOper_1_win3
# OM_OC_LH_SalVentAttn_ParOper_1_win4
# OM_OC_LH_SalVentAttn_ParOper_1_win5
# OM_OC_LH_SalVentAttn_ParOper_2_win2
# OM_OC_LH_SalVentAttn_ParOper_2_win3
# OM_OC_LH_SalVentAttn_ParOper_2_win4
# OM_OC_LH_SalVentAttn_ParOper_2_win5
# OM_OC_LH_SalVentAttn_ParOper_3_win1
# OM_OC_LH_SalVentAttn_ParOper_3_win2
# OM_OC_LH_SalVentAttn_ParOper_3_win3
# OM_OC_LH_SalVentAttn_ParOper_3_win5
# OM_OC_LH_SalVentAttn_ParOper_3_win6
# OM_OC_LH_SalVentAttn_ParOper_3_win7
# OM_OC_RH_DorsAttn_Post_8_win4
# OM_OC_RH_DorsAttn_Post_8_win5
# OM_OC_RH_DorsAttn_PrCv_1_win2
# OM_OC_RH_DorsAttn_PrCv_1_win3
# OM_OC_RH_DorsAttn_PrCv_1_win4
# OM_OC_RH_DorsAttn_PrCv_1_win5
# OM_OC_RH_Limbic_OFC_1_win2
# OM_OC_RH_Limbic_OFC_1_win3
# OM_OC_RH_Limbic_OFC_1_win4
# OM_OC_RH_Limbic_OFC_1_win5
# OM_OC_RH_Limbic_OFC_2_win1
# OM_OC_RH_Limbic_OFC_2_win6
# OM_OC_RH_Limbic_OFC_2_win7
# OM_OC_RH_Limbic_OFC_2_win8
# OM_OC_RH_Limbic_OFC_3_win1
# OM_OC_RH_Limbic_TempPole_1_win1
# OM_OC_RH_Limbic_TempPole_1_win2
# OM_OC_RH_Limbic_TempPole_3_win1
# OM_OC_RH_Limbic_TempPole_3_win6
# OM_OC_RH_Limbic_TempPole_3_win7
# OM_OC_RH_Limbic_TempPole_3_win8
# OM_OC_RH_SalVentAttn_FrOperIns_3_win2
# OM_OC_RH_SalVentAttn_FrOperIns_3_win3
# OM_OC_RH_SalVentAttn_FrOperIns_3_win4
# OM_OC_RH_SalVentAttn_FrOperIns_3_win5
# OM_OC_RH_SalVentAttn_PrC_1_win1
# OM_OC_RH_SalVentAttn_PrC_1_win2
# OM_OC_RH_SalVentAttn_PrC_1_win3
# OM_OC_RH_SalVentAttn_PrC_1_win4
# OM_OC_RH_SalVentAttn_PrC_1_win6
# OM_OC_RH_SalVentAttn_TempOccPar_1_win1
# OM_OC_RH_SalVentAttn_TempOccPar_1_win2
# OM_OC_RH_SalVentAttn_TempOccPar_1_win3
# OM_OC_RH_SalVentAttn_TempOccPar_1_win4
# OM_OC_RH_SalVentAttn_TempOccPar_1_win5
# OM_OC_RH_SalVentAttn_TempOccPar_1_win6
# OM_OC_RH_SalVentAttn_TempOccPar_1_win7
# OM_OC_RH_SalVentAttn_TempOccPar_1_win8
# OM_OC_RH_SalVentAttn_TempOccPar_2_win2
# OM_OC_RH_SalVentAttn_TempOccPar_2_win3
# OM_OC_RH_SalVentAttn_TempOccPar_2_win4
# OM_OC_RH_SalVentAttn_TempOccPar_2_win5
# OM_OC_RH_SalVentAttn_TempOccPar_3_win1
# OM_OC_RH_SalVentAttn_TempOccPar_3_win6
# OM_OC_RH_SalVentAttn_TempOccPar_3_win7
# OM_OC_RH_SalVentAttn_TempOccPar_3_win8
# OM_OC_RH_SomMot_11_win1
# OM_OC_RH_SomMot_11_win6
# OM_OC_RH_SomMot_11_win7
# OM_OC_RH_SomMot_11_win8
# OM_OC_RH_SomMot_15_win2
# OM_OC_RH_SomMot_15_win3
# OM_OC_RH_SomMot_15_win4
# OM_OC_RH_SomMot_15_win5
# OM_OC_RH_SomMot_17_win2
# OM_OC_RH_SomMot_17_win3
# OM_OC_RH_SomMot_17_win4
# OM_OC_RH_SomMot_17_win5
# OM_OC_RH_SomMot_2_win1
# OM_OC_RH_SomMot_2_win6
# SM_SC_LH_SalVentAttn_FrOperIns_2_win5
# SM_SC_LH_SalVentAttn_FrOperIns_3_win1
# SM_SC_LH_SalVentAttn_FrOperIns_3_win2
# SM_SC_LH_SalVentAttn_FrOperIns_3_win3
# SM_SC_LH_SalVentAttn_FrOperIns_3_win4
# SM_SC_LH_SalVentAttn_FrOperIns_3_win6
# SM_SC_LH_SalVentAttn_FrOperIns_3_win7
# SM_SC_LH_SalVentAttn_FrOperIns_3_win8
# SM_SC_LH_SalVentAttn_FrOperIns_4_win1
# SM_SC_LH_SalVentAttn_FrOperIns_4_win6
# SM_SC_LH_SalVentAttn_FrOperIns_4_win7
# SM_SC_LH_SalVentAttn_FrOperIns_4_win8
# SM_SC_LH_SalVentAttn_Med_1_win1
# SM_SC_LH_SalVentAttn_Med_1_win2
# SM_SC_LH_SalVentAttn_Med_1_win3
# SM_SC_LH_SalVentAttn_Med_1_win4
# SM_SC_LH_SalVentAttn_Med_1_win5
# SM_SC_LH_SalVentAttn_Med_1_win6
# SM_SC_LH_SalVentAttn_Med_1_win7
# SM_SC_LH_SalVentAttn_Med_1_win8
# SM_SC_LH_SalVentAttn_Med_2_win1
# SM_SC_LH_SalVentAttn_Med_2_win6
# SM_SC_LH_SalVentAttn_Med_2_win7
# SM_SC_LH_SalVentAttn_Med_2_win8
# SM_SC_LH_SalVentAttn_Med_3_win1
# SM_SC_LH_SalVentAttn_Med_3_win2
# SM_SC_LH_SalVentAttn_Med_3_win3
# SM_SC_LH_SalVentAttn_Med_3_win4
# SM_SC_LH_SalVentAttn_Med_3_win5
# SM_SC_LH_SalVentAttn_Med_3_win6
# SM_SC_LH_SalVentAttn_Med_3_win7
# SM_SC_LH_SalVentAttn_Med_3_win8
# SM_SC_LH_SalVentAttn_PFCl_1_win1
# SM_SC_LH_SalVentAttn_PFCl_1_win2
# SM_SC_LH_SalVentAttn_PFCl_1_win3
# SM_SC_LH_SalVentAttn_PFCl_1_win4
# SM_SC_LH_SalVentAttn_PFCl_1_win5
# SM_SC_LH_SalVentAttn_PFCl_1_win6
# SM_SC_LH_SalVentAttn_PFCl_1_win7
# SM_SC_LH_SalVentAttn_PFCl_1_win8
# SM_SC_LH_SalVentAttn_ParOper_1_win2
# SM_SC_LH_SalVentAttn_ParOper_1_win3
# SM_SC_LH_SalVentAttn_ParOper_1_win4
# SM_SC_LH_SalVentAttn_ParOper_1_win5
# SM_SC_LH_SalVentAttn_ParOper_2_win2
# SM_SC_LH_SalVentAttn_ParOper_2_win3
# SM_SC_LH_SalVentAttn_ParOper_2_win4
# SM_SC_LH_SalVentAttn_ParOper_2_win5
# SM_SC_LH_SalVentAttn_ParOper_3_win1
# SM_SC_LH_SalVentAttn_ParOper_3_win2
# SM_SC_LH_SalVentAttn_ParOper_3_win3
# SM_SC_LH_SalVentAttn_ParOper_3_win4
# SM_SC_LH_SalVentAttn_ParOper_3_win5
# SM_SC_LH_SalVentAttn_ParOper_3_win6
# SM_SC_LH_SalVentAttn_ParOper_3_win7
# SM_SC_LH_SalVentAttn_ParOper_3_win8
# SM_SC_LH_SomMot_10_win1
# SM_SC_LH_SomMot_10_win2
# SM_SC_LH_SomMot_10_win3
# SM_SC_LH_SomMot_10_win4
# SM_SC_LH_SomMot_10_win5
# SM_SC_LH_SomMot_10_win6
# SM_SC_LH_SomMot_11_win1
# SM_SC_LH_SomMot_11_win2
# SM_SC_LH_SomMot_11_win3
# SM_SC_LH_SomMot_11_win4
# SM_SC_LH_SomMot_11_win5
# SM_SC_LH_SomMot_11_win7
# SM_SC_LH_SomMot_11_win8
# SM_SC_LH_SomMot_12_win2
# SM_SC_LH_SomMot_12_win3
# SM_SC_LH_SomMot_12_win4
# SM_SC_LH_SomMot_12_win5
# SM_SC_LH_SomMot_13_win1
# SM_SC_LH_SomMot_13_win2
# SM_SC_LH_SomMot_13_win3
# SM_SC_LH_SomMot_13_win4
# SM_SC_LH_SomMot_13_win5
# SM_SC_LH_SomMot_13_win6
# SM_SC_LH_SomMot_13_win7
# SM_SC_LH_SomMot_13_win8
# SM_SC_LH_SomMot_14_win1
# SM_SC_LH_SomMot_14_win2
# SM_SC_LH_SomMot_14_win3
# SM_SC_LH_SomMot_14_win6
# SM_SC_LH_SomMot_14_win7
# SM_SC_LH_SomMot_14_win8
# SM_SC_LH_SomMot_15_win1
# SM_SC_LH_SomMot_15_win6
# SM_SC_LH_SomMot_15_win7
# SM_SC_LH_SomMot_15_win8
# SM_SC_LH_SomMot_16_win1
# SM_SC_LH_SomMot_16_win2
# SM_SC_LH_SomMot_16_win3
# SM_SC_LH_SomMot_16_win4
# SM_SC_LH_SomMot_16_win5
# SM_SC_LH_SomMot_16_win6
# SM_SC_LH_SomMot_16_win7
# SM_SC_LH_SomMot_16_win8
# SM_SC_LH_SomMot_1_win1
# SM_SC_LH_SomMot_1_win2
# SM_SC_LH_SomMot_1_win3
# SM_SC_LH_SomMot_1_win4
# SM_SC_LH_SomMot_1_win5
# SM_SC_LH_SomMot_1_win6
# SM_SC_LH_SomMot_1_win7
# SM_SC_LH_SomMot_1_win8
# SM_SC_LH_SomMot_2_win1
# SM_SC_LH_SomMot_2_win2
# SM_SC_LH_SomMot_2_win3
# SM_SC_LH_SomMot_2_win4
# SM_SC_LH_SomMot_2_win5
# SM_SC_LH_SomMot_2_win6
# SM_SC_LH_SomMot_2_win7
# SM_SC_LH_SomMot_2_win8
# SM_SC_LH_SomMot_3_win1
# SM_SC_LH_SomMot_3_win2
# SM_SC_LH_SomMot_3_win3
# SM_SC_LH_SomMot_3_win4
# SM_SC_LH_SomMot_3_win5
# SM_SC_LH_SomMot_3_win6
# SM_SC_LH_SomMot_3_win7
# SM_SC_LH_SomMot_3_win8
# SM_SC_LH_SomMot_4_win1
# SM_SC_LH_SomMot_4_win2
# SM_SC_LH_SomMot_4_win3
# SM_SC_LH_SomMot_4_win4
# SM_SC_LH_SomMot_4_win5
# SM_SC_LH_SomMot_5_win1
# SM_SC_LH_SomMot_5_win2
# SM_SC_LH_SomMot_5_win3
# SM_SC_RH_DorsAttn_Post_9_win1
# SM_SC_RH_DorsAttn_PrCv_1_win1
# SM_SC_RH_DorsAttn_PrCv_1_win2
# SM_SC_RH_DorsAttn_PrCv_1_win3
# SM_SC_RH_DorsAttn_PrCv_1_win4
# SM_SC_RH_DorsAttn_PrCv_1_win5
# SM_SC_RH_Limbic_OFC_1_win1
# SM_SC_RH_Limbic_OFC_1_win2
# SM_SC_RH_Limbic_OFC_1_win3
# SM_SC_RH_Limbic_OFC_1_win4
# SM_SC_RH_Limbic_OFC_1_win5
# SM_SC_RH_Limbic_OFC_1_win6
# SM_SC_RH_Limbic_OFC_2_win1
# SM_SC_RH_Limbic_OFC_2_win6
# SM_SC_RH_Limbic_OFC_2_win7
# SM_SC_RH_Limbic_OFC_2_win8
# SM_SC_RH_Limbic_OFC_3_win1
# SM_SC_RH_Limbic_OFC_3_win2
# SM_SC_RH_Limbic_OFC_3_win3
# SM_SC_RH_Limbic_OFC_3_win4
# SM_SC_RH_Limbic_OFC_3_win5
# SM_SC_RH_Limbic_OFC_3_win7
# SM_SC_RH_Limbic_OFC_3_win8
# SM_SC_RH_Limbic_TempPole_1_win1
# SM_SC_RH_Limbic_TempPole_1_win2
# SM_SC_RH_Limbic_TempPole_1_win3
# SM_SC_RH_Limbic_TempPole_1_win4
# SM_SC_RH_Limbic_TempPole_1_win5
# SM_SC_RH_Limbic_TempPole_1_win6
# SM_SC_RH_Limbic_TempPole_1_win7
# SM_SC_RH_Limbic_TempPole_1_win8
# SM_SC_RH_Limbic_TempPole_2_win1
# SM_SC_RH_Limbic_TempPole_2_win2
# SM_SC_RH_Limbic_TempPole_2_win3
# SM_SC_RH_Limbic_TempPole_2_win6
# SM_SC_RH_Limbic_TempPole_3_win1
# SM_SC_RH_Limbic_TempPole_3_win2
# SM_SC_RH_Limbic_TempPole_3_win3
# SM_SC_RH_Limbic_TempPole_3_win6
# SM_SC_RH_Limbic_TempPole_3_win7
# SM_SC_RH_Limbic_TempPole_3_win8
# SM_SC_RH_SalVentAttn_FrOperIns_2_win2
# SM_SC_RH_SalVentAttn_FrOperIns_2_win3
# SM_SC_RH_SalVentAttn_FrOperIns_2_win4
# SM_SC_RH_SalVentAttn_FrOperIns_3_win1
# SM_SC_RH_SalVentAttn_FrOperIns_3_win2
# SM_SC_RH_SalVentAttn_FrOperIns_3_win3
# SM_SC_RH_SalVentAttn_FrOperIns_3_win4
# SM_SC_RH_SalVentAttn_FrOperIns_3_win5
# SM_SC_RH_SalVentAttn_FrOperIns_3_win6
# SM_SC_RH_SalVentAttn_FrOperIns_4_win1
# SM_SC_RH_SalVentAttn_FrOperIns_4_win2
# SM_SC_RH_SalVentAttn_FrOperIns_4_win3
# SM_SC_RH_SalVentAttn_FrOperIns_4_win6
# SM_SC_RH_SalVentAttn_FrOperIns_4_win7
# SM_SC_RH_SalVentAttn_Med_1_win1
# SM_SC_RH_SalVentAttn_Med_2_win1
# SM_SC_RH_SalVentAttn_Med_2_win2
# SM_SC_RH_Vis_12_win8
# SM_SC_RH_Vis_13_win1
# SM_SC_RH_Vis_13_win2
# SM_SC_RH_Vis_13_win3
# SM_SC_RH_Vis_14_win2
# SM_SC_RH_Vis_14_win3
# SM_SC_RH_Vis_14_win4
# SM_SC_RH_Vis_15_win1
# SM_SC_RH_Vis_15_win2
# SM_SC_RH_Vis_15_win5
# SM_SC_RH_Vis_1_win1
# SM_SC_RH_Vis_1_win2
# SM_SC_RH_Vis_1_win3
# SM_SC_RH_Vis_1_win4
# SM_SC_RH_Vis_1_win5
# SM_SC_RH_Vis_1_win6
# SM_SC_RH_Vis_1_win7
# SM_SC_RH_Vis_1_win8
# SM_SC_RH_Vis_2_win1
# SM_SC_RH_Vis_3_win1
# SM_SC_RH_Vis_3_win2
# SM_SC_RH_Vis_3_win3
# SM_SC_RH_Vis_3_win6
# SM_SC_RH_Vis_3_win7
# SM_SC_RH_Vis_4_win1
# SM_SC_RH_Vis_4_win2
# SM_SC_RH_Vis_4_win3
# SM_SC_RH_Vis_4_win4
# SM_SC_RH_Vis_4_win5
# SM_SC_RH_Vis_4_win6
# SM_SC_RH_Vis_4_win7
# SM_SC_RH_Vis_4_win8
# SM_SC_RH_Vis_5_win1
# SM_SC_RH_Vis_5_win6
# SM_SC_RH_Vis_5_win7
# SM_SC_RH_Vis_5_win8
# SM_SC_RH_Vis_6_win1
# SM_SC_RH_Vis_6_win2
# SM_SC_RH_Vis_6_win3
# SM_SC_RH_Vis_6_win4
# SM_SC_RH_Vis_6_win6
# SM_SC_RH_Vis_6_win7
# SM_SC_RH_Vis_7_win1
# SM_SC_RH_Vis_7_win2
# SM_SC_RH_Vis_7_win3
# SM_SC_RH_Vis_7_win4
# SM_SC_RH_Vis_7_win5
# SM_SC_RH_Vis_8_win1
# SM_SC_RH_Vis_8_win2
# SM_SC_RH_Vis_8_win3
# SM_SC_RH_Vis_8_win4
# SM_SC_RH_Vis_8_win5
# SM_SC_RH_Vis_8_win6
# SM_SC_RH_Vis_8_win7
# SM_SC_RH_Vis_8_win8
# SM_SC_RH_Vis_9_win1
# SM_SC_RH_Vis_9_win2

# %%
roi_list = ['RH_Cont_Par_2', 'LH_Default_PFC_11','RH_Default_Par_3']
roi_list = ['LH_Default_PFC_11',]
new_dic = {}
for anal in sorted(activations):
    if anal[6:-5] in roi_list:
        new_dic[anal] = activations[anal]

# %%
for key in new_dic:
    print(f'{key}')
# Out:
# OM_OC_LH_Default_PFC_11_win2
# OM_OC_LH_Default_PFC_11_win3
# OM_OC_LH_Default_PFC_11_win4
# OM_OC_LH_Default_PFC_11_win5
# SM_SC_LH_Default_PFC_11_win1
# SM_SC_LH_Default_PFC_11_win2
# SM_SC_LH_Default_PFC_11_win3
# SM_SC_LH_Default_PFC_11_win4
# SM_SC_LH_Default_PFC_11_win5
# SM_SC_LH_Default_PFC_11_win6
# SM_SC_LH_Default_PFC_11_win7
# SM_SC_LH_Default_PFC_11_win8

# %%
new_dic[key]['X'].shape
# Out:
# (925, 296)
