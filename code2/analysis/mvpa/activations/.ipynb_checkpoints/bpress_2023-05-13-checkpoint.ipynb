# %%
#python resample.py $IMAGE_TO_RESAMPLE $REFERENCE_IMAGE

# %%
#!jupyter nbconvert bpress_2023-05-13.ipynb --to python

# %%
"""
~~~ Script description ~~~
adapted from troubshoot_bpress_slopes_6-24-22
adapted from ATM_bpress_within-between_1-4-23_rest.py on 1/31/23
- changed bpress to exclude overlap
changed path, added sys.argv for multiple jobs 5/11/23
- roi_activations_2023-05-11.npy is the same dictionary as
  mvpa_results_2023-05-11.npy with more windows and better name  
5/13
- Iterate across subs 
this script specifically looks at 28 subs for dmPFC and rTPJ
5/24
- create function that normalizes over space instead of time
"""
# Out:
# '\n~~~ Script description ~~~\nadapted from troubshoot_bpress_slopes_6-24-22\nadapted from ATM_bpress_within-between_1-4-23_rest.py on 1/31/23\n- changed bpress to exclude overlap\nchanged path, added sys.argv for multiple jobs 5/11/23\n- roi_activations_2023-05-11.npy is the same dictionary as\n  mvpa_results_2023-05-11.npy with more windows and better name  \n5/13\n- Iterate across subs \nthis script specifically looks at 28 subs for dmPFC and rTPJ\n5/24\n- create function that normalizes over space instead of time\n'

# %%
import nibabel as nib

from nilearn.input_data import NiftiMasker , MultiNiftiMasker

import nilearn as nil
"""
Plotting!
https://nilearn.github.io/plotting/index.html

"""
from nilearn import plotting
import numpy as np 
import os
import os.path
import scipy.io
import nibabel as nib
from nilearn.input_data import NiftiMasker
from nilearn.masking import compute_epi_mask
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import PredefinedSplit
from copy import deepcopy

import warnings
import sys  
import random
# import logging

import deepdish as dd
import numpy as np

import brainiak.eventseg.event
import nibabel as nib
from nilearn.input_data import NiftiMasker

import scipy.io
from scipy import stats
from scipy.stats import norm, zscore, pearsonr
from scipy.signal import gaussian, convolve
from sklearn import decomposition
from sklearn.model_selection import LeaveOneOut, KFold

from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches
import seaborn as sns 

sns.set(style = 'white', context='talk', font_scale=1, rc={"lines.linewidth": 2})

if not sys.warnoptions:
    warnings.simplefilter("ignore")

"""
from utils import sherlock_h5_data

if not os.path.exists(sherlock_h5_data):
    os.makedirs(sherlock_h5_data)
    print('Make dir: ', sherlock_h5_data)
else: 
    print('Data path exists')
    
from utils import sherlock_dir
"""

random.seed(10)

from brainiak import image, io
from scipy.stats import stats
import nibabel as nib
import numpy as np
from matplotlib import pyplot as plt
from brainiak import image, io

import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import LeavePGroupsOut

import pandas as pd
from nilearn.plotting import plot_glass_brain

# Import machine learning libraries
from nilearn.input_data import NiftiMasker
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold, f_classif, SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from scipy.stats import sem
from copy import deepcopy
from sklearn.metrics import roc_auc_score
import statistics

from nilearn import datasets, plotting
from nilearn.input_data import NiftiSpheresMasker

from nilearn.glm.first_level import FirstLevelModel
from nilearn.glm.first_level import make_first_level_design_matrix
from nilearn.image import concat_imgs, resample_img, mean_img, index_img
from nilearn import image
from nilearn import masking
from nilearn.plotting import view_img
from nilearn.plotting import plot_design_matrix
from nilearn.reporting import get_clusters_table
from nilearn import input_data
# Out:
# /jukebox/pkgs/PYGER/base/envs/0.11.0/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %% [markdown]
# # Functions

# %%
## Expand / Label TRs
"""
0 = SM
1 = SC
2 = OM
3 = OC
4 = Re
requires list of labels ouputed by psychopy (column 1 - MM_self_title.started, etc.)
returns label list (order is preserved) and TR labels
"""

def label_lists(label, num_tr):
    b = [[]]
    a = []
    for i in label:
        # substring label in psychopy output
        # if the first three characters == M_s, etc, then add correct indext to string
        if i[1:4] == "M_s":
            a.append("SM")
            b.append([0]*num_tr)
        elif i[1:4] == "C_s":
            a.append("SC")
            b.append([1]*num_tr)        
        elif i[1:4] == "M_o":
            a.append("OM")
            b.append([2]*num_tr)
        elif i[1:4] == "C_o":
            a.append("OC")
            b.append([3]*num_tr)     
        else:
            a.append("Re")
            b.append([4]*num_tr)     
    return a, b[1:]

# %%
def find_cond_index(sub_ses_labels):
    """
    For the array of ordered run names (i.e.'Re', 'SM',) find the two indexes per condition
    """ 
    lab_inx = []

    a = []
    b = []
    c = []
    d = []
    e = []

    for i in enumerate(sub_ses_labels):
        if i[1] == "SM":
            # append the index according to where it appeared in the array
            a.append(i[0])
        if i[1] == "SC":
            b.append(i[0])
        if i[1] == "OM":
            c.append(i[0])
        if i[1] == "OC":
            d.append(i[0])

    # Create a dictionary where each key contains the appropriate indexes
    lab_indic = {
        'SM' : a,
        'SC' : b,
        'OM' : c,
        'OC' : d,
        'RE' : [0,9]
    }
    return lab_indic

# %%
def load_epi_data(sub, ses, task,run, space):
  # Load MRI file
    if space == "MNI":
        epi_in = os.path.join(data_dir, sub, ses, 'func', "%s_%s_task-%s_run-%s_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz" % (sub, ses, task,run))
    elif space == "T1":
        epi_in = os.path.join(data_dir, sub, ses, 'func', "%s_%s_task-%s_run-%s_space-T1w_desc-preproc_bold.nii.gz" % (sub, ses, task,run))
    else:
        print("wrong load epi input. check this function")
    epi_data = nib.load(epi_in)
    print("Loading data from %s" % (epi_in))
    return epi_data

def load_roi_mask(ROI_name, space):
    if space == "MNI":
        maskdir = os.path.join(rois_dir)    
        print("expected shape: 78, 93,65")
    elif space == "T1":
        maskdir = os.path.join(rois_dir+ "/T1")
        print("expected shape: 56, 72,53")
    else:
        print("wrong mask input. check this function")
    # load the mask
    maskfile = os.path.join(maskdir, "%s.nii" % (ROI_name))
    mask = nib.load(maskfile)
    print("mask shape: ", mask.shape)
    print("Loaded %s mask" % (ROI_name))
    return mask

# %%
def intersect_mask(sub, num_runs,reg, ses="ses-01",task="Attn"):
    # This is based off of 'load_data' function in template
    # Loads all fMRI runs into a matrix #
    """
    reg = T1 or MNI registration?
    norm_type = by Space or by Time? 
    """
    yoz = []
    print("Begin intersecting, yeehaw")
    for run in range(1, num_runs + 1):
        # Load epi data 
        epi = load_epi_data(sub,ses,task,run,reg)
        # Load ROI data
        roi_samp = compute_epi_mask(epi)
     #   print(roi_samp)
        #nifti_masker = NiftiMasker(mask_img=roi_samp)
        #maskedData = nifti_masker.fit_transform(epi)
        yoz.append(roi_samp)
    #print(concatenated_data)
    epi_data = nil.masking.intersect_masks(yoz)
    print("all done wit da intersextion (lol)")

    return epi_data

# %%
# find indices of where each condition occured in 10 runs for each sub
def fnd_indices(sub,behav_p):
    behav = pd.read_csv(os.path.join(behav_p, '%s_behav_cleaned.csv') % (sub))
    # Define the column in behav to be used for creating labels # 
    label = behav.iloc[:,1]
    # Create an array of labels [1] AND the order in which runs occured [0]#
    sub_ses_labels = label_lists(label, 200)
    ## Find run sequence, extraction condition indexes from behav data ## 
    return find_cond_index(sub_ses_labels[0])

# %%
# organize into dict
def org_bdata_dic(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b, in a dik
    
    """
    bold_dict = {}
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    bold_dict[cond_a] = a
    bold_dict[cond_b] = b
    
    print("concatenated", cond_a, cond_b)
    return bold_dict

# organize into list
def org_bdata_list(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b
    
    """
    bold_data = []
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    print("concatenated", cond_a, cond_b)
    return a + b

def org_bdata(unsort_bdata, run_indexes, cond_a, cond_b): 
    """
    organize two runs for concatenation
    Two runs of cond_a, then two runs of cond_b
    
    """
    bold_data = []
    a = [unsort_bdata[run_indexes[cond_a][0]], unsort_bdata[run_indexes[cond_a][1]]]
    b = [unsort_bdata[run_indexes[cond_b][0]], unsort_bdata[run_indexes[cond_b][1]]]
    print("returning", cond_a, cond_b)
    return np.asarray(a), np.asarray(b)

# %%
suffix = "_205_noproc.npy"

# load data into a dictionary
def load_smsc_fmri_list(sub,behav_p,cond_a,cond_b,suffix,int_mask):
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    #cats = load_fMRI3d(sub, 10, "MNI", 'space', int_mask)
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    return org_bdata_list(cats, lab_indic, cond_a, cond_b)

# Load data into dictionary
def load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask):
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    #cats = load_fMRI3d(sub, 10, "MNI", 'space', int_mask)
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    return org_bdata_dic(cats, lab_indic, cond_a, cond_b)

# %% [markdown]
# # Rest stuff

# %%
def create_event_list_rest(sub, bpress, cond, cond_alt, run_dic, base_onset,comp_onset_list,stim_dur):
    """
    this function reads in a condition for each sub
    and returns the corresponding b4 + after events
    
    sub: subject number
    bpress: array of button press onset times
    cond: which condition do you want to create event dataframe fore
    """
    all_tims = []
    events = {}
    # Convert alternate bpress to array #
    bpress_arr = np.asarray(bpress[sub][cond_alt])
    # Select runs to include according to run_dic, append
    # * include runs of rest 
    all_tims = all_tims + list(bpress_arr[run_dic[sub]['RE']])
    # how much to shift from button press onset
    
    ## create fake bpress for missing data if only one run ## 
    if len(all_tims) <2 and len(run_dic[sub]['RE']) >1:
        all_tims = list(all_tims[0], all_tims[0])
        
    return all_tims

# %%
def load_2conds_runs_fmri(sub,behav_p,cond_a,cond_b, run_dic, suffix="_205_noproc.npy"):
    """
    read in target conditions + subject info
    output: 2 runs of condition A, as they were presented, then two runs of condition B
    """
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True)) 
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    a, b = org_bdata(cats, lab_indic, cond_a, cond_b)
    # Get the indices of the runs to include #
    return list(a[run_dic[sub][cond_a]]), list(b[run_dic[sub][cond_b]])

# %%
def load_1cond_runs_fmri(sub,behav_p,cond_a, cond_b, run_dic, targ_run, suffix="_205_noproc.npy"):
    """
    read in target conditions + subject info
    output: 2 runs of condition A, as they were presented, then two runs of condition B
    """
    cats = list(np.load(load_fmri + sub + suffix, allow_pickle =True))
    # Find run labels from behavioral data
    lab_indic = fnd_indices(sub, behav_p)
    # Organize and concatenate bold data
    a, b = org_bdata(cats, lab_indic, cond_a, cond_b)
    # Get the indices of the runs to include #
    return list(a[run_dic[sub][cond_a]])

# %% [markdown]
# # Define Static VARS

# %%
####
data_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/bids/derivatives/fmriprep/"
#rois_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/work/rois/"
rois_dir = "/jukebox/graziano/coolCatIsaac/ATM/data/work/rois/results_masks/masks_mvpa"
behav_p = '/jukebox/graziano/coolCatIsaac/ATM/data/behavioral'
load_bpress = "/jukebox/graziano/coolCatIsaac/ATM/data/work/results/bpress_GLM/behav"
load_fmri = "/jukebox/graziano/coolCatIsaac/ATM/data/work/results/bpress_GLM/"
confounds = '/jukebox/graziano/coolCatIsaac/ATM/data/bids/derivatives/fmriprep/afni-head_mot/'
confounds_dir = '/jukebox/graziano/coolCatIsaac/ATM/data/work/workspace/censor_hm/'

# load whole brain mask
int_mask = nib.load('/jukebox/graziano/coolCatIsaac/ATM/data/work/workspace/load_fcma/mask_10r_n22-subs.nii.gz')

# %% [markdown]
# # dynamic vars

# %%
## sublist for rest ##
"""
no 5,8, 19, 26, 12
sub-005
 - 
sub-008

sub-019
- 
sub-012
- index range issue -- definitely due to the NO selection of runs for fMRI data -- we
select runs to be included for bpress data but not fMRI data -- need to edit
"""

### Rest Subs ### 
sub_list = ["sub-000", "sub-001","sub-002","sub-003","sub-004","sub-006","sub-007",
            "sub-009","sub-010","sub-011","sub-013","sub-014","sub-015", "sub-016","sub-017", 
            "sub-018","sub-020", "sub-021", "sub-022","sub-023","sub-024","sub-025","sub-027"]
## bad subs that do not work for rest ## 
sub_list = ["sub-000", "sub-001","sub-002","sub-003","sub-004",'sub-005', "sub-006","sub-007",'sub-008',
            "sub-009","sub-010","sub-011",'sub-012',"sub-013","sub-014","sub-015", "sub-016","sub-017", 
            "sub-018",'sub-019',"sub-020", "sub-021", "sub-022","sub-023","sub-024","sub-025", "sub-026","sub-027"]


## What threshold of head motion to extract ## 
hm_thresh = str(3)

## cluster coordinates to be extracted 
# coords = [(51,-42,44)]

# %%
len(sub_list)
# Out:
# 28

# %% [markdown]
# # bpress data

# %%
## Bpress behavioral data -- overlap removed ##
bpress = dict(enumerate(np.load(os.path.join(load_bpress, "n28_4_conds_ts_press_ovrlpREMOV.npy"), 
                                allow_pickle=True).flatten(),1))[1]

# %%
### runs to exclude with head motion accounted for and missing bpress runs deleted
run_dic = dict(enumerate(np.load(os.path.join(confounds_dir, "n28_runs_2_include_removNoBpress_delHMruns_threshp%s.npy") %(hm_thresh), 
                                allow_pickle=True).flatten(),1))[1]

# %% [markdown]
# # Confounds

# %%
conf_sub = dict(enumerate(np.load(os.path.join(confounds_dir, 'n28_conf+cens_MERGE_removNoBpress_delHMruns_threshp%s_glm.npy')%(hm_thresh), 
                                          allow_pickle = True).flatten(),1))[1]

# %% [markdown]
# # Create rest button presses

# %%
"""
for sub in sub_list:
    print(sub)
    temp = []
    events_b = create_event_list_rest(sub, bpress, "RE",cond_a,run_dic,base_onset,comp_onset_list,stim_dur)
    for runs in range(len(run_dic[sub]['RE'])):
        temp.append(events_b[runs])   
    bpress.setdefault(sub, {}).setdefault('RE',temp)
"""
# Out:
# '\nfor sub in sub_list:\n    print(sub)\n    temp = []\n    events_b = create_event_list_rest(sub, bpress, "RE",cond_a,run_dic,base_onset,comp_onset_list,stim_dur)\n    for runs in range(len(run_dic[sub][\'RE\'])):\n        temp.append(events_b[runs])   \n    bpress.setdefault(sub, {}).setdefault(\'RE\',temp)\n'

# %% [markdown]
# # ROI Info

# %%
"""
# sublist is set up top
# sub_list = ['sub-001']

# load in target ROI
# roi = ["l_prim_motor_sm_win2_mask"]
# roi = ["dmPFC_ovlp_mask"]
# roi = ["rTPJ_mask"]

roi = ["l_prim_motor_sm_win2_mask"]
tr = 1.5
high_pass = 1/128
roi_mask = load_roi_mask(roi[0], "MNI")

# REGRESS CONFOUNDS 
##** standardize = False ??? # 


masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                     standardize=True, detrend=True, high_pass=high_pass,
                    t_r=tr)
"""
# Out:
# '\n# sublist is set up top\n# sub_list = [\'sub-001\']\n\n# load in target ROI\n# roi = ["l_prim_motor_sm_win2_mask"]\n# roi = ["dmPFC_ovlp_mask"]\n# roi = ["rTPJ_mask"]\n\nroi = ["l_prim_motor_sm_win2_mask"]\ntr = 1.5\nhigh_pass = 1/128\nroi_mask = load_roi_mask(roi[0], "MNI")\n\n# REGRESS CONFOUNDS \n##** standardize = False ??? # \n\n\nmasker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,\n                     standardize=True, detrend=True, high_pass=high_pass,\n                    t_r=tr)\n'

# %% [markdown]
# # Define main function

# %%
def get_activations_tempnorm(sub_list, roi, roi_voxels, tr_range, cond_list):
    """
    Purpose:
        - extract activations from each ROI at each window, average two TRs within window
    Inputs:
        - sub_list: list of subs to iterate through
        - roi: which roi to extract activations 
        - roi_voxels: number of voxels for the selected ROI
        - tr_range: how many TRs should be averaged over?
        - cond_list: Which two conditions are we comparing
    Outputs:
        - X: Activations for every button press across subs for a given window 
        - Y: array of integers describing if button press is cond a (0) or cond b (1)
        - Groups: array of integers denoting button presses for each sub
    """
    # load in target ROI
    roi = roi
    high_pass = 1/128
    roi_mask = load_roi_mask(roi[0], "MNI")

    # Create masker object and REGRESS CONFOUNDS 
    masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                         standardize=True, detrend=True, high_pass=high_pass,t_r=1.5)

    ## X variable corresponds to a matrix that is: roi voxels x 
    X = np.empty((0, roi_voxels))
    ## Set subject array ## 
    group_id = 0
    groups = np.array([])
    ## set array for labels ## 
    y = np.array([])

    for sub in sub_list:
        ## Which conditions? ## 
        cond_a = cond_list[0]
        cond_b = cond_list[1]

        print(sub)
        # LOAD RUNS FOR COND A AND COND B
        fmri_imgs = load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask)
        # for each condition, extract patterns for each TR and average
        for sing_cond in cond_list:
            # for each run in available run dictionairy
            for run in range(len(run_dic[sub][sing_cond])):
                temp_run = []
                print("condition: ", sing_cond)
                #temp_pred = []
                print("run", run)

                # Fit the masker object to extract a 2d matrix: voxels x TR [454, 205]
                print("sub: ", sub)
                roi_act = masker.fit_transform(fmri_imgs[sing_cond][run], confounds = conf_sub[sub][sing_cond][run])
                print(roi_act.shape)


                # extract BPRESS behavioral data # 
                linez = bpress[sub][sing_cond][run]
                print("button press TRS:", linez)

                # Average activations 
                avg_activations = []
                
                # For each TR #
                for tr in linez:
                    # Find the tr that each onset occured - convert from seconds to TR
                    print(tr)
                    tr = round(tr/1.5)
                    print(tr)
                    temp = []
                    for i in tr_range:
                        try:
                            # IF tr exists in the range of TRs add to temp array before averaging in the next step
                            temp.append(roi_act[tr+i])
                        except:
                            continue
                    print("temp length: ", len(temp))
                    # If TRs exist for this button press, add it to the array # 
                    if (len(temp) > 0):
                        X = np.vstack((X, np.mean(temp, axis=0)))
                        print("X: ", X.shape)
                        groups = np.append(groups, group_id)
                        # note that I changed this to cond_a, cond_b
                        if (sing_cond == cond_a):
                            y = np.append(y, 0)

                        elif (sing_cond == cond_b):
                            y = np.append(y, 1)


        group_id = group_id + 1
    
    return X, y, groups

# %%
def get_activations_spacenorm(sub_list, roi, roi_voxels, tr_range, cond_list):
    """
    Purpose:
        - extract activations from each ROI at each window, average two TRs within window
        - ** only difference from above is we changed standardize to false **
    Inputs:
        - sub_list: list of subs to iterate through
        - roi: which roi to extract activations 
        - roi_voxels: number of voxels for the selected ROI
        - tr_range: how many TRs should be averaged over?
        - cond_list: Which two conditions are we comparing
    Outputs:
        - X: Activations for every button press across subs for a given window 
        - Y: array of integers describing if button press is cond a (0) or cond b (1)
        - Groups: array of integers denoting button presses for each sub
    """
    # load in target ROI
    high_pass = 1/128
    roi_mask = load_roi_mask(roi[0], "MNI")

    # Create masker object and REGRESS CONFOUNDS 
    masker = NiftiMasker(mask_img=roi_mask,smoothing_fwhm=2,
                         standardize=False, detrend=True, high_pass=high_pass,t_r=1.5)

    ## X variable corresponds to a matrix that is: roi voxels x 
    X = np.empty((0, roi_voxels))
    ## Set subject array ## 
    group_id = 0
    groups = np.array([])
    ## set array for labels ## 
    y = np.array([])

    for sub in sub_list:
        ## Which conditions? ## 
        cond_a = cond_list[0]
        cond_b = cond_list[1]

        print(sub)
        # LOAD RUNS FOR COND A AND COND B
        fmri_imgs = load_smsc_fmri_dic(sub,behav_p,cond_a,cond_b,suffix,int_mask)
        # for each condition, extract patterns for each TR and average
        for sing_cond in cond_list:
            # for each run in available run dictionairy
            for run in range(len(run_dic[sub][sing_cond])):
                temp_run = []
                print("condition: ", sing_cond)
                #temp_pred = []
                print("run", run)

                # Fit the masker object to extract a 2d matrix: voxels x TR [454, 205]
                print("sub: ", sub)
                roi_act = masker.fit_transform(fmri_imgs[sing_cond][run], confounds = conf_sub[sub][sing_cond][run])
                print(roi_act.shape)


                # extract BPRESS behavioral data # 
                linez = bpress[sub][sing_cond][run]
                print("button press TRS:", linez)

                # Average activations 
                avg_activations = []
                
                # For each TR #
                for tr in linez:
                    # Find the tr that each onset occured - convert from seconds to TR
                    print(tr)
                    tr = round(tr/1.5)
                    print(tr)
                    temp = []
                    for i in tr_range:
                        try:
                            # IF tr exists in the range of TRs add to temp array before averaging in the next step
                            temp.append(roi_act[tr+i])
                        except:
                            continue
                    print("temp length: ", len(temp))
                    # If TRs exist for this button press, add it to the array # 
                    if (len(temp) > 0):
                        X = np.vstack((X, np.mean(temp, axis=0)))
                        print("X: ", X.shape)
                        groups = np.append(groups, group_id)
                        # note that I changed this to cond_a, cond_b
                        if (sing_cond == cond_a):
                            y = np.append(y, 0)

                        elif (sing_cond == cond_b):
                            y = np.append(y, 1)


        group_id = group_id + 1
    
    return X, y, groups

# %% [markdown]
# # begin

# %%
# Top Directory
top_dir = '/jukebox/graziano/coolCatIsaac/ATM/code/analysis/MVPA/final'
act_dir = top_dir + '/activations'
perm_dir = top_dir +'/permutations'
perm_results = perm_dir + '/perm_results'

# %%
### Set RoI ## 
#roi_dict = {'motor': ["l_prim_motor_sm_win2_mask"], 'dmPFC': ["dmPFC_ovlp_mask"], 'rTPJ': ["rTPJ_mask"]}
#roi_dict = {'rTPJ_2' : ['RH_Cont_Par_2'], 'dmPFC': ["dmPFC_ovlp_mask"],'rTPJ': ["rTPJ_mask"]}
roi_dict = { 'dmPFC': ["dmPFC_ovlp_mask"],'rTPJ': ["rTPJ_mask"]}


cond_list = [['SM', 'SC'], ['OM', 'OC']]
voxels_dict = {'motor': 454, 'dmPFC': 112, 'rTPJ': 187, 'rTPJ_2': 198}

## Final 

tr_range_dict = {'1' : np.array([-2,-3]), '2' : np.array([0,-1]), '3' : np.array([1,2]), 
                 '4' : np.array([3,4]), '5' : np.array([5,6]), '6' : np.array([7,8]), 
                '7' : np.array([9,10]), '8' : np.array([11,12])}


### Save Vars ## 
date = '2023-06-06'
act_dict_name = f'roi_activations_final_n28_tempnorm_{date}'

# %%
#### CHECK BELOW FOR ZSCORE ####

# %%
for roi_name in roi_dict:
    roi = roi_dict[roi_name]
    print(roi_name)
    for conds in cond_list:
        print(conds)
        for window in tr_range_dict:
            print(f'window {window}')
            # Get activations ---- norm by space or time ? --- #
            X, y, g = get_activations_tempnorm(sub_list, roi, roi_voxels = voxels_dict[roi_name], 
                                      tr_range = tr_range_dict[window], cond_list = conds)
            ##### NORMALIZE ACROSS VOX ####
            #X = zscore(X, axis = 1)
            ###
            print(X.shape)
            print(y.shape)
            print(g.shape)
            
            print('now save')
            # set analysis # 
            analysis = '%s_%s_%s_win%s' %(conds[0], conds[1], roi_name, window)
            # Save act dic ## 
            if os.path.isfile(os.path.join(act_dir, '%s.npy') %(act_dict_name)):
                print('exists!')
                activations = np.load(os.path.join(act_dir, '%s.npy') %(act_dict_name ), allow_pickle=True).item()
            else:
                activations = {}
                print('creating dic')
            d2 = {"X": X, "y": y, "groups":g}
            activations[analysis] = d2
            np.save(os.path.join(act_dir, '%s.npy') %(act_dict_name), activations)
# Out:
# dmPFC
# ['SM', 'SC']
# window 1
# expected shape: 78, 93,65
# mask shape:  (78, 93, 65)
# Loaded dmPFC_ovlp_mask mask
# sub-000
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-000
# (205, 112)
# button press TRS: [ 94.6  115.6  154.02 221.83 269.04]
# 94.6
# 63
# temp length:  2
# X:  (1, 112)
# 115.6
# 77
# temp length:  2
# X:  (2, 112)
# 154.02
# 103
# temp length:  2
# X:  (3, 112)
# 221.83
# 148
# temp length:  2
# X:  (4, 112)
# 269.04
# 179
# temp length:  2
# X:  (5, 112)
# condition:  SM
# run 1
# sub:  sub-000
# (205, 112)
# button press TRS: [ 27.81  59.33  74.99 103.14 126.75 154.29 167.91 190.39 208.15 225.51
#  251.94 276.34 299.11]
# 27.81
# 19
# temp length:  2
# X:  (6, 112)
# 59.33
# 40
# temp length:  2
# X:  (7, 112)
# 74.99
# 50
# temp length:  2
# X:  (8, 112)
# 103.14
# 69
# temp length:  2
# X:  (9, 112)
# 126.75
# 84
# temp length:  2
# X:  (10, 112)
# 154.29
# 103
# temp length:  2
# X:  (11, 112)
# 167.91
# 112
# temp length:  2
# X:  (12, 112)
# 190.39
# 127
# temp length:  2
# X:  (13, 112)
# 208.15
# 139
# temp length:  2
# X:  (14, 112)
# 225.51
# 150
# temp length:  2
# X:  (15, 112)
# 251.94
# 168
# temp length:  2
# X:  (16, 112)
# 276.34
# 184
# temp length:  2
# X:  (17, 112)
# 299.11
# 199
# temp length:  2
# X:  (18, 112)
# condition:  SC
# run 0
# sub:  sub-000
# (205, 112)
# button press TRS: [ 24.51  47.41  70.55  96.8  124.51 152.11 182.5  214.31 252.61 281.45]
# 24.51
# 16
# temp length:  2
# X:  (19, 112)
# 47.41
# 32
# temp length:  2
# X:  (20, 112)
# 70.55
# 47
# temp length:  2
# X:  (21, 112)
# 96.8
# 65
# temp length:  2
# X:  (22, 112)
# 124.51
# 83
# temp length:  2
# X:  (23, 112)
# 152.11
# 101
# temp length:  2
# X:  (24, 112)
# 182.5
# 122
# temp length:  2
# X:  (25, 112)
# 214.31
# 143
# temp length:  2
# X:  (26, 112)
# 252.61
# 168
# temp length:  2
# X:  (27, 112)
# 281.45
# 188
# temp length:  2
# X:  (28, 112)
# condition:  SC
# run 1
# sub:  sub-000
# (205, 112)
# button press TRS: [ 21.66  42.06  63.67  88.93 118.27 150.12 187.09 216.3  255.31 299.71]
# 21.66
# 14
# temp length:  2
# X:  (29, 112)
# 42.06
# 28
# temp length:  2
# X:  (30, 112)
# 63.67
# 42
# temp length:  2
# X:  (31, 112)
# 88.93
# 59
# temp length:  2
# X:  (32, 112)
# 118.27
# 79
# temp length:  2
# X:  (33, 112)
# 150.12
# 100
# temp length:  2
# X:  (34, 112)
# 187.09
# 125
# temp length:  2
# X:  (35, 112)
# 216.3
# 144
# temp length:  2
# X:  (36, 112)
# 255.31
# 170
# temp length:  2
# X:  (37, 112)
# 299.71
# 200
# temp length:  2
# X:  (38, 112)
# sub-001
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-001
# (205, 112)
# button press TRS: [  7.8   30.85  53.28  67.01 116.3  144.7  162.57 178.74 200.63 230.38
#  247.79 262.98 290.36]
# 7.8
# 5
# temp length:  2
# X:  (39, 112)
# 30.85
# 21
# temp length:  2
# X:  (40, 112)
# 53.28
# 36
# temp length:  2
# X:  (41, 112)
# 67.01
# 45
# temp length:  2
# X:  (42, 112)
# 116.3
# 78
# temp length:  2
# X:  (43, 112)
# 144.7
# 96
# temp length:  2
# X:  (44, 112)
# 162.57
# 108
# temp length:  2
# X:  (45, 112)
# 178.74
# 119
# temp length:  2
# X:  (46, 112)
# 200.63
# 134
# temp length:  2
# X:  (47, 112)
# 230.38
# 154
# temp length:  2
# X:  (48, 112)
# 247.79
# 165
# temp length:  2
# X:  (49, 112)
# 262.98
# 175
# temp length:  2
# X:  (50, 112)
# 290.36
# 194
# temp length:  2
# X:  (51, 112)
# condition:  SM
# run 1
# sub:  sub-001
# (205, 112)
# button press TRS: [  2.58  21.65  27.5   47.7   72.38 107.04 145.3  167.35 193.33 228.28
#  261.19 273.19]
# 2.58
# 2
# temp length:  2
# X:  (52, 112)
# 21.65
# 14
# temp length:  2
# X:  (53, 112)
# 27.5
# 18
# temp length:  2
# X:  (54, 112)
# 47.7
# 32
# temp length:  2
# X:  (55, 112)
# 72.38
# 48
# temp length:  2
# X:  (56, 112)
# 107.04
# 71
# temp length:  2
# X:  (57, 112)
# 145.3
# 97
# temp length:  2
# X:  (58, 112)
# 167.35
# 112
# temp length:  2
# X:  (59, 112)
# 193.33
# 129
# temp length:  2
# X:  (60, 112)
# 228.28
# 152
# temp length:  2
# X:  (61, 112)
# 261.19
# 174
# temp length:  2
# X:  (62, 112)
# 273.19
# 182
# temp length:  2
# X:  (63, 112)
# condition:  SC
# run 0
# sub:  sub-001
# (205, 112)
# button press TRS: [ 42.98  85.26 121.66 161.35 196.7  228.55 254.42 285.95]
# 42.98
# 29
# temp length:  2
# X:  (64, 112)
# 85.26
# 57
# temp length:  2
# X:  (65, 112)
# 121.66
# 81
# temp length:  2
# X:  (66, 112)
# 161.35
# 108
# temp length:  2
# X:  (67, 112)
# 196.7
# 131
# temp length:  2
# X:  (68, 112)
# 228.55
# 152
# temp length:  2
# X:  (69, 112)
# 254.42
# 170
# temp length:  2
# X:  (70, 112)
# 285.95
# 191
# temp length:  2
# X:  (71, 112)
# condition:  SC
# run 1
# sub:  sub-001
# (205, 112)
# button press TRS: [ 40.25  74.61 102.55 132.45 164.88 197.5  226.1  254.84 288.92]
# 40.25
# 27
# temp length:  2
# X:  (72, 112)
# 74.61
# 50
# temp length:  2
# X:  (73, 112)
# 102.55
# 68
# temp length:  2
# X:  (74, 112)
# 132.45
# 88
# temp length:  2
# X:  (75, 112)
# 164.88
# 110
# temp length:  2
# X:  (76, 112)
# 197.5
# 132
# temp length:  2
# X:  (77, 112)
# 226.1
# 151
# temp length:  2
# X:  (78, 112)
# 254.84
# 170
# temp length:  2
# X:  (79, 112)
# 288.92
# 193
# temp length:  2
# X:  (80, 112)
# sub-002
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-002
# (205, 112)
# button press TRS: [  8.53  53.51 106.1  136.66 185.53 209.58 224.18 301.88]
# 8.53
# 6
# temp length:  2
# X:  (81, 112)
# 53.51
# 36
# temp length:  2
# X:  (82, 112)
# 106.1
# 71
# temp length:  2
# X:  (83, 112)
# 136.66
# 91
# temp length:  2
# X:  (84, 112)
# 185.53
# 124
# temp length:  2
# X:  (85, 112)
# 209.58
# 140
# temp length:  2
# X:  (86, 112)
# 224.18
# 149
# temp length:  2
# X:  (87, 112)
# 301.88
# 201
# temp length:  2
# X:  (88, 112)
# condition:  SC
# run 0
# sub:  sub-002
# (205, 112)
# button press TRS: [ 25.13  55.12  82.08 112.   136.19 166.12 178.45 212.87 232.25 258.56
#  280.85 307.3 ]
# 25.13
# 17
# temp length:  2
# X:  (89, 112)
# 55.12
# 37
# temp length:  2
# X:  (90, 112)
# 82.08
# 55
# temp length:  2
# X:  (91, 112)
# 112.0
# 75
# temp length:  2
# X:  (92, 112)
# 136.19
# 91
# temp length:  2
# X:  (93, 112)
# 166.12
# 111
# temp length:  2
# X:  (94, 112)
# 178.45
# 119
# temp length:  2
# X:  (95, 112)
# 212.87
# 142
# temp length:  2
# X:  (96, 112)
# 232.25
# 155
# temp length:  2
# X:  (97, 112)
# 258.56
# 172
# temp length:  2
# X:  (98, 112)
# 280.85
# 187
# temp length:  2
# X:  (99, 112)
# 307.3
# 205
# temp length:  2
# X:  (100, 112)
# condition:  SC
# run 1
# sub:  sub-002
# (205, 112)
# button press TRS: [ 23.68  55.33  79.99 116.44 146.47 174.11 203.37 257.88 292.36]
# 23.68
# 16
# temp length:  2
# X:  (101, 112)
# 55.33
# 37
# temp length:  2
# X:  (102, 112)
# 79.99
# 53
# temp length:  2
# X:  (103, 112)
# 116.44
# 78
# temp length:  2
# X:  (104, 112)
# 146.47
# 98
# temp length:  2
# X:  (105, 112)
# 174.11
# 116
# temp length:  2
# X:  (106, 112)
# 203.37
# 136
# temp length:  2
# X:  (107, 112)
# 257.88
# 172
# temp length:  2
# X:  (108, 112)
# 292.36
# 195
# temp length:  2
# X:  (109, 112)
# sub-003
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-003
# (205, 112)
# button press TRS: [ 51.47  86.66 125.07 144.52 187.05 231.54 286.57]
# 51.47
# 34
# temp length:  2
# X:  (110, 112)
# 86.66
# 58
# temp length:  2
# X:  (111, 112)
# 125.07
# 83
# temp length:  2
# X:  (112, 112)
# 144.52
# 96
# temp length:  2
# X:  (113, 112)
# 187.05
# 125
# temp length:  2
# X:  (114, 112)
# 231.54
# 154
# temp length:  2
# X:  (115, 112)
# 286.57
# 191
# temp length:  2
# X:  (116, 112)
# condition:  SM
# run 1
# sub:  sub-003
# (205, 112)
# button press TRS: [ 28.29  47.47  73.32 104.27 117.57 162.55 210.47 227.62 243.59 277.45
#  299.87]
# 28.29
# 19
# temp length:  2
# X:  (117, 112)
# 47.47
# 32
# temp length:  2
# X:  (118, 112)
# 73.32
# 49
# temp length:  2
# X:  (119, 112)
# 104.27
# 70
# temp length:  2
# X:  (120, 112)
# 117.57
# 78
# temp length:  2
# X:  (121, 112)
# 162.55
# 108
# temp length:  2
# X:  (122, 112)
# 210.47
# 140
# temp length:  2
# X:  (123, 112)
# 227.62
# 152
# temp length:  2
# X:  (124, 112)
# 243.59
# 162
# temp length:  2
# X:  (125, 112)
# 277.45
# 185
# temp length:  2
# X:  (126, 112)
# 299.87
# 200
# temp length:  2
# X:  (127, 112)
# condition:  SC
# run 0
# sub:  sub-003
# (205, 112)
# button press TRS: [ 20.37  45.95  71.57  96.39 120.17 146.97 172.67 198.49 226.2  253.3
#  280.37 306.93]
# 20.37
# 14
# temp length:  2
# X:  (128, 112)
# 45.95
# 31
# temp length:  2
# X:  (129, 112)
# 71.57
# 48
# temp length:  2
# X:  (130, 112)
# 96.39
# 64
# temp length:  2
# X:  (131, 112)
# 120.17
# 80
# temp length:  2
# X:  (132, 112)
# 146.97
# 98
# temp length:  2
# X:  (133, 112)
# 172.67
# 115
# temp length:  2
# X:  (134, 112)
# 198.49
# 132
# temp length:  2
# X:  (135, 112)
# 226.2
# 151
# temp length:  2
# X:  (136, 112)
# 253.3
# 169
# temp length:  2
# X:  (137, 112)
# 280.37
# 187
# temp length:  2
# X:  (138, 112)
# 306.93
# 205
# temp length:  2
# X:  (139, 112)
# condition:  SC
# run 1
# sub:  sub-003
# (205, 112)
# button press TRS: [ 26.04  55.24  82.49 109.91 142.12 173.92 206.52 238.3  268.42 295.35]
# 26.04
# 17
# temp length:  2
# X:  (140, 112)
# 55.24
# 37
# temp length:  2
# X:  (141, 112)
# 82.49
# 55
# temp length:  2
# X:  (142, 112)
# 109.91
# 73
# temp length:  2
# X:  (143, 112)
# 142.12
# 95
# temp length:  2
# X:  (144, 112)
# 173.92
# 116
# temp length:  2
# X:  (145, 112)
# 206.52
# 138
# temp length:  2
# X:  (146, 112)
# 238.3
# 159
# temp length:  2
# X:  (147, 112)
# 268.42
# 179
# temp length:  2
# X:  (148, 112)
# 295.35
# 197
# temp length:  2
# X:  (149, 112)
# sub-004
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-004
# (205, 112)
# button press TRS: [ 80.65 144.76 212.08 261.59 294.76]
# 80.65
# 54
# temp length:  2
# X:  (150, 112)
# 144.76
# 97
# temp length:  2
# X:  (151, 112)
# 212.08
# 141
# temp length:  2
# X:  (152, 112)
# 261.59
# 174
# temp length:  2
# X:  (153, 112)
# 294.76
# 197
# temp length:  2
# X:  (154, 112)
# condition:  SM
# run 1
# sub:  sub-004
# (205, 112)
# button press TRS: [ 39.56  69.99  86.32 103.37 134.38 148.8  170.88 188.15 205.13 222.53
#  238.37 258.02 272.16 284.57 300.58]
# 39.56
# 26
# temp length:  2
# X:  (155, 112)
# 69.99
# 47
# temp length:  2
# X:  (156, 112)
# 86.32
# 58
# temp length:  2
# X:  (157, 112)
# 103.37
# 69
# temp length:  2
# X:  (158, 112)
# 134.38
# 90
# temp length:  2
# X:  (159, 112)
# 148.8
# 99
# temp length:  2
# X:  (160, 112)
# 170.88
# 114
# temp length:  2
# X:  (161, 112)
# 188.15
# 125
# temp length:  2
# X:  (162, 112)
# 205.13
# 137
# temp length:  2
# X:  (163, 112)
# 222.53
# 148
# temp length:  2
# X:  (164, 112)
# 238.37
# 159
# temp length:  2
# X:  (165, 112)
# 258.02
# 172
# temp length:  2
# X:  (166, 112)
# 272.16
# 181
# temp length:  2
# X:  (167, 112)
# 284.57
# 190
# temp length:  2
# X:  (168, 112)
# 300.58
# 200
# temp length:  2
# X:  (169, 112)
# condition:  SC
# run 0
# sub:  sub-004
# (205, 112)
# button press TRS: [ 18.28  37.75  54.77  71.11  88.27 104.54 121.74 137.73 155.52 172.64
#  189.77 206.53 222.51 237.14 254.9  273.37 292.08]
# 18.28
# 12
# temp length:  2
# X:  (170, 112)
# 37.75
# 25
# temp length:  2
# X:  (171, 112)
# 54.77
# 37
# temp length:  2
# X:  (172, 112)
# 71.11
# 47
# temp length:  2
# X:  (173, 112)
# 88.27
# 59
# temp length:  2
# X:  (174, 112)
# 104.54
# 70
# temp length:  2
# X:  (175, 112)
# 121.74
# 81
# temp length:  2
# X:  (176, 112)
# 137.73
# 92
# temp length:  2
# X:  (177, 112)
# 155.52
# 104
# temp length:  2
# X:  (178, 112)
# 172.64
# 115
# temp length:  2
# X:  (179, 112)
# 189.77
# 127
# temp length:  2
# X:  (180, 112)
# 206.53
# 138
# temp length:  2
# X:  (181, 112)
# 222.51
# 148
# temp length:  2
# X:  (182, 112)
# 237.14
# 158
# temp length:  2
# X:  (183, 112)
# 254.9
# 170
# temp length:  2
# X:  (184, 112)
# 273.37
# 182
# temp length:  2
# X:  (185, 112)
# 292.08
# 195
# temp length:  2
# X:  (186, 112)
# condition:  SC
# run 1
# sub:  sub-004
# (205, 112)
# button press TRS: [ 20.32  36.63  52.94  71.46  88.05 105.7  121.53 141.96 157.6  174.38
#  192.   208.07 228.53 241.04 258.58 275.33 291.89 307.08]
# 20.32
# 14
# temp length:  2
# X:  (187, 112)
# 36.63
# 24
# temp length:  2
# X:  (188, 112)
# 52.94
# 35
# temp length:  2
# X:  (189, 112)
# 71.46
# 48
# temp length:  2
# X:  (190, 112)
# 88.05
# 59
# temp length:  2
# X:  (191, 112)
# 105.7
# 70
# temp length:  2
# X:  (192, 112)
# 121.53
# 81
# temp length:  2
# X:  (193, 112)
# 141.96
# 95
# temp length:  2
# X:  (194, 112)
# 157.6
# 105
# temp length:  2
# X:  (195, 112)
# 174.38
# 116
# temp length:  2
# X:  (196, 112)
# 192.0
# 128
# temp length:  2
# X:  (197, 112)
# 208.07
# 139
# temp length:  2
# X:  (198, 112)
# 228.53
# 152
# temp length:  2
# X:  (199, 112)
# 241.04
# 161
# temp length:  2
# X:  (200, 112)
# 258.58
# 172
# temp length:  2
# X:  (201, 112)
# 275.33
# 184
# temp length:  2
# X:  (202, 112)
# 291.89
# 195
# temp length:  2
# X:  (203, 112)
# 307.08
# 205
# temp length:  2
# X:  (204, 112)
# sub-005
# concatenated SM SC
# sub-006
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-006
# (205, 112)
# button press TRS: [ 16.92  50.91  78.77  97.28 113.34 151.33 172.77 192.95 217.45 230.03
#  246.78 300.4 ]
# 16.92
# 11
# temp length:  2
# X:  (205, 112)
# 50.91
# 34
# temp length:  2
# X:  (206, 112)
# 78.77
# 53
# temp length:  2
# X:  (207, 112)
# 97.28
# 65
# temp length:  2
# X:  (208, 112)
# 113.34
# 76
# temp length:  2
# X:  (209, 112)
# 151.33
# 101
# temp length:  2
# X:  (210, 112)
# 172.77
# 115
# temp length:  2
# X:  (211, 112)
# 192.95
# 129
# temp length:  2
# X:  (212, 112)
# 217.45
# 145
# temp length:  2
# X:  (213, 112)
# 230.03
# 153
# temp length:  2
# X:  (214, 112)
# 246.78
# 165
# temp length:  2
# X:  (215, 112)
# 300.4
# 200
# temp length:  2
# X:  (216, 112)
# condition:  SC
# run 0
# sub:  sub-006
# (205, 112)
# button press TRS: [ 31.63  60.23  74.45 103.45 133.76 162.38 187.1  213.76 243.08 262.99
#  280.07 295.16]
# 31.63
# 21
# temp length:  2
# X:  (217, 112)
# 60.23
# 40
# temp length:  2
# X:  (218, 112)
# 74.45
# 50
# temp length:  2
# X:  (219, 112)
# 103.45
# 69
# temp length:  2
# X:  (220, 112)
# 133.76
# 89
# temp length:  2
# X:  (221, 112)
# 162.38
# 108
# temp length:  2
# X:  (222, 112)
# 187.1
# 125
# temp length:  2
# X:  (223, 112)
# 213.76
# 143
# temp length:  2
# X:  (224, 112)
# 243.08
# 162
# temp length:  2
# X:  (225, 112)
# 262.99
# 175
# temp length:  2
# X:  (226, 112)
# 280.07
# 187
# temp length:  2
# X:  (227, 112)
# 295.16
# 197
# temp length:  2
# X:  (228, 112)
# sub-007
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-007
# (205, 112)
# button press TRS: [ 32.45  45.02  71.66  92.11 112.67 130.2  151.35 168.27 196.03 214.27
#  245.18 268.42 300.35]
# 32.45
# 22
# temp length:  2
# X:  (229, 112)
# 45.02
# 30
# temp length:  2
# X:  (230, 112)
# 71.66
# 48
# temp length:  2
# X:  (231, 112)
# 92.11
# 61
# temp length:  2
# X:  (232, 112)
# 112.67
# 75
# temp length:  2
# X:  (233, 112)
# 130.2
# 87
# temp length:  2
# X:  (234, 112)
# 151.35
# 101
# temp length:  2
# X:  (235, 112)
# 168.27
# 112
# temp length:  2
# X:  (236, 112)
# 196.03
# 131
# temp length:  2
# X:  (237, 112)
# 214.27
# 143
# temp length:  2
# X:  (238, 112)
# 245.18
# 163
# temp length:  2
# X:  (239, 112)
# 268.42
# 179
# temp length:  2
# X:  (240, 112)
# 300.35
# 200
# temp length:  2
# X:  (241, 112)
# condition:  SC
# run 0
# sub:  sub-007
# (205, 112)
# button press TRS: [ 22.07  43.51  66.91  87.13 104.76 118.98 136.4  153.63 178.91 196.49
#  217.33 236.59 253.09 267.98 297.73]
# 22.07
# 15
# temp length:  2
# X:  (242, 112)
# 43.51
# 29
# temp length:  2
# X:  (243, 112)
# 66.91
# 45
# temp length:  2
# X:  (244, 112)
# 87.13
# 58
# temp length:  2
# X:  (245, 112)
# 104.76
# 70
# temp length:  2
# X:  (246, 112)
# 118.98
# 79
# temp length:  2
# X:  (247, 112)
# 136.4
# 91
# temp length:  2
# X:  (248, 112)
# 153.63
# 102
# temp length:  2
# X:  (249, 112)
# 178.91
# 119
# temp length:  2
# X:  (250, 112)
# 196.49
# 131
# temp length:  2
# X:  (251, 112)
# 217.33
# 145
# temp length:  2
# X:  (252, 112)
# 236.59
# 158
# temp length:  2
# X:  (253, 112)
# 253.09
# 169
# temp length:  2
# X:  (254, 112)
# 267.98
# 179
# temp length:  2
# X:  (255, 112)
# 297.73
# 198
# temp length:  2
# X:  (256, 112)
# sub-008
# concatenated SM SC
# condition:  SC
# run 0
# sub:  sub-008
# (205, 112)
# button press TRS: [ 23.6   38.66  60.68  88.31 156.35 168.56 191.98 203.03 215.67 247.73
#  274.07 305.77]
# 23.6
# 16
# temp length:  2
# X:  (257, 112)
# 38.66
# 26
# temp length:  2
# X:  (258, 112)
# 60.68
# 40
# temp length:  2
# X:  (259, 112)
# 88.31
# 59
# temp length:  2
# X:  (260, 112)
# 156.35
# 104
# temp length:  2
# X:  (261, 112)
# 168.56
# 112
# temp length:  2
# X:  (262, 112)
# 191.98
# 128
# temp length:  2
# X:  (263, 112)
# 203.03
# 135
# temp length:  2
# X:  (264, 112)
# 215.67
# 144
# temp length:  2
# X:  (265, 112)
# 247.73
# 165
# temp length:  2
# X:  (266, 112)
# 274.07
# 183
# temp length:  2
# X:  (267, 112)
# 305.77
# 204
# temp length:  2
# X:  (268, 112)
# sub-009
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-009
# (205, 112)
# button press TRS: [295.65]
# 295.65
# 197
# temp length:  2
# X:  (269, 112)
# condition:  SM
# run 1
# sub:  sub-009
# (205, 112)
# button press TRS: [155.73]
# 155.73
# 104
# temp length:  2
# X:  (270, 112)
# condition:  SC
# run 0
# sub:  sub-009
# (205, 112)
# button press TRS: [ 16.26  47.62  82.82 116.9  180.35 209.74 235.32 261.82 292.33]
# 16.26
# 11
# temp length:  2
# X:  (271, 112)
# 47.62
# 32
# temp length:  2
# X:  (272, 112)
# 82.82
# 55
# temp length:  2
# X:  (273, 112)
# 116.9
# 78
# temp length:  2
# X:  (274, 112)
# 180.35
# 120
# temp length:  2
# X:  (275, 112)
# 209.74
# 140
# temp length:  2
# X:  (276, 112)
# 235.32
# 157
# temp length:  2
# X:  (277, 112)
# 261.82
# 175
# temp length:  2
# X:  (278, 112)
# 292.33
# 195
# temp length:  2
# X:  (279, 112)
# condition:  SC
# run 1
# sub:  sub-009
# (205, 112)
# button press TRS: [ 17.61  37.44  67.8   86.62 105.22 125.22 147.62 160.42 189.5  226.45
#  262.21 275.92 303.08]
# 17.61
# 12
# temp length:  2
# X:  (280, 112)
# 37.44
# 25
# temp length:  2
# X:  (281, 112)
# 67.8
# 45
# temp length:  2
# X:  (282, 112)
# 86.62
# 58
# temp length:  2
# X:  (283, 112)
# 105.22
# 70
# temp length:  2
# X:  (284, 112)
# 125.22
# 83
# temp length:  2
# X:  (285, 112)
# 147.62
# 98
# temp length:  2
# X:  (286, 112)
# 160.42
# 107
# temp length:  2
# X:  (287, 112)
# 189.5
# 126
# temp length:  2
# X:  (288, 112)
# 226.45
# 151
# temp length:  2
# X:  (289, 112)
# 262.21
# 175
# temp length:  2
# X:  (290, 112)
# 275.92
# 184
# temp length:  2
# X:  (291, 112)
# 303.08
# 202
# temp length:  2
# X:  (292, 112)
# sub-010
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-010
# (205, 112)
# button press TRS: [ 98.22 111.64 129.42 152.83 173.19 197.08 215.15 240.35 256.09 283.57
#  298.53]
# 98.22
# 65
# temp length:  2
# X:  (293, 112)
# 111.64
# 74
# temp length:  2
# X:  (294, 112)
# 129.42
# 86
# temp length:  2
# X:  (295, 112)
# 152.83
# 102
# temp length:  2
# X:  (296, 112)
# 173.19
# 115
# temp length:  2
# X:  (297, 112)
# 197.08
# 131
# temp length:  2
# X:  (298, 112)
# 215.15
# 143
# temp length:  2
# X:  (299, 112)
# 240.35
# 160
# temp length:  2
# X:  (300, 112)
# 256.09
# 171
# temp length:  2
# X:  (301, 112)
# 283.57
# 189
# temp length:  2
# X:  (302, 112)
# 298.53
# 199
# temp length:  2
# X:  (303, 112)
# condition:  SC
# run 0
# sub:  sub-010
# (205, 112)
# button press TRS: [ 29.56  57.32  83.79 108.42 132.67 154.82 177.13 199.97 221.99 248.53
#  271.6  290.59]
# 29.56
# 20
# temp length:  2
# X:  (304, 112)
# 57.32
# 38
# temp length:  2
# X:  (305, 112)
# 83.79
# 56
# temp length:  2
# X:  (306, 112)
# 108.42
# 72
# temp length:  2
# X:  (307, 112)
# 132.67
# 88
# temp length:  2
# X:  (308, 112)
# 154.82
# 103
# temp length:  2
# X:  (309, 112)
# 177.13
# 118
# temp length:  2
# X:  (310, 112)
# 199.97
# 133
# temp length:  2
# X:  (311, 112)
# 221.99
# 148
# temp length:  2
# X:  (312, 112)
# 248.53
# 166
# temp length:  2
# X:  (313, 112)
# 271.6
# 181
# temp length:  2
# X:  (314, 112)
# 290.59
# 194
# temp length:  2
# X:  (315, 112)
# condition:  SC
# run 1
# sub:  sub-010
# (205, 112)
# button press TRS: [ 30.35  60.82  98.77 139.62 165.29 215.73 229.3  262.03]
# 30.35
# 20
# temp length:  2
# X:  (316, 112)
# 60.82
# 41
# temp length:  2
# X:  (317, 112)
# 98.77
# 66
# temp length:  2
# X:  (318, 112)
# 139.62
# 93
# temp length:  2
# X:  (319, 112)
# 165.29
# 110
# temp length:  2
# X:  (320, 112)
# 215.73
# 144
# temp length:  2
# X:  (321, 112)
# 229.3
# 153
# temp length:  2
# X:  (322, 112)
# 262.03
# 175
# temp length:  2
# X:  (323, 112)
# sub-011
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-011
# (205, 112)
# button press TRS: [ 79.59 107.83 121.13 140.12 172.77 194.25 204.45 228.97 248.29 262.37
#  278.92 289.04 302.34]
# 79.59
# 53
# temp length:  2
# X:  (324, 112)
# 107.83
# 72
# temp length:  2
# X:  (325, 112)
# 121.13
# 81
# temp length:  2
# X:  (326, 112)
# 140.12
# 93
# temp length:  2
# X:  (327, 112)
# 172.77
# 115
# temp length:  2
# X:  (328, 112)
# 194.25
# 130
# temp length:  2
# X:  (329, 112)
# 204.45
# 136
# temp length:  2
# X:  (330, 112)
# 228.97
# 153
# temp length:  2
# X:  (331, 112)
# 248.29
# 166
# temp length:  2
# X:  (332, 112)
# 262.37
# 175
# temp length:  2
# X:  (333, 112)
# 278.92
# 186
# temp length:  2
# X:  (334, 112)
# 289.04
# 193
# temp length:  2
# X:  (335, 112)
# 302.34
# 202
# temp length:  2
# X:  (336, 112)
# condition:  SC
# run 0
# sub:  sub-011
# (205, 112)
# button press TRS: [ 30.85  63.47  90.11 121.29 136.75 159.65 216.39 252.34 275.34 302.92]
# 30.85
# 21
# temp length:  2
# X:  (337, 112)
# 63.47
# 42
# temp length:  2
# X:  (338, 112)
# 90.11
# 60
# temp length:  2
# X:  (339, 112)
# 121.29
# 81
# temp length:  2
# X:  (340, 112)
# 136.75
# 91
# temp length:  2
# X:  (341, 112)
# 159.65
# 106
# temp length:  2
# X:  (342, 112)
# 216.39
# 144
# temp length:  2
# X:  (343, 112)
# 252.34
# 168
# temp length:  2
# X:  (344, 112)
# 275.34
# 184
# temp length:  2
# X:  (345, 112)
# 302.92
# 202
# temp length:  2
# X:  (346, 112)
# condition:  SC
# run 1
# sub:  sub-011
# (205, 112)
# button press TRS: [ 30.28  64.8   84.83  99.13 115.55 165.65 211.09 240.84]
# 30.28
# 20
# temp length:  2
# X:  (347, 112)
# 64.8
# 43
# temp length:  2
# X:  (348, 112)
# 84.83
# 57
# temp length:  2
# X:  (349, 112)
# 99.13
# 66
# temp length:  2
# X:  (350, 112)
# 115.55
# 77
# temp length:  2
# X:  (351, 112)
# 165.65
# 110
# temp length:  2
# X:  (352, 112)
# 211.09
# 141
# temp length:  2
# X:  (353, 112)
# 240.84
# 161
# temp length:  2
# X:  (354, 112)
# sub-012
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-012
# (205, 112)
# button press TRS: [ 73.74 101.85 121.07 147.64 160.26 173.57 197.   210.94 238.45 298.8 ]
# 73.74
# 49
# temp length:  2
# X:  (355, 112)
# 101.85
# 68
# temp length:  2
# X:  (356, 112)
# 121.07
# 81
# temp length:  2
# X:  (357, 112)
# 147.64
# 98
# temp length:  2
# X:  (358, 112)
# 160.26
# 107
# temp length:  2
# X:  (359, 112)
# 173.57
# 116
# temp length:  2
# X:  (360, 112)
# 197.0
# 131
# temp length:  2
# X:  (361, 112)
# 210.94
# 141
# temp length:  2
# X:  (362, 112)
# 238.45
# 159
# temp length:  2
# X:  (363, 112)
# 298.8
# 199
# temp length:  2
# X:  (364, 112)
# condition:  SM
# run 1
# sub:  sub-012
# (205, 112)
# button press TRS: [ 48.    76.57  92.56 124.4  149.25 175.01 187.68 209.7  226.4  247.68]
# 48.0
# 32
# temp length:  2
# X:  (365, 112)
# 76.57
# 51
# temp length:  2
# X:  (366, 112)
# 92.56
# 62
# temp length:  2
# X:  (367, 112)
# 124.4
# 83
# temp length:  2
# X:  (368, 112)
# 149.25
# 100
# temp length:  2
# X:  (369, 112)
# 175.01
# 117
# temp length:  2
# X:  (370, 112)
# 187.68
# 125
# temp length:  2
# X:  (371, 112)
# 209.7
# 140
# temp length:  2
# X:  (372, 112)
# 226.4
# 151
# temp length:  2
# X:  (373, 112)
# 247.68
# 165
# temp length:  2
# X:  (374, 112)
# condition:  SC
# run 0
# sub:  sub-012
# (205, 112)
# button press TRS: [ 17.78  34.12  50.57  66.17  80.72  96.69 114.32 130.5  148.68 165.37
#  181.42 198.58 214.02 229.4  244.2  258.96 274.24 292.12 307.15]
# 17.78
# 12
# temp length:  2
# X:  (375, 112)
# 34.12
# 23
# temp length:  2
# X:  (376, 112)
# 50.57
# 34
# temp length:  2
# X:  (377, 112)
# 66.17
# 44
# temp length:  2
# X:  (378, 112)
# 80.72
# 54
# temp length:  2
# X:  (379, 112)
# 96.69
# 64
# temp length:  2
# X:  (380, 112)
# 114.32
# 76
# temp length:  2
# X:  (381, 112)
# 130.5
# 87
# temp length:  2
# X:  (382, 112)
# 148.68
# 99
# temp length:  2
# X:  (383, 112)
# 165.37
# 110
# temp length:  2
# X:  (384, 112)
# 181.42
# 121
# temp length:  2
# X:  (385, 112)
# 198.58
# 132
# temp length:  2
# X:  (386, 112)
# 214.02
# 143
# temp length:  2
# X:  (387, 112)
# 229.4
# 153
# temp length:  2
# X:  (388, 112)
# 244.2
# 163
# temp length:  2
# X:  (389, 112)
# 258.96
# 173
# temp length:  2
# X:  (390, 112)
# 274.24
# 183
# temp length:  2
# X:  (391, 112)
# 292.12
# 195
# temp length:  2
# X:  (392, 112)
# 307.15
# 205
# temp length:  2
# X:  (393, 112)
# sub-013
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-013
# (205, 112)
# button press TRS: [ 41.34  57.06  83.98 102.17 162.49 183.97 203.82 223.54 237.75 251.78
#  278.54 298.29]
# 41.34
# 28
# temp length:  2
# X:  (394, 112)
# 57.06
# 38
# temp length:  2
# X:  (395, 112)
# 83.98
# 56
# temp length:  2
# X:  (396, 112)
# 102.17
# 68
# temp length:  2
# X:  (397, 112)
# 162.49
# 108
# temp length:  2
# X:  (398, 112)
# 183.97
# 123
# temp length:  2
# X:  (399, 112)
# 203.82
# 136
# temp length:  2
# X:  (400, 112)
# 223.54
# 149
# temp length:  2
# X:  (401, 112)
# 237.75
# 158
# temp length:  2
# X:  (402, 112)
# 251.78
# 168
# temp length:  2
# X:  (403, 112)
# 278.54
# 186
# temp length:  2
# X:  (404, 112)
# 298.29
# 199
# temp length:  2
# X:  (405, 112)
# condition:  SM
# run 1
# sub:  sub-013
# (205, 112)
# button press TRS: [ 59.05  80.29 105.75 162.98 199.12 220.54 238.   263.01 291.14]
# 59.05
# 39
# temp length:  2
# X:  (406, 112)
# 80.29
# 54
# temp length:  2
# X:  (407, 112)
# 105.75
# 70
# temp length:  2
# X:  (408, 112)
# 162.98
# 109
# temp length:  2
# X:  (409, 112)
# 199.12
# 133
# temp length:  2
# X:  (410, 112)
# 220.54
# 147
# temp length:  2
# X:  (411, 112)
# 238.0
# 159
# temp length:  2
# X:  (412, 112)
# 263.01
# 175
# temp length:  2
# X:  (413, 112)
# 291.14
# 194
# temp length:  2
# X:  (414, 112)
# condition:  SC
# run 0
# sub:  sub-013
# (205, 112)
# button press TRS: [ 33.06  63.05  92.78 123.32 152.88 170.41 193.06 211.15 235.2  253.67
#  272.69 303.31]
# 33.06
# 22
# temp length:  2
# X:  (415, 112)
# 63.05
# 42
# temp length:  2
# X:  (416, 112)
# 92.78
# 62
# temp length:  2
# X:  (417, 112)
# 123.32
# 82
# temp length:  2
# X:  (418, 112)
# 152.88
# 102
# temp length:  2
# X:  (419, 112)
# 170.41
# 114
# temp length:  2
# X:  (420, 112)
# 193.06
# 129
# temp length:  2
# X:  (421, 112)
# 211.15
# 141
# temp length:  2
# X:  (422, 112)
# 235.2
# 157
# temp length:  2
# X:  (423, 112)
# 253.67
# 169
# temp length:  2
# X:  (424, 112)
# 272.69
# 182
# temp length:  2
# X:  (425, 112)
# 303.31
# 202
# temp length:  2
# X:  (426, 112)
# condition:  SC
# run 1
# sub:  sub-013
# (205, 112)
# button press TRS: [ 38.76  98.83 158.95 208.32 268.29]
# 38.76
# 26
# temp length:  2
# X:  (427, 112)
# 98.83
# 66
# temp length:  2
# X:  (428, 112)
# 158.95
# 106
# temp length:  2
# X:  (429, 112)
# 208.32
# 139
# temp length:  2
# X:  (430, 112)
# 268.29
# 179
# temp length:  2
# X:  (431, 112)
# sub-014
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-014
# (205, 112)
# button press TRS: [129.91]
# 129.91
# 87
# temp length:  2
# X:  (432, 112)
# condition:  SM
# run 1
# sub:  sub-014
# (205, 112)
# button press TRS: [ 57.96  88.03 129.75 166.09 194.74 238.75 263.3  289.58]
# 57.96
# 39
# temp length:  2
# X:  (433, 112)
# 88.03
# 59
# temp length:  2
# X:  (434, 112)
# 129.75
# 86
# temp length:  2
# X:  (435, 112)
# 166.09
# 111
# temp length:  2
# X:  (436, 112)
# 194.74
# 130
# temp length:  2
# X:  (437, 112)
# 238.75
# 159
# temp length:  2
# X:  (438, 112)
# 263.3
# 176
# temp length:  2
# X:  (439, 112)
# 289.58
# 193
# temp length:  2
# X:  (440, 112)
# condition:  SC
# run 0
# sub:  sub-014
# (205, 112)
# button press TRS: [ 24.39  43.57  64.42  87.19 105.75 124.9  144.   163.59 181.43 216.9
#  234.58 262.85 277.4  292.59]
# 24.39
# 16
# temp length:  2
# X:  (441, 112)
# 43.57
# 29
# temp length:  2
# X:  (442, 112)
# 64.42
# 43
# temp length:  2
# X:  (443, 112)
# 87.19
# 58
# temp length:  2
# X:  (444, 112)
# 105.75
# 70
# temp length:  2
# X:  (445, 112)
# 124.9
# 83
# temp length:  2
# X:  (446, 112)
# 144.0
# 96
# temp length:  2
# X:  (447, 112)
# 163.59
# 109
# temp length:  2
# X:  (448, 112)
# 181.43
# 121
# temp length:  2
# X:  (449, 112)
# 216.9
# 145
# temp length:  2
# X:  (450, 112)
# 234.58
# 156
# temp length:  2
# X:  (451, 112)
# 262.85
# 175
# temp length:  2
# X:  (452, 112)
# 277.4
# 185
# temp length:  2
# X:  (453, 112)
# 292.59
# 195
# temp length:  2
# X:  (454, 112)
# condition:  SC
# run 1
# sub:  sub-014
# (205, 112)
# button press TRS: [ 20.49  45.99  71.34  92.86 116.85 139.07 158.54 179.34 203.55 225.35
#  240.55 265.75 287.22 305.04]
# 20.49
# 14
# temp length:  2
# X:  (455, 112)
# 45.99
# 31
# temp length:  2
# X:  (456, 112)
# 71.34
# 48
# temp length:  2
# X:  (457, 112)
# 92.86
# 62
# temp length:  2
# X:  (458, 112)
# 116.85
# 78
# temp length:  2
# X:  (459, 112)
# 139.07
# 93
# temp length:  2
# X:  (460, 112)
# 158.54
# 106
# temp length:  2
# X:  (461, 112)
# 179.34
# 120
# temp length:  2
# X:  (462, 112)
# 203.55
# 136
# temp length:  2
# X:  (463, 112)
# 225.35
# 150
# temp length:  2
# X:  (464, 112)
# 240.55
# 160
# temp length:  2
# X:  (465, 112)
# 265.75
# 177
# temp length:  2
# X:  (466, 112)
# 287.22
# 191
# temp length:  2
# X:  (467, 112)
# 305.04
# 203
# temp length:  2
# X:  (468, 112)
# sub-015
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-015
# (205, 112)
# button press TRS: [ 18.95  54.48  94.07 131.29 157.22 197.36 214.43 227.44 245.44 281.
#  302.88]
# 18.95
# 13
# temp length:  2
# X:  (469, 112)
# 54.48
# 36
# temp length:  2
# X:  (470, 112)
# 94.07
# 63
# temp length:  2
# X:  (471, 112)
# 131.29
# 88
# temp length:  2
# X:  (472, 112)
# 157.22
# 105
# temp length:  2
# X:  (473, 112)
# 197.36
# 132
# temp length:  2
# X:  (474, 112)
# 214.43
# 143
# temp length:  2
# X:  (475, 112)
# 227.44
# 152
# temp length:  2
# X:  (476, 112)
# 245.44
# 164
# temp length:  2
# X:  (477, 112)
# 281.0
# 187
# temp length:  2
# X:  (478, 112)
# 302.88
# 202
# temp length:  2
# X:  (479, 112)
# condition:  SM
# run 1
# sub:  sub-015
# (205, 112)
# button press TRS: [ 39.49  53.95  93.72 121.87 143.72 158.22 210.37 234.88 247.98 268.54
#  289.01]
# 39.49
# 26
# temp length:  2
# X:  (480, 112)
# 53.95
# 36
# temp length:  2
# X:  (481, 112)
# 93.72
# 62
# temp length:  2
# X:  (482, 112)
# 121.87
# 81
# temp length:  2
# X:  (483, 112)
# 143.72
# 96
# temp length:  2
# X:  (484, 112)
# 158.22
# 105
# temp length:  2
# X:  (485, 112)
# 210.37
# 140
# temp length:  2
# X:  (486, 112)
# 234.88
# 157
# temp length:  2
# X:  (487, 112)
# 247.98
# 165
# temp length:  2
# X:  (488, 112)
# 268.54
# 179
# temp length:  2
# X:  (489, 112)
# 289.01
# 193
# temp length:  2
# X:  (490, 112)
# condition:  SC
# run 0
# sub:  sub-015
# (205, 112)
# button press TRS: [ 14.25  29.15  44.05  59.    74.01  89.2  104.   119.09 134.08 149.01
#  164.04 178.91 194.07 209.06 223.89 238.97 253.95 269.21 284.23 299.37]
# 14.25
# 10
# temp length:  2
# X:  (491, 112)
# 29.15
# 19
# temp length:  2
# X:  (492, 112)
# 44.05
# 29
# temp length:  2
# X:  (493, 112)
# 59.0
# 39
# temp length:  2
# X:  (494, 112)
# 74.01
# 49
# temp length:  2
# X:  (495, 112)
# 89.2
# 59
# temp length:  2
# X:  (496, 112)
# 104.0
# 69
# temp length:  2
# X:  (497, 112)
# 119.09
# 79
# temp length:  2
# X:  (498, 112)
# 134.08
# 89
# temp length:  2
# X:  (499, 112)
# 149.01
# 99
# temp length:  2
# X:  (500, 112)
# 164.04
# 109
# temp length:  2
# X:  (501, 112)
# 178.91
# 119
# temp length:  2
# X:  (502, 112)
# 194.07
# 129
# temp length:  2
# X:  (503, 112)
# 209.06
# 139
# temp length:  2
# X:  (504, 112)
# 223.89
# 149
# temp length:  2
# X:  (505, 112)
# 238.97
# 159
# temp length:  2
# X:  (506, 112)
# 253.95
# 169
# temp length:  2
# X:  (507, 112)
# 269.21
# 179
# temp length:  2
# X:  (508, 112)
# 284.23
# 189
# temp length:  2
# X:  (509, 112)
# 299.37
# 200
# temp length:  2
# X:  (510, 112)
# condition:  SC
# run 1
# sub:  sub-015
# (205, 112)
# button press TRS: [ 13.98  28.95  43.87  59.12  73.87  89.16 103.77 119.62 134.19 148.94
#  163.89 179.02 194.09 208.97 221.1  236.17 251.3  266.02 280.83 296.06]
# 13.98
# 9
# temp length:  2
# X:  (511, 112)
# 28.95
# 19
# temp length:  2
# X:  (512, 112)
# 43.87
# 29
# temp length:  2
# X:  (513, 112)
# 59.12
# 39
# temp length:  2
# X:  (514, 112)
# 73.87
# 49
# temp length:  2
# X:  (515, 112)
# 89.16
# 59
# temp length:  2
# X:  (516, 112)
# 103.77
# 69
# temp length:  2
# X:  (517, 112)
# 119.62
# 80
# temp length:  2
# X:  (518, 112)
# 134.19
# 89
# temp length:  2
# X:  (519, 112)
# 148.94
# 99
# temp length:  2
# X:  (520, 112)
# 163.89
# 109
# temp length:  2
# X:  (521, 112)
# 179.02
# 119
# temp length:  2
# X:  (522, 112)
# 194.09
# 129
# temp length:  2
# X:  (523, 112)
# 208.97
# 139
# temp length:  2
# X:  (524, 112)
# 221.1
# 147
# temp length:  2
# X:  (525, 112)
# 236.17
# 157
# temp length:  2
# X:  (526, 112)
# 251.3
# 168
# temp length:  2
# X:  (527, 112)
# 266.02
# 177
# temp length:  2
# X:  (528, 112)
# 280.83
# 187
# temp length:  2
# X:  (529, 112)
# 296.06
# 197
# temp length:  2
# X:  (530, 112)
# sub-016
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-016
# (205, 112)
# button press TRS: [ 26.49  62.43  76.12  95.15 117.18 145.22 193.75 220.63 264.68 291.24]
# 26.49
# 18
# temp length:  2
# X:  (531, 112)
# 62.43
# 42
# temp length:  2
# X:  (532, 112)
# 76.12
# 51
# temp length:  2
# X:  (533, 112)
# 95.15
# 63
# temp length:  2
# X:  (534, 112)
# 117.18
# 78
# temp length:  2
# X:  (535, 112)
# 145.22
# 97
# temp length:  2
# X:  (536, 112)
# 193.75
# 129
# temp length:  2
# X:  (537, 112)
# 220.63
# 147
# temp length:  2
# X:  (538, 112)
# 264.68
# 176
# temp length:  2
# X:  (539, 112)
# 291.24
# 194
# temp length:  2
# X:  (540, 112)
# condition:  SM
# run 1
# sub:  sub-016
# (205, 112)
# button press TRS: [ 18.12  41.49  53.62  73.57  91.2  109.62 135.8  157.28 181.04 206.07
#  256.5  274.35 298.34]
# 18.12
# 12
# temp length:  2
# X:  (541, 112)
# 41.49
# 28
# temp length:  2
# X:  (542, 112)
# 53.62
# 36
# temp length:  2
# X:  (543, 112)
# 73.57
# 49
# temp length:  2
# X:  (544, 112)
# 91.2
# 61
# temp length:  2
# X:  (545, 112)
# 109.62
# 73
# temp length:  2
# X:  (546, 112)
# 135.8
# 91
# temp length:  2
# X:  (547, 112)
# 157.28
# 105
# temp length:  2
# X:  (548, 112)
# 181.04
# 121
# temp length:  2
# X:  (549, 112)
# 206.07
# 137
# temp length:  2
# X:  (550, 112)
# 256.5
# 171
# temp length:  2
# X:  (551, 112)
# 274.35
# 183
# temp length:  2
# X:  (552, 112)
# 298.34
# 199
# temp length:  2
# X:  (553, 112)
# condition:  SC
# run 0
# sub:  sub-016
# (205, 112)
# button press TRS: [ 22.32  40.3   56.12  69.26  82.53  95.97 108.18 126.82 140.57 168.02
#  181.82 208.17 224.52 239.63 254.5  273.84 286.06 300.91]
# 22.32
# 15
# temp length:  2
# X:  (554, 112)
# 40.3
# 27
# temp length:  2
# X:  (555, 112)
# 56.12
# 37
# temp length:  2
# X:  (556, 112)
# 69.26
# 46
# temp length:  2
# X:  (557, 112)
# 82.53
# 55
# temp length:  2
# X:  (558, 112)
# 95.97
# 64
# temp length:  2
# X:  (559, 112)
# 108.18
# 72
# temp length:  2
# X:  (560, 112)
# 126.82
# 85
# temp length:  2
# X:  (561, 112)
# 140.57
# 94
# temp length:  2
# X:  (562, 112)
# 168.02
# 112
# temp length:  2
# X:  (563, 112)
# 181.82
# 121
# temp length:  2
# X:  (564, 112)
# 208.17
# 139
# temp length:  2
# X:  (565, 112)
# 224.52
# 150
# temp length:  2
# X:  (566, 112)
# 239.63
# 160
# temp length:  2
# X:  (567, 112)
# 254.5
# 170
# temp length:  2
# X:  (568, 112)
# 273.84
# 183
# temp length:  2
# X:  (569, 112)
# 286.06
# 191
# temp length:  2
# X:  (570, 112)
# 300.91
# 201
# temp length:  2
# X:  (571, 112)
# condition:  SC
# run 1
# sub:  sub-016
# (205, 112)
# button press TRS: [ 19.25  37.52  67.85  80.32  92.34 108.08 128.57 161.68 176.48 205.18
#  230.4 ]
# 19.25
# 13
# temp length:  2
# X:  (572, 112)
# 37.52
# 25
# temp length:  2
# X:  (573, 112)
# 67.85
# 45
# temp length:  2
# X:  (574, 112)
# 80.32
# 54
# temp length:  2
# X:  (575, 112)
# 92.34
# 62
# temp length:  2
# X:  (576, 112)
# 108.08
# 72
# temp length:  2
# X:  (577, 112)
# 128.57
# 86
# temp length:  2
# X:  (578, 112)
# 161.68
# 108
# temp length:  2
# X:  (579, 112)
# 176.48
# 118
# temp length:  2
# X:  (580, 112)
# 205.18
# 137
# temp length:  2
# X:  (581, 112)
# 230.4
# 154
# temp length:  2
# X:  (582, 112)
# sub-017
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-017
# (205, 112)
# button press TRS: [ 96.05 135.82 175.5  213.07 236.15 257.95 300.7 ]
# 96.05
# 64
# temp length:  2
# X:  (583, 112)
# 135.82
# 91
# temp length:  2
# X:  (584, 112)
# 175.5
# 117
# temp length:  2
# X:  (585, 112)
# 213.07
# 142
# temp length:  2
# X:  (586, 112)
# 236.15
# 157
# temp length:  2
# X:  (587, 112)
# 257.95
# 172
# temp length:  2
# X:  (588, 112)
# 300.7
# 200
# temp length:  2
# X:  (589, 112)
# condition:  SM
# run 1
# sub:  sub-017
# (205, 112)
# button press TRS: [ 29.37  67.53 106.2  127.17 155.85 167.87 192.92 208.   228.85 252.69
#  279.92 300.45]
# 29.37
# 20
# temp length:  2
# X:  (590, 112)
# 67.53
# 45
# temp length:  2
# X:  (591, 112)
# 106.2
# 71
# temp length:  2
# X:  (592, 112)
# 127.17
# 85
# temp length:  2
# X:  (593, 112)
# 155.85
# 104
# temp length:  2
# X:  (594, 112)
# 167.87
# 112
# temp length:  2
# X:  (595, 112)
# 192.92
# 129
# temp length:  2
# X:  (596, 112)
# 208.0
# 139
# temp length:  2
# X:  (597, 112)
# 228.85
# 153
# temp length:  2
# X:  (598, 112)
# 252.69
# 168
# temp length:  2
# X:  (599, 112)
# 279.92
# 187
# temp length:  2
# X:  (600, 112)
# 300.45
# 200
# temp length:  2
# X:  (601, 112)
# condition:  SC
# run 0
# sub:  sub-017
# (205, 112)
# button press TRS: [ 32.11  61.7   94.66 127.38 159.91 187.95 218.49 248.87 279.18]
# 32.11
# 21
# temp length:  2
# X:  (602, 112)
# 61.7
# 41
# temp length:  2
# X:  (603, 112)
# 94.66
# 63
# temp length:  2
# X:  (604, 112)
# 127.38
# 85
# temp length:  2
# X:  (605, 112)
# 159.91
# 107
# temp length:  2
# X:  (606, 112)
# 187.95
# 125
# temp length:  2
# X:  (607, 112)
# 218.49
# 146
# temp length:  2
# X:  (608, 112)
# 248.87
# 166
# temp length:  2
# X:  (609, 112)
# 279.18
# 186
# temp length:  2
# X:  (610, 112)
# sub-018
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-018
# (205, 112)
# button press TRS: [ 82.38 122.97 206.33 245.09]
# 82.38
# 55
# temp length:  2
# X:  (611, 112)
# 122.97
# 82
# temp length:  2
# X:  (612, 112)
# 206.33
# 138
# temp length:  2
# X:  (613, 112)
# 245.09
# 163
# temp length:  2
# X:  (614, 112)
# condition:  SM
# run 1
# sub:  sub-018
# (205, 112)
# button press TRS: [ 53.05 123.74 182.08 233.53]
# 53.05
# 35
# temp length:  2
# X:  (615, 112)
# 123.74
# 82
# temp length:  2
# X:  (616, 112)
# 182.08
# 121
# temp length:  2
# X:  (617, 112)
# 233.53
# 156
# temp length:  2
# X:  (618, 112)
# condition:  SC
# run 0
# sub:  sub-018
# (205, 112)
# button press TRS: [ 35.68  75.37 110.9  144.72 179.89 214.61 243.57 276.68 306.11]
# 35.68
# 24
# temp length:  2
# X:  (619, 112)
# 75.37
# 50
# temp length:  2
# X:  (620, 112)
# 110.9
# 74
# temp length:  2
# X:  (621, 112)
# 144.72
# 96
# temp length:  2
# X:  (622, 112)
# 179.89
# 120
# temp length:  2
# X:  (623, 112)
# 214.61
# 143
# temp length:  2
# X:  (624, 112)
# 243.57
# 162
# temp length:  2
# X:  (625, 112)
# 276.68
# 184
# temp length:  2
# X:  (626, 112)
# 306.11
# 204
# temp length:  2
# X:  (627, 112)
# condition:  SC
# run 1
# sub:  sub-018
# (205, 112)
# button press TRS: [ 26.65  59.55  99.6  136.57 174.8  208.2  247.35 280.55]
# 26.65
# 18
# temp length:  2
# X:  (628, 112)
# 59.55
# 40
# temp length:  2
# X:  (629, 112)
# 99.6
# 66
# temp length:  2
# X:  (630, 112)
# 136.57
# 91
# temp length:  2
# X:  (631, 112)
# 174.8
# 117
# temp length:  2
# X:  (632, 112)
# 208.2
# 139
# temp length:  2
# X:  (633, 112)
# 247.35
# 165
# temp length:  2
# X:  (634, 112)
# 280.55
# 187
# temp length:  2
# X:  (635, 112)
# sub-019
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-019
# (205, 112)
# button press TRS: [ 82.58 172.3  223.21 253.43]
# 82.58
# 55
# temp length:  2
# X:  (636, 112)
# 172.3
# 115
# temp length:  2
# X:  (637, 112)
# 223.21
# 149
# temp length:  2
# X:  (638, 112)
# 253.43
# 169
# temp length:  2
# X:  (639, 112)
# condition:  SC
# run 0
# sub:  sub-019
# (205, 112)
# button press TRS: [  4.56  35.03  71.81 112.   136.35 163.08 176.45 211.93 236.78 250.44
#  266.98 283.88 300.76]
# 4.56
# 3
# temp length:  2
# X:  (640, 112)
# 35.03
# 23
# temp length:  2
# X:  (641, 112)
# 71.81
# 48
# temp length:  2
# X:  (642, 112)
# 112.0
# 75
# temp length:  2
# X:  (643, 112)
# 136.35
# 91
# temp length:  2
# X:  (644, 112)
# 163.08
# 109
# temp length:  2
# X:  (645, 112)
# 176.45
# 118
# temp length:  2
# X:  (646, 112)
# 211.93
# 141
# temp length:  2
# X:  (647, 112)
# 236.78
# 158
# temp length:  2
# X:  (648, 112)
# 250.44
# 167
# temp length:  2
# X:  (649, 112)
# 266.98
# 178
# temp length:  2
# X:  (650, 112)
# 283.88
# 189
# temp length:  2
# X:  (651, 112)
# 300.76
# 201
# temp length:  2
# X:  (652, 112)
# condition:  SC
# run 1
# sub:  sub-019
# (205, 112)
# button press TRS: [ 16.25  31.77  45.26  59.85  73.96 104.63 121.88 187.39 208.81 228.38
#  241.81 255.06 268.9  297.11]
# 16.25
# 11
# temp length:  2
# X:  (653, 112)
# 31.77
# 21
# temp length:  2
# X:  (654, 112)
# 45.26
# 30
# temp length:  2
# X:  (655, 112)
# 59.85
# 40
# temp length:  2
# X:  (656, 112)
# 73.96
# 49
# temp length:  2
# X:  (657, 112)
# 104.63
# 70
# temp length:  2
# X:  (658, 112)
# 121.88
# 81
# temp length:  2
# X:  (659, 112)
# 187.39
# 125
# temp length:  2
# X:  (660, 112)
# 208.81
# 139
# temp length:  2
# X:  (661, 112)
# 228.38
# 152
# temp length:  2
# X:  (662, 112)
# 241.81
# 161
# temp length:  2
# X:  (663, 112)
# 255.06
# 170
# temp length:  2
# X:  (664, 112)
# 268.9
# 179
# temp length:  2
# X:  (665, 112)
# 297.11
# 198
# temp length:  2
# X:  (666, 112)
# sub-020
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-020
# (205, 112)
# button press TRS: [ 72.72 111.13 131.81 157.68 171.93 231.8  246.2  274.37 293.93]
# 72.72
# 48
# temp length:  2
# X:  (667, 112)
# 111.13
# 74
# temp length:  2
# X:  (668, 112)
# 131.81
# 88
# temp length:  2
# X:  (669, 112)
# 157.68
# 105
# temp length:  2
# X:  (670, 112)
# 171.93
# 115
# temp length:  2
# X:  (671, 112)
# 231.8
# 155
# temp length:  2
# X:  (672, 112)
# 246.2
# 164
# temp length:  2
# X:  (673, 112)
# 274.37
# 183
# temp length:  2
# X:  (674, 112)
# 293.93
# 196
# temp length:  2
# X:  (675, 112)
# condition:  SM
# run 1
# sub:  sub-020
# (205, 112)
# button press TRS: [ 50.5   77.4  102.37 118.94 131.74 156.85 170.07 184.28 197.78 221.13
#  241.48 274.3 ]
# 50.5
# 34
# temp length:  2
# X:  (676, 112)
# 77.4
# 52
# temp length:  2
# X:  (677, 112)
# 102.37
# 68
# temp length:  2
# X:  (678, 112)
# 118.94
# 79
# temp length:  2
# X:  (679, 112)
# 131.74
# 88
# temp length:  2
# X:  (680, 112)
# 156.85
# 105
# temp length:  2
# X:  (681, 112)
# 170.07
# 113
# temp length:  2
# X:  (682, 112)
# 184.28
# 123
# temp length:  2
# X:  (683, 112)
# 197.78
# 132
# temp length:  2
# X:  (684, 112)
# 221.13
# 147
# temp length:  2
# X:  (685, 112)
# 241.48
# 161
# temp length:  2
# X:  (686, 112)
# 274.3
# 183
# temp length:  2
# X:  (687, 112)
# condition:  SC
# run 0
# sub:  sub-020
# (205, 112)
# button press TRS: [ 26.15  54.02  78.17 104.   128.64 154.94 177.42 203.12 222.34 246.28
#  284.12 303.04]
# 26.15
# 17
# temp length:  2
# X:  (688, 112)
# 54.02
# 36
# temp length:  2
# X:  (689, 112)
# 78.17
# 52
# temp length:  2
# X:  (690, 112)
# 104.0
# 69
# temp length:  2
# X:  (691, 112)
# 128.64
# 86
# temp length:  2
# X:  (692, 112)
# 154.94
# 103
# temp length:  2
# X:  (693, 112)
# 177.42
# 118
# temp length:  2
# X:  (694, 112)
# 203.12
# 135
# temp length:  2
# X:  (695, 112)
# 222.34
# 148
# temp length:  2
# X:  (696, 112)
# 246.28
# 164
# temp length:  2
# X:  (697, 112)
# 284.12
# 189
# temp length:  2
# X:  (698, 112)
# 303.04
# 202
# temp length:  2
# X:  (699, 112)
# condition:  SC
# run 1
# sub:  sub-020
# (205, 112)
# button press TRS: [ 22.4   40.76  58.39  76.25  92.09 121.97 137.04 151.78 165.73 190.2
#  253.87 273.14 305.2 ]
# 22.4
# 15
# temp length:  2
# X:  (700, 112)
# 40.76
# 27
# temp length:  2
# X:  (701, 112)
# 58.39
# 39
# temp length:  2
# X:  (702, 112)
# 76.25
# 51
# temp length:  2
# X:  (703, 112)
# 92.09
# 61
# temp length:  2
# X:  (704, 112)
# 121.97
# 81
# temp length:  2
# X:  (705, 112)
# 137.04
# 91
# temp length:  2
# X:  (706, 112)
# 151.78
# 101
# temp length:  2
# X:  (707, 112)
# 165.73
# 110
# temp length:  2
# X:  (708, 112)
# 190.2
# 127
# temp length:  2
# X:  (709, 112)
# 253.87
# 169
# temp length:  2
# X:  (710, 112)
# 273.14
# 182
# temp length:  2
# X:  (711, 112)
# 305.2
# 203
# temp length:  2
# X:  (712, 112)
# sub-021
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-021
# (205, 112)
# button press TRS: [  9.3   32.5   52.35  74.14  99.87 112.43 143.53 168.58 185.18 209.83
#  226.1  240.33 266.27 281.32]
# 9.3
# 6
# temp length:  2
# X:  (713, 112)
# 32.5
# 22
# temp length:  2
# X:  (714, 112)
# 52.35
# 35
# temp length:  2
# X:  (715, 112)
# 74.14
# 49
# temp length:  2
# X:  (716, 112)
# 99.87
# 67
# temp length:  2
# X:  (717, 112)
# 112.43
# 75
# temp length:  2
# X:  (718, 112)
# 143.53
# 96
# temp length:  2
# X:  (719, 112)
# 168.58
# 112
# temp length:  2
# X:  (720, 112)
# 185.18
# 123
# temp length:  2
# X:  (721, 112)
# 209.83
# 140
# temp length:  2
# X:  (722, 112)
# 226.1
# 151
# temp length:  2
# X:  (723, 112)
# 240.33
# 160
# temp length:  2
# X:  (724, 112)
# 266.27
# 178
# temp length:  2
# X:  (725, 112)
# 281.32
# 188
# temp length:  2
# X:  (726, 112)
# condition:  SM
# run 1
# sub:  sub-021
# (205, 112)
# button press TRS: [  6.92  26.99  41.78  58.5   86.78 108.07 136.74 153.25 171.08 185.42
#  198.06 211.   224.54 236.79 257.35 277.88 294.43]
# 6.92
# 5
# temp length:  2
# X:  (727, 112)
# 26.99
# 18
# temp length:  2
# X:  (728, 112)
# 41.78
# 28
# temp length:  2
# X:  (729, 112)
# 58.5
# 39
# temp length:  2
# X:  (730, 112)
# 86.78
# 58
# temp length:  2
# X:  (731, 112)
# 108.07
# 72
# temp length:  2
# X:  (732, 112)
# 136.74
# 91
# temp length:  2
# X:  (733, 112)
# 153.25
# 102
# temp length:  2
# X:  (734, 112)
# 171.08
# 114
# temp length:  2
# X:  (735, 112)
# 185.42
# 124
# temp length:  2
# X:  (736, 112)
# 198.06
# 132
# temp length:  2
# X:  (737, 112)
# 211.0
# 141
# temp length:  2
# X:  (738, 112)
# 224.54
# 150
# temp length:  2
# X:  (739, 112)
# 236.79
# 158
# temp length:  2
# X:  (740, 112)
# 257.35
# 172
# temp length:  2
# X:  (741, 112)
# 277.88
# 185
# temp length:  2
# X:  (742, 112)
# 294.43
# 196
# temp length:  2
# X:  (743, 112)
# condition:  SC
# run 0
# sub:  sub-021
# (205, 112)
# button press TRS: [ 19.68  35.27  49.95  65.16  80.24  95.07 109.77 125.25 140.07 155.23
#  170.22 184.79 201.63 216.7  243.28 259.27 271.3  287.12 302.05]
# 19.68
# 13
# temp length:  2
# X:  (744, 112)
# 35.27
# 24
# temp length:  2
# X:  (745, 112)
# 49.95
# 33
# temp length:  2
# X:  (746, 112)
# 65.16
# 43
# temp length:  2
# X:  (747, 112)
# 80.24
# 53
# temp length:  2
# X:  (748, 112)
# 95.07
# 63
# temp length:  2
# X:  (749, 112)
# 109.77
# 73
# temp length:  2
# X:  (750, 112)
# 125.25
# 84
# temp length:  2
# X:  (751, 112)
# 140.07
# 93
# temp length:  2
# X:  (752, 112)
# 155.23
# 103
# temp length:  2
# X:  (753, 112)
# 170.22
# 113
# temp length:  2
# X:  (754, 112)
# 184.79
# 123
# temp length:  2
# X:  (755, 112)
# 201.63
# 134
# temp length:  2
# X:  (756, 112)
# 216.7
# 144
# temp length:  2
# X:  (757, 112)
# 243.28
# 162
# temp length:  2
# X:  (758, 112)
# 259.27
# 173
# temp length:  2
# X:  (759, 112)
# 271.3
# 181
# temp length:  2
# X:  (760, 112)
# 287.12
# 191
# temp length:  2
# X:  (761, 112)
# 302.05
# 201
# temp length:  2
# X:  (762, 112)
# condition:  SC
# run 1
# sub:  sub-021
# (205, 112)
# button press TRS: [ 15.74  31.06  45.72  75.62  89.85 104.11 119.23 131.53 149.2  173.99
#  201.53 215.75 234.54 247.6  274.39 287.07 300.66]
# 15.74
# 10
# temp length:  2
# X:  (763, 112)
# 31.06
# 21
# temp length:  2
# X:  (764, 112)
# 45.72
# 30
# temp length:  2
# X:  (765, 112)
# 75.62
# 50
# temp length:  2
# X:  (766, 112)
# 89.85
# 60
# temp length:  2
# X:  (767, 112)
# 104.11
# 69
# temp length:  2
# X:  (768, 112)
# 119.23
# 79
# temp length:  2
# X:  (769, 112)
# 131.53
# 88
# temp length:  2
# X:  (770, 112)
# 149.2
# 99
# temp length:  2
# X:  (771, 112)
# 173.99
# 116
# temp length:  2
# X:  (772, 112)
# 201.53
# 134
# temp length:  2
# X:  (773, 112)
# 215.75
# 144
# temp length:  2
# X:  (774, 112)
# 234.54
# 156
# temp length:  2
# X:  (775, 112)
# 247.6
# 165
# temp length:  2
# X:  (776, 112)
# 274.39
# 183
# temp length:  2
# X:  (777, 112)
# 287.07
# 191
# temp length:  2
# X:  (778, 112)
# 300.66
# 200
# temp length:  2
# X:  (779, 112)
# sub-022
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-022
# (205, 112)
# button press TRS: [ 75.91  97.45 141.7  173.18 224.04 266.33 279.56 294.89]
# 75.91
# 51
# temp length:  2
# X:  (780, 112)
# 97.45
# 65
# temp length:  2
# X:  (781, 112)
# 141.7
# 94
# temp length:  2
# X:  (782, 112)
# 173.18
# 115
# temp length:  2
# X:  (783, 112)
# 224.04
# 149
# temp length:  2
# X:  (784, 112)
# 266.33
# 178
# temp length:  2
# X:  (785, 112)
# 279.56
# 186
# temp length:  2
# X:  (786, 112)
# 294.89
# 197
# temp length:  2
# X:  (787, 112)
# condition:  SM
# run 1
# sub:  sub-022
# (205, 112)
# button press TRS: [ 62.57  78.72  98.95 126.7  145.73 170.84 192.2  206.73 221.29 226.91
#  236.98 260.68 277.33 297.16 304.43]
# 62.57
# 42
# temp length:  2
# X:  (788, 112)
# 78.72
# 52
# temp length:  2
# X:  (789, 112)
# 98.95
# 66
# temp length:  2
# X:  (790, 112)
# 126.7
# 84
# temp length:  2
# X:  (791, 112)
# 145.73
# 97
# temp length:  2
# X:  (792, 112)
# 170.84
# 114
# temp length:  2
# X:  (793, 112)
# 192.2
# 128
# temp length:  2
# X:  (794, 112)
# 206.73
# 138
# temp length:  2
# X:  (795, 112)
# 221.29
# 148
# temp length:  2
# X:  (796, 112)
# 226.91
# 151
# temp length:  2
# X:  (797, 112)
# 236.98
# 158
# temp length:  2
# X:  (798, 112)
# 260.68
# 174
# temp length:  2
# X:  (799, 112)
# 277.33
# 185
# temp length:  2
# X:  (800, 112)
# 297.16
# 198
# temp length:  2
# X:  (801, 112)
# 304.43
# 203
# temp length:  2
# X:  (802, 112)
# condition:  SC
# run 0
# sub:  sub-022
# (205, 112)
# button press TRS: [ 22.03  47.42  74.46  99.18 127.43 153.06 180.13 206.81 233.38 256.23
#  283.93 307.47]
# 22.03
# 15
# temp length:  2
# X:  (803, 112)
# 47.42
# 32
# temp length:  2
# X:  (804, 112)
# 74.46
# 50
# temp length:  2
# X:  (805, 112)
# 99.18
# 66
# temp length:  2
# X:  (806, 112)
# 127.43
# 85
# temp length:  2
# X:  (807, 112)
# 153.06
# 102
# temp length:  2
# X:  (808, 112)
# 180.13
# 120
# temp length:  2
# X:  (809, 112)
# 206.81
# 138
# temp length:  2
# X:  (810, 112)
# 233.38
# 156
# temp length:  2
# X:  (811, 112)
# 256.23
# 171
# temp length:  2
# X:  (812, 112)
# 283.93
# 189
# temp length:  2
# X:  (813, 112)
# 307.47
# 205
# temp length:  2
# X:  (814, 112)
# sub-023
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-023
# (205, 112)
# button press TRS: [ 67.09 118.82 136.05 186.52 207.78 242.37]
# 67.09
# 45
# temp length:  2
# X:  (815, 112)
# 118.82
# 79
# temp length:  2
# X:  (816, 112)
# 136.05
# 91
# temp length:  2
# X:  (817, 112)
# 186.52
# 124
# temp length:  2
# X:  (818, 112)
# 207.78
# 139
# temp length:  2
# X:  (819, 112)
# 242.37
# 162
# temp length:  2
# X:  (820, 112)
# condition:  SM
# run 1
# sub:  sub-023
# (205, 112)
# button press TRS: [ 64.87  94.17 128.58 157.12 195.4  236.03 291.57]
# 64.87
# 43
# temp length:  2
# X:  (821, 112)
# 94.17
# 63
# temp length:  2
# X:  (822, 112)
# 128.58
# 86
# temp length:  2
# X:  (823, 112)
# 157.12
# 105
# temp length:  2
# X:  (824, 112)
# 195.4
# 130
# temp length:  2
# X:  (825, 112)
# 236.03
# 157
# temp length:  2
# X:  (826, 112)
# 291.57
# 194
# temp length:  2
# X:  (827, 112)
# condition:  SC
# run 0
# sub:  sub-023
# (205, 112)
# button press TRS: [ 22.1   44.67  68.83  99.25 128.72 157.31 187.37 214.78 243.63 277.25]
# 22.1
# 15
# temp length:  2
# X:  (828, 112)
# 44.67
# 30
# temp length:  2
# X:  (829, 112)
# 68.83
# 46
# temp length:  2
# X:  (830, 112)
# 99.25
# 66
# temp length:  2
# X:  (831, 112)
# 128.72
# 86
# temp length:  2
# X:  (832, 112)
# 157.31
# 105
# temp length:  2
# X:  (833, 112)
# 187.37
# 125
# temp length:  2
# X:  (834, 112)
# 214.78
# 143
# temp length:  2
# X:  (835, 112)
# 243.63
# 162
# temp length:  2
# X:  (836, 112)
# 277.25
# 185
# temp length:  2
# X:  (837, 112)
# condition:  SC
# run 1
# sub:  sub-023
# (205, 112)
# button press TRS: [ 23.53  50.35  74.88  99.71 123.32 151.11 180.3  210.18 239.55 267.08
#  297.95]
# 23.53
# 16
# temp length:  2
# X:  (838, 112)
# 50.35
# 34
# temp length:  2
# X:  (839, 112)
# 74.88
# 50
# temp length:  2
# X:  (840, 112)
# 99.71
# 66
# temp length:  2
# X:  (841, 112)
# 123.32
# 82
# temp length:  2
# X:  (842, 112)
# 151.11
# 101
# temp length:  2
# X:  (843, 112)
# 180.3
# 120
# temp length:  2
# X:  (844, 112)
# 210.18
# 140
# temp length:  2
# X:  (845, 112)
# 239.55
# 160
# temp length:  2
# X:  (846, 112)
# 267.08
# 178
# temp length:  2
# X:  (847, 112)
# 297.95
# 199
# temp length:  2
# X:  (848, 112)
# sub-024
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-024
# (205, 112)
# button press TRS: [117.56 172.6  222.47 245.77]
# 117.56
# 78
# temp length:  2
# X:  (849, 112)
# 172.6
# 115
# temp length:  2
# X:  (850, 112)
# 222.47
# 148
# temp length:  2
# X:  (851, 112)
# 245.77
# 164
# temp length:  2
# X:  (852, 112)
# condition:  SC
# run 0
# sub:  sub-024
# (205, 112)
# button press TRS: [ 34.55  66.88  95.75 120.6  162.12 254.99]
# 34.55
# 23
# temp length:  2
# X:  (853, 112)
# 66.88
# 45
# temp length:  2
# X:  (854, 112)
# 95.75
# 64
# temp length:  2
# X:  (855, 112)
# 120.6
# 80
# temp length:  2
# X:  (856, 112)
# 162.12
# 108
# temp length:  2
# X:  (857, 112)
# 254.99
# 170
# temp length:  2
# X:  (858, 112)
# condition:  SC
# run 1
# sub:  sub-024
# (205, 112)
# button press TRS: [ 30.66  55.78  82.73 113.48 141.77 169.02 199.54 226.49 256.35 283.8 ]
# 30.66
# 20
# temp length:  2
# X:  (859, 112)
# 55.78
# 37
# temp length:  2
# X:  (860, 112)
# 82.73
# 55
# temp length:  2
# X:  (861, 112)
# 113.48
# 76
# temp length:  2
# X:  (862, 112)
# 141.77
# 95
# temp length:  2
# X:  (863, 112)
# 169.02
# 113
# temp length:  2
# X:  (864, 112)
# 199.54
# 133
# temp length:  2
# X:  (865, 112)
# 226.49
# 151
# temp length:  2
# X:  (866, 112)
# 256.35
# 171
# temp length:  2
# X:  (867, 112)
# 283.8
# 189
# temp length:  2
# X:  (868, 112)
# sub-025
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-025
# (205, 112)
# button press TRS: [ 70.86 151.18 212.98 270.79 296.65]
# 70.86
# 47
# temp length:  2
# ...
# 14.25
# 10
# temp length:  2
# X:  (491, 187)
# 29.15
# 19
# temp length:  2
# X:  (492, 187)
# 44.05
# 29
# temp length:  2
# X:  (493, 187)
# 59.0
# 39
# temp length:  2
# X:  (494, 187)
# 74.01
# 49
# temp length:  2
# X:  (495, 187)
# 89.2
# 59
# temp length:  2
# X:  (496, 187)
# 104.0
# 69
# temp length:  2
# X:  (497, 187)
# 119.09
# 79
# temp length:  2
# X:  (498, 187)
# 134.08
# 89
# temp length:  2
# X:  (499, 187)
# 149.01
# 99
# temp length:  2
# X:  (500, 187)
# 164.04
# 109
# temp length:  2
# X:  (501, 187)
# 178.91
# 119
# temp length:  2
# X:  (502, 187)
# 194.07
# 129
# temp length:  2
# X:  (503, 187)
# 209.06
# 139
# temp length:  2
# X:  (504, 187)
# 223.89
# 149
# temp length:  2
# X:  (505, 187)
# 238.97
# 159
# temp length:  2
# X:  (506, 187)
# 253.95
# 169
# temp length:  2
# X:  (507, 187)
# 269.21
# 179
# temp length:  2
# X:  (508, 187)
# 284.23
# 189
# temp length:  2
# X:  (509, 187)
# 299.37
# 200
# temp length:  2
# X:  (510, 187)
# condition:  SC
# run 1
# sub:  sub-015
# (205, 187)
# button press TRS: [ 13.98  28.95  43.87  59.12  73.87  89.16 103.77 119.62 134.19 148.94
#  163.89 179.02 194.09 208.97 221.1  236.17 251.3  266.02 280.83 296.06]
# 13.98
# 9
# temp length:  2
# X:  (511, 187)
# 28.95
# 19
# temp length:  2
# X:  (512, 187)
# 43.87
# 29
# temp length:  2
# X:  (513, 187)
# 59.12
# 39
# temp length:  2
# X:  (514, 187)
# 73.87
# 49
# temp length:  2
# X:  (515, 187)
# 89.16
# 59
# temp length:  2
# X:  (516, 187)
# 103.77
# 69
# temp length:  2
# X:  (517, 187)
# 119.62
# 80
# temp length:  2
# X:  (518, 187)
# 134.19
# 89
# temp length:  2
# X:  (519, 187)
# 148.94
# 99
# temp length:  2
# X:  (520, 187)
# 163.89
# 109
# temp length:  2
# X:  (521, 187)
# 179.02
# 119
# temp length:  2
# X:  (522, 187)
# 194.09
# 129
# temp length:  2
# X:  (523, 187)
# 208.97
# 139
# temp length:  2
# X:  (524, 187)
# 221.1
# 147
# temp length:  2
# X:  (525, 187)
# 236.17
# 157
# temp length:  2
# X:  (526, 187)
# 251.3
# 168
# temp length:  2
# X:  (527, 187)
# 266.02
# 177
# temp length:  2
# X:  (528, 187)
# 280.83
# 187
# temp length:  2
# X:  (529, 187)
# 296.06
# 197
# temp length:  2
# X:  (530, 187)
# sub-016
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-016
# (205, 187)
# button press TRS: [ 26.49  62.43  76.12  95.15 117.18 145.22 193.75 220.63 264.68 291.24]
# 26.49
# 18
# temp length:  2
# X:  (531, 187)
# 62.43
# 42
# temp length:  2
# X:  (532, 187)
# 76.12
# 51
# temp length:  2
# X:  (533, 187)
# 95.15
# 63
# temp length:  2
# X:  (534, 187)
# 117.18
# 78
# temp length:  2
# X:  (535, 187)
# 145.22
# 97
# temp length:  2
# X:  (536, 187)
# 193.75
# 129
# temp length:  2
# X:  (537, 187)
# 220.63
# 147
# temp length:  2
# X:  (538, 187)
# 264.68
# 176
# temp length:  2
# X:  (539, 187)
# 291.24
# 194
# temp length:  2
# X:  (540, 187)
# condition:  SM
# run 1
# sub:  sub-016
# (205, 187)
# button press TRS: [ 18.12  41.49  53.62  73.57  91.2  109.62 135.8  157.28 181.04 206.07
#  256.5  274.35 298.34]
# 18.12
# 12
# temp length:  2
# X:  (541, 187)
# 41.49
# 28
# temp length:  2
# X:  (542, 187)
# 53.62
# 36
# temp length:  2
# X:  (543, 187)
# 73.57
# 49
# temp length:  2
# X:  (544, 187)
# 91.2
# 61
# temp length:  2
# X:  (545, 187)
# 109.62
# 73
# temp length:  2
# X:  (546, 187)
# 135.8
# 91
# temp length:  2
# X:  (547, 187)
# 157.28
# 105
# temp length:  2
# X:  (548, 187)
# 181.04
# 121
# temp length:  2
# X:  (549, 187)
# 206.07
# 137
# temp length:  2
# X:  (550, 187)
# 256.5
# 171
# temp length:  2
# X:  (551, 187)
# 274.35
# 183
# temp length:  2
# X:  (552, 187)
# 298.34
# 199
# temp length:  2
# X:  (553, 187)
# condition:  SC
# run 0
# sub:  sub-016
# (205, 187)
# button press TRS: [ 22.32  40.3   56.12  69.26  82.53  95.97 108.18 126.82 140.57 168.02
#  181.82 208.17 224.52 239.63 254.5  273.84 286.06 300.91]
# 22.32
# 15
# temp length:  2
# X:  (554, 187)
# 40.3
# 27
# temp length:  2
# X:  (555, 187)
# 56.12
# 37
# temp length:  2
# X:  (556, 187)
# 69.26
# 46
# temp length:  2
# X:  (557, 187)
# 82.53
# 55
# temp length:  2
# X:  (558, 187)
# 95.97
# 64
# temp length:  2
# X:  (559, 187)
# 108.18
# 72
# temp length:  2
# X:  (560, 187)
# 126.82
# 85
# temp length:  2
# X:  (561, 187)
# 140.57
# 94
# temp length:  2
# X:  (562, 187)
# 168.02
# 112
# temp length:  2
# X:  (563, 187)
# 181.82
# 121
# temp length:  2
# X:  (564, 187)
# 208.17
# 139
# temp length:  2
# X:  (565, 187)
# 224.52
# 150
# temp length:  2
# X:  (566, 187)
# 239.63
# 160
# temp length:  2
# X:  (567, 187)
# 254.5
# 170
# temp length:  2
# X:  (568, 187)
# 273.84
# 183
# temp length:  2
# X:  (569, 187)
# 286.06
# 191
# temp length:  2
# X:  (570, 187)
# 300.91
# 201
# temp length:  2
# X:  (571, 187)
# condition:  SC
# run 1
# sub:  sub-016
# (205, 187)
# button press TRS: [ 19.25  37.52  67.85  80.32  92.34 108.08 128.57 161.68 176.48 205.18
#  230.4 ]
# 19.25
# 13
# temp length:  2
# X:  (572, 187)
# 37.52
# 25
# temp length:  2
# X:  (573, 187)
# 67.85
# 45
# temp length:  2
# X:  (574, 187)
# 80.32
# 54
# temp length:  2
# X:  (575, 187)
# 92.34
# 62
# temp length:  2
# X:  (576, 187)
# 108.08
# 72
# temp length:  2
# X:  (577, 187)
# 128.57
# 86
# temp length:  2
# X:  (578, 187)
# 161.68
# 108
# temp length:  2
# X:  (579, 187)
# 176.48
# 118
# temp length:  2
# X:  (580, 187)
# 205.18
# 137
# temp length:  2
# X:  (581, 187)
# 230.4
# 154
# temp length:  2
# X:  (582, 187)
# sub-017
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-017
# (205, 187)
# button press TRS: [ 96.05 135.82 175.5  213.07 236.15 257.95 300.7 ]
# 96.05
# 64
# temp length:  2
# X:  (583, 187)
# 135.82
# 91
# temp length:  2
# X:  (584, 187)
# 175.5
# 117
# temp length:  2
# X:  (585, 187)
# 213.07
# 142
# temp length:  2
# X:  (586, 187)
# 236.15
# 157
# temp length:  2
# X:  (587, 187)
# 257.95
# 172
# temp length:  2
# X:  (588, 187)
# 300.7
# 200
# temp length:  2
# X:  (589, 187)
# condition:  SM
# run 1
# sub:  sub-017
# (205, 187)
# button press TRS: [ 29.37  67.53 106.2  127.17 155.85 167.87 192.92 208.   228.85 252.69
#  279.92 300.45]
# 29.37
# 20
# temp length:  2
# X:  (590, 187)
# 67.53
# 45
# temp length:  2
# X:  (591, 187)
# 106.2
# 71
# temp length:  2
# X:  (592, 187)
# 127.17
# 85
# temp length:  2
# X:  (593, 187)
# 155.85
# 104
# temp length:  2
# X:  (594, 187)
# 167.87
# 112
# temp length:  2
# X:  (595, 187)
# 192.92
# 129
# temp length:  2
# X:  (596, 187)
# 208.0
# 139
# temp length:  2
# X:  (597, 187)
# 228.85
# 153
# temp length:  2
# X:  (598, 187)
# 252.69
# 168
# temp length:  2
# X:  (599, 187)
# 279.92
# 187
# temp length:  2
# X:  (600, 187)
# 300.45
# 200
# temp length:  2
# X:  (601, 187)
# condition:  SC
# run 0
# sub:  sub-017
# (205, 187)
# button press TRS: [ 32.11  61.7   94.66 127.38 159.91 187.95 218.49 248.87 279.18]
# 32.11
# 21
# temp length:  2
# X:  (602, 187)
# 61.7
# 41
# temp length:  2
# X:  (603, 187)
# 94.66
# 63
# temp length:  2
# X:  (604, 187)
# 127.38
# 85
# temp length:  2
# X:  (605, 187)
# 159.91
# 107
# temp length:  2
# X:  (606, 187)
# 187.95
# 125
# temp length:  2
# X:  (607, 187)
# 218.49
# 146
# temp length:  2
# X:  (608, 187)
# 248.87
# 166
# temp length:  2
# X:  (609, 187)
# 279.18
# 186
# temp length:  2
# X:  (610, 187)
# sub-018
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-018
# (205, 187)
# button press TRS: [ 82.38 122.97 206.33 245.09]
# 82.38
# 55
# temp length:  2
# X:  (611, 187)
# 122.97
# 82
# temp length:  2
# X:  (612, 187)
# 206.33
# 138
# temp length:  2
# X:  (613, 187)
# 245.09
# 163
# temp length:  2
# X:  (614, 187)
# condition:  SM
# run 1
# sub:  sub-018
# (205, 187)
# button press TRS: [ 53.05 123.74 182.08 233.53]
# 53.05
# 35
# temp length:  2
# X:  (615, 187)
# 123.74
# 82
# temp length:  2
# X:  (616, 187)
# 182.08
# 121
# temp length:  2
# X:  (617, 187)
# 233.53
# 156
# temp length:  2
# X:  (618, 187)
# condition:  SC
# run 0
# sub:  sub-018
# (205, 187)
# button press TRS: [ 35.68  75.37 110.9  144.72 179.89 214.61 243.57 276.68 306.11]
# 35.68
# 24
# temp length:  2
# X:  (619, 187)
# 75.37
# 50
# temp length:  2
# X:  (620, 187)
# 110.9
# 74
# temp length:  2
# X:  (621, 187)
# 144.72
# 96
# temp length:  2
# X:  (622, 187)
# 179.89
# 120
# temp length:  2
# X:  (623, 187)
# 214.61
# 143
# temp length:  2
# X:  (624, 187)
# 243.57
# 162
# temp length:  2
# X:  (625, 187)
# 276.68
# 184
# temp length:  2
# X:  (626, 187)
# 306.11
# 204
# temp length:  2
# X:  (627, 187)
# condition:  SC
# run 1
# sub:  sub-018
# (205, 187)
# button press TRS: [ 26.65  59.55  99.6  136.57 174.8  208.2  247.35 280.55]
# 26.65
# 18
# temp length:  2
# X:  (628, 187)
# 59.55
# 40
# temp length:  2
# X:  (629, 187)
# 99.6
# 66
# temp length:  2
# X:  (630, 187)
# 136.57
# 91
# temp length:  2
# X:  (631, 187)
# 174.8
# 117
# temp length:  2
# X:  (632, 187)
# 208.2
# 139
# temp length:  2
# X:  (633, 187)
# 247.35
# 165
# temp length:  2
# X:  (634, 187)
# 280.55
# 187
# temp length:  2
# X:  (635, 187)
# sub-019
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-019
# (205, 187)
# button press TRS: [ 82.58 172.3  223.21 253.43]
# 82.58
# 55
# temp length:  2
# X:  (636, 187)
# 172.3
# 115
# temp length:  2
# X:  (637, 187)
# 223.21
# 149
# temp length:  2
# X:  (638, 187)
# 253.43
# 169
# temp length:  2
# X:  (639, 187)
# condition:  SC
# run 0
# sub:  sub-019
# (205, 187)
# button press TRS: [  4.56  35.03  71.81 112.   136.35 163.08 176.45 211.93 236.78 250.44
#  266.98 283.88 300.76]
# 4.56
# 3
# temp length:  2
# X:  (640, 187)
# 35.03
# 23
# temp length:  2
# X:  (641, 187)
# 71.81
# 48
# temp length:  2
# X:  (642, 187)
# 112.0
# 75
# temp length:  2
# X:  (643, 187)
# 136.35
# 91
# temp length:  2
# X:  (644, 187)
# 163.08
# 109
# temp length:  2
# X:  (645, 187)
# 176.45
# 118
# temp length:  2
# X:  (646, 187)
# 211.93
# 141
# temp length:  2
# X:  (647, 187)
# 236.78
# 158
# temp length:  2
# X:  (648, 187)
# 250.44
# 167
# temp length:  2
# X:  (649, 187)
# 266.98
# 178
# temp length:  2
# X:  (650, 187)
# 283.88
# 189
# temp length:  2
# X:  (651, 187)
# 300.76
# 201
# temp length:  2
# X:  (652, 187)
# condition:  SC
# run 1
# sub:  sub-019
# (205, 187)
# button press TRS: [ 16.25  31.77  45.26  59.85  73.96 104.63 121.88 187.39 208.81 228.38
#  241.81 255.06 268.9  297.11]
# 16.25
# 11
# temp length:  2
# X:  (653, 187)
# 31.77
# 21
# temp length:  2
# X:  (654, 187)
# 45.26
# 30
# temp length:  2
# X:  (655, 187)
# 59.85
# 40
# temp length:  2
# X:  (656, 187)
# 73.96
# 49
# temp length:  2
# X:  (657, 187)
# 104.63
# 70
# temp length:  2
# X:  (658, 187)
# 121.88
# 81
# temp length:  2
# X:  (659, 187)
# 187.39
# 125
# temp length:  2
# X:  (660, 187)
# 208.81
# 139
# temp length:  2
# X:  (661, 187)
# 228.38
# 152
# temp length:  2
# X:  (662, 187)
# 241.81
# 161
# temp length:  2
# X:  (663, 187)
# 255.06
# 170
# temp length:  2
# X:  (664, 187)
# 268.9
# 179
# temp length:  2
# X:  (665, 187)
# 297.11
# 198
# temp length:  2
# X:  (666, 187)
# sub-020
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-020
# (205, 187)
# button press TRS: [ 72.72 111.13 131.81 157.68 171.93 231.8  246.2  274.37 293.93]
# 72.72
# 48
# temp length:  2
# X:  (667, 187)
# 111.13
# 74
# temp length:  2
# X:  (668, 187)
# 131.81
# 88
# temp length:  2
# X:  (669, 187)
# 157.68
# 105
# temp length:  2
# X:  (670, 187)
# 171.93
# 115
# temp length:  2
# X:  (671, 187)
# 231.8
# 155
# temp length:  2
# X:  (672, 187)
# 246.2
# 164
# temp length:  2
# X:  (673, 187)
# 274.37
# 183
# temp length:  2
# X:  (674, 187)
# 293.93
# 196
# temp length:  2
# X:  (675, 187)
# condition:  SM
# run 1
# sub:  sub-020
# (205, 187)
# button press TRS: [ 50.5   77.4  102.37 118.94 131.74 156.85 170.07 184.28 197.78 221.13
#  241.48 274.3 ]
# 50.5
# 34
# temp length:  2
# X:  (676, 187)
# 77.4
# 52
# temp length:  2
# X:  (677, 187)
# 102.37
# 68
# temp length:  2
# X:  (678, 187)
# 118.94
# 79
# temp length:  2
# X:  (679, 187)
# 131.74
# 88
# temp length:  2
# X:  (680, 187)
# 156.85
# 105
# temp length:  2
# X:  (681, 187)
# 170.07
# 113
# temp length:  2
# X:  (682, 187)
# 184.28
# 123
# temp length:  2
# X:  (683, 187)
# 197.78
# 132
# temp length:  2
# X:  (684, 187)
# 221.13
# 147
# temp length:  2
# X:  (685, 187)
# 241.48
# 161
# temp length:  2
# X:  (686, 187)
# 274.3
# 183
# temp length:  2
# X:  (687, 187)
# condition:  SC
# run 0
# sub:  sub-020
# (205, 187)
# button press TRS: [ 26.15  54.02  78.17 104.   128.64 154.94 177.42 203.12 222.34 246.28
#  284.12 303.04]
# 26.15
# 17
# temp length:  2
# X:  (688, 187)
# 54.02
# 36
# temp length:  2
# X:  (689, 187)
# 78.17
# 52
# temp length:  2
# X:  (690, 187)
# 104.0
# 69
# temp length:  2
# X:  (691, 187)
# 128.64
# 86
# temp length:  2
# X:  (692, 187)
# 154.94
# 103
# temp length:  2
# X:  (693, 187)
# 177.42
# 118
# temp length:  2
# X:  (694, 187)
# 203.12
# 135
# temp length:  2
# X:  (695, 187)
# 222.34
# 148
# temp length:  2
# X:  (696, 187)
# 246.28
# 164
# temp length:  2
# X:  (697, 187)
# 284.12
# 189
# temp length:  2
# X:  (698, 187)
# 303.04
# 202
# temp length:  2
# X:  (699, 187)
# condition:  SC
# run 1
# sub:  sub-020
# (205, 187)
# button press TRS: [ 22.4   40.76  58.39  76.25  92.09 121.97 137.04 151.78 165.73 190.2
#  253.87 273.14 305.2 ]
# 22.4
# 15
# temp length:  2
# X:  (700, 187)
# 40.76
# 27
# temp length:  2
# X:  (701, 187)
# 58.39
# 39
# temp length:  2
# X:  (702, 187)
# 76.25
# 51
# temp length:  2
# X:  (703, 187)
# 92.09
# 61
# temp length:  2
# X:  (704, 187)
# 121.97
# 81
# temp length:  2
# X:  (705, 187)
# 137.04
# 91
# temp length:  2
# X:  (706, 187)
# 151.78
# 101
# temp length:  2
# X:  (707, 187)
# 165.73
# 110
# temp length:  2
# X:  (708, 187)
# 190.2
# 127
# temp length:  2
# X:  (709, 187)
# 253.87
# 169
# temp length:  2
# X:  (710, 187)
# 273.14
# 182
# temp length:  2
# X:  (711, 187)
# 305.2
# 203
# temp length:  2
# X:  (712, 187)
# sub-021
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-021
# (205, 187)
# button press TRS: [  9.3   32.5   52.35  74.14  99.87 112.43 143.53 168.58 185.18 209.83
#  226.1  240.33 266.27 281.32]
# 9.3
# 6
# temp length:  2
# X:  (713, 187)
# 32.5
# 22
# temp length:  2
# X:  (714, 187)
# 52.35
# 35
# temp length:  2
# X:  (715, 187)
# 74.14
# 49
# temp length:  2
# X:  (716, 187)
# 99.87
# 67
# temp length:  2
# X:  (717, 187)
# 112.43
# 75
# temp length:  2
# X:  (718, 187)
# 143.53
# 96
# temp length:  2
# X:  (719, 187)
# 168.58
# 112
# temp length:  2
# X:  (720, 187)
# 185.18
# 123
# temp length:  2
# X:  (721, 187)
# 209.83
# 140
# temp length:  2
# X:  (722, 187)
# 226.1
# 151
# temp length:  2
# X:  (723, 187)
# 240.33
# 160
# temp length:  2
# X:  (724, 187)
# 266.27
# 178
# temp length:  2
# X:  (725, 187)
# 281.32
# 188
# temp length:  2
# X:  (726, 187)
# condition:  SM
# run 1
# sub:  sub-021
# (205, 187)
# button press TRS: [  6.92  26.99  41.78  58.5   86.78 108.07 136.74 153.25 171.08 185.42
#  198.06 211.   224.54 236.79 257.35 277.88 294.43]
# 6.92
# 5
# temp length:  2
# X:  (727, 187)
# 26.99
# 18
# temp length:  2
# X:  (728, 187)
# 41.78
# 28
# temp length:  2
# X:  (729, 187)
# 58.5
# 39
# temp length:  2
# X:  (730, 187)
# 86.78
# 58
# temp length:  2
# X:  (731, 187)
# 108.07
# 72
# temp length:  2
# X:  (732, 187)
# 136.74
# 91
# temp length:  2
# X:  (733, 187)
# 153.25
# 102
# temp length:  2
# X:  (734, 187)
# 171.08
# 114
# temp length:  2
# X:  (735, 187)
# 185.42
# 124
# temp length:  2
# X:  (736, 187)
# 198.06
# 132
# temp length:  2
# X:  (737, 187)
# 211.0
# 141
# temp length:  2
# X:  (738, 187)
# 224.54
# 150
# temp length:  2
# X:  (739, 187)
# 236.79
# 158
# temp length:  2
# X:  (740, 187)
# 257.35
# 172
# temp length:  2
# X:  (741, 187)
# 277.88
# 185
# temp length:  2
# X:  (742, 187)
# 294.43
# 196
# temp length:  2
# X:  (743, 187)
# condition:  SC
# run 0
# sub:  sub-021
# (205, 187)
# button press TRS: [ 19.68  35.27  49.95  65.16  80.24  95.07 109.77 125.25 140.07 155.23
#  170.22 184.79 201.63 216.7  243.28 259.27 271.3  287.12 302.05]
# 19.68
# 13
# temp length:  2
# X:  (744, 187)
# 35.27
# 24
# temp length:  2
# X:  (745, 187)
# 49.95
# 33
# temp length:  2
# X:  (746, 187)
# 65.16
# 43
# temp length:  2
# X:  (747, 187)
# 80.24
# 53
# temp length:  2
# X:  (748, 187)
# 95.07
# 63
# temp length:  2
# X:  (749, 187)
# 109.77
# 73
# temp length:  2
# X:  (750, 187)
# 125.25
# 84
# temp length:  2
# X:  (751, 187)
# 140.07
# 93
# temp length:  2
# X:  (752, 187)
# 155.23
# 103
# temp length:  2
# X:  (753, 187)
# 170.22
# 113
# temp length:  2
# X:  (754, 187)
# 184.79
# 123
# temp length:  2
# X:  (755, 187)
# 201.63
# 134
# temp length:  2
# X:  (756, 187)
# 216.7
# 144
# temp length:  2
# X:  (757, 187)
# 243.28
# 162
# temp length:  2
# X:  (758, 187)
# 259.27
# 173
# temp length:  2
# X:  (759, 187)
# 271.3
# 181
# temp length:  2
# X:  (760, 187)
# 287.12
# 191
# temp length:  2
# X:  (761, 187)
# 302.05
# 201
# temp length:  2
# X:  (762, 187)
# condition:  SC
# run 1
# sub:  sub-021
# (205, 187)
# button press TRS: [ 15.74  31.06  45.72  75.62  89.85 104.11 119.23 131.53 149.2  173.99
#  201.53 215.75 234.54 247.6  274.39 287.07 300.66]
# 15.74
# 10
# temp length:  2
# X:  (763, 187)
# 31.06
# 21
# temp length:  2
# X:  (764, 187)
# 45.72
# 30
# temp length:  2
# X:  (765, 187)
# 75.62
# 50
# temp length:  2
# X:  (766, 187)
# 89.85
# 60
# temp length:  2
# X:  (767, 187)
# 104.11
# 69
# temp length:  2
# X:  (768, 187)
# 119.23
# 79
# temp length:  2
# X:  (769, 187)
# 131.53
# 88
# temp length:  2
# X:  (770, 187)
# 149.2
# 99
# temp length:  2
# X:  (771, 187)
# 173.99
# 116
# temp length:  2
# X:  (772, 187)
# 201.53
# 134
# temp length:  2
# X:  (773, 187)
# 215.75
# 144
# temp length:  2
# X:  (774, 187)
# 234.54
# 156
# temp length:  2
# X:  (775, 187)
# 247.6
# 165
# temp length:  2
# X:  (776, 187)
# 274.39
# 183
# temp length:  2
# X:  (777, 187)
# 287.07
# 191
# temp length:  2
# X:  (778, 187)
# 300.66
# 200
# temp length:  2
# X:  (779, 187)
# sub-022
# concatenated SM SC
# condition:  SM
# run 0
# sub:  sub-022
# (205, 187)
# button press TRS: [ 75.91  97.45 141.7  173.18 224.04 266.33 279.56 294.89]
# 75.91
# 51
# temp length:  2
# X:  (780, 187)
# 97.45
# 65
# temp length:  2
# X:  (781, 187)
# 141.7
# 94
# temp length:  2
# X:  (782, 187)
# 173.18
# 115
# temp length:  2
# X:  (783, 187)
# 224.04
# 149
# temp length:  2
# X:  (784, 187)
# 266.33
# 178
# temp length:  2
# X:  (785, 187)
# 279.56
# 186
# temp length:  2
# X:  (786, 187)
# 294.89
# 197
# temp length:  2
# X:  (787, 187)
# condition:  SM
# run 1
# sub:  sub-022

# %%
activations = np.load(os.path.join(act_dir, '%s.npy') %(act_dict_name ), allow_pickle=True).item()
for key in sorted(activations):
    print(key)
# Out:
# OM_OC_dmPFC_win1
# OM_OC_dmPFC_win2
# OM_OC_dmPFC_win3
# OM_OC_dmPFC_win4
# OM_OC_dmPFC_win5
# OM_OC_dmPFC_win6
# OM_OC_dmPFC_win7
# OM_OC_dmPFC_win8
# OM_OC_rTPJ_win1
# OM_OC_rTPJ_win2
# OM_OC_rTPJ_win3
# OM_OC_rTPJ_win4
# OM_OC_rTPJ_win5
# OM_OC_rTPJ_win6
# OM_OC_rTPJ_win7
# OM_OC_rTPJ_win8
# SM_SC_dmPFC_win1
# SM_SC_dmPFC_win2
# SM_SC_dmPFC_win3
# SM_SC_dmPFC_win4
# SM_SC_dmPFC_win5
# SM_SC_dmPFC_win6
# SM_SC_dmPFC_win7
# SM_SC_dmPFC_win8
# SM_SC_rTPJ_win1
# SM_SC_rTPJ_win2
# SM_SC_rTPJ_win3
# SM_SC_rTPJ_win4
# SM_SC_rTPJ_win5
# SM_SC_rTPJ_win6
# SM_SC_rTPJ_win7
# SM_SC_rTPJ_win8
