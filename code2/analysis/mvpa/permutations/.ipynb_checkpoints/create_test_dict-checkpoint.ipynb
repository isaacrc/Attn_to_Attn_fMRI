# %%
import pandas as pd
import numpy as np
import os
from datetime import date

# %%
# directory # 
out_dir = '/jukebox/graziano/mindy/permutations'
date = date.today()
dictionary_name = f'perm_results_{date}'

# %%
# # name of current analysis
# analysis = 'SM_SC_dMPFC_win1'

# %%
# only create new directory once ! # can just reload it after initial save 
d = {}

# %%
# # Create for every analysis, after finishes running 
# d2 = {"accuracy":[.54], "accuracy_vec": [.53,.49,.7], "perm_acc":[.50], "pval":[.09]}
# # analysis 1
# d[analysis] = d2
# # another analysis -- just as an example -- would have different acc metrics, etc # 
# d["SM_SC_tpj_win1"] = d2

# %%
d
# Out:
# {'SM_SC_dMPFC_win1': {'accuracy': [0.54],
#   'accuracy_vec': [0.53, 0.49, 0.7],
#   'perm_acc': [0.5],
#   'pval': [0.09]},
#  'SM_SC_tpj_win1': {'accuracy': [0.54],
#   'accuracy_vec': [0.53, 0.49, 0.7],
#   'perm_acc': [0.5],
#   'pval': [0.09]}}

# %%
# d['SM_SC_dMPFC_win1']['accuracy_vec'][1]
# Out:
# 0.49

# %%
pd.DataFrame(d).T
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# save

# %%
# np.save(os.path.join(out_dir, '%s.npy') %(dictionary_name), d)

# %%
# load existing dictionary to save new data, following each analysis #

# %%
d = dict(enumerate(np.load(os.path.join(out_dir, '%s.npy') %(dictionary_name), 
                                allow_pickle=True).flatten(),1))[1]

# %%
d
# Out:
# {}

# %%
# # name of current analysis
# analysis = 'SM_SC_dMPFC_win2'

# # add new analysis 
# d[analysis] = d2

# d
# Out:
# {'SM_SC_dMPFC_win1': {'accuracy': [0.54],
#   'accuracy_vec': [0.53, 0.49, 0.7],
#   'perm_acc': [0.5],
#   'pval': [0.09]},
#  'SM_SC_tpj_win1': {'accuracy': [0.54],
#   'accuracy_vec': [0.53, 0.49, 0.7],
#   'perm_acc': [0.5],
#   'pval': [0.09]},
#  'SM_SC_dMPFC_win2': {'accuracy': [0.54],
#   'accuracy_vec': [0.53, 0.49, 0.7],
#   'perm_acc': [0.5],
#   'pval': [0.09]}}

# %%
# save again
# np.save(os.path.join(out_dir, '%s.npy') %(dictionary_name), d)
